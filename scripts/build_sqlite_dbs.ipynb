# %% [markdown]
# # Imports

# %%
import pandas as pd
from tqdm.notebook import tqdm
import sqlite3

# %% [markdown]
# # Create SQLite DBs from Hopteam and NPPES

# %% [markdown]
# ## Explore NPPES CSVs

# %%
end = pd.read_csv('../data/NPPES/endpoint.csv', chunksize = 1000)
npi = pd.read_csv('../data/NPPES/npidata.csv', chunksize = 1000)
other = pd.read_csv('../data/NPPES/othername.csv', chunksize = 1000)
pl = pd.read_csv('../data/NPPES/pl.csv', chunksize = 1000)

# %% [markdown]
# ## endpoint

# %%
end_chunk1 = next(end)
end_chunk1.head()
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 1000  1639173594        DIRECT  Direct Messaging Address
# 1001  1548264401        DIRECT  Direct Messaging Address
# 1002  1003810961        DIRECT  Direct Messaging Address
# 1003  1912901877        DIRECT  Direct Messaging Address
# 1004  1558365411        DIRECT  Direct Messaging Address
#
#                                                Endpoint Affiliation  \
# 1000  julie.grannanfnpc.p63@direct.ahni.nextgenshare...           N
# 1001             robert.caffrey@digichart.direct-ci.com           N
# 1002                 michael.d.marshall2@upmcdirect.com           Y
# 1003  Direct@IllinoisEyeCenterPeoriaIL.CompulinkDire...           N
# 1004      eric.kanter.p1@direct.rvc-nj.nextgenshare.com           N
#
#                        Endpoint Description Affiliation Legal Business Name  \
# 1000                                    NaN                             NaN
# 1001                                    NaN                             NaN
# 1002                                    NaN                            UPMC
# 1003  CCD only, does not accept attachments                             NaN
# 1004                         Direct Address                             NaN
#
#      Use Code                    Use Description Other Use Description  \
# 1000   DIRECT                             Direct                   NaN
# 1001      NaN                                NaN                   NaN
# 1002      NaN                                NaN                   NaN
# 1003   DIRECT                             Direct                   NaN
# 1004      HIE  Health Information Exchange (HIE)                   NaN
#
#      Content Type Content Description Other Content Description  \
# 1000        OTHER               Other                      CCDA
# 1001          NaN                 NaN                       NaN
# 1002          NaN                 NaN                       NaN
# 1003          NaN                 NaN                       NaN
# 1004          CSV                 CSV                       NaN
#
#      Affiliation Address Line One Affiliation Address Line Two  \
# 1000          4101 Technology Ave                          NaN
# 1001            19550 E 39th St S                      Ste 300
# 1002                 600 Grant St                     Floor 58
# 1003          8921 N Wood Sage Rd                          NaN
# 1004          349 E Northfield Rd                      Ste 100
#
#      Affiliation Address City Affiliation Address State  \
# 1000               New Albany                        IN
# 1001             Independence                        MO
# 1002               Pittsburgh                        PA
# 1003                   Peoria                        IL
# 1004               Livingston                        NJ
#
#      Affiliation Address Country  Affiliation Address Postal Code
# 1000                          US                      471508548.0
# 1001                          US                      640572303.0
# 1002                          US                      152192702.0
# 1003                          US                      616157822.0
# 1004                          US                       70394802.0

# %%
end_chunk1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1000 to 1999
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   NPI                              1000 non-null   int64
#  1   Endpoint Type                    999 non-null    object
#  2   Endpoint Type Description        999 non-null    object
#  3   Endpoint                         999 non-null    object
#  4   Affiliation                      1000 non-null   object
#  5   Endpoint Description             291 non-null    object
#  6   Affiliation Legal Business Name  148 non-null    object
#  7   Use Code                         454 non-null    object
#  8   Use Description                  454 non-null    object
#  9   Other Use Description            39 non-null     object
#  10  Content Type                     307 non-null    object
#  11  Content Description              307 non-null    object
#  12  Other Content Description        206 non-null    object
#  13  Affiliation Address Line One     998 non-null    object
#  14  Affiliation Address Line Two     285 non-null    object
#  15  Affiliation Address City         998 non-null    object
#  16  Affiliation Address State        998 non-null    object
#  17  Affiliation Address Country      998 non-null    object
#  18  Affiliation Address Postal Code  998 non-null    float64
# dtypes: float64(1), int64(1), object(17)
# memory usage: 148.6+ KB

# %% [markdown]
# ## npi
#     - 'NPI'
#     - 'Entity Type Code'
#     - 'Provider Organization Name (Legal Business Name)'
#     - 'Provider Last Name (Legal Name)'
#     - 'Provider First Name'
#     - 'Provider Middle Name'
#     - 'Provider Name Prefix Text'
#     - 'Provider Name Suffix Text'
#     - 'Provider Credential Text'
#     - 'Provider First Line Business Practice Location Address'
#     - 'Provider Second Line Business Practice Location Address'
#     - 'Provider Business Practice Location Address City Name'
#     - 'Provider Business Practice Location Address State Name'
#     - 'Provider Business Practice Location Address Postal Code'

# %%
npi_chunk1 = next(npi)

# %%
taxes = npi_chunk1.filter(regex = '^NPI$|(Taxonomy (Code|Switch))')

taxes_code_long = taxes.melt(id_vars = [col for col in taxes.columns if 'NPI' in col or 'Taxonomy Switch' in col],
           var_name = 'Taxonomy Code Number',
           value_name = 'Taxonomy Code'
          )
taxes_long = taxes_code_long.melt(id_vars = [col for col in taxes_code_long.columns if 'NPI' in col or 'Taxonomy Code' in col],
                 var_name = 'Taxonomy Switch Number',
                 value_name = 'Taxonomy Switch'
            )

taxes_long['Taxonomy Code Number'] = taxes_long['Taxonomy Code Number'].str.extract('(\d+)')
taxes_long['Taxonomy Switch Number'] = taxes_long['Taxonomy Switch Number'].str.extract('(\d+)')

primary_taxes = (taxes_long[(taxes_long['Taxonomy Code Number'] == taxes_long['Taxonomy Switch Number']) 
                & 
                (taxes_long['Taxonomy Switch'] == 'Y')]
                .drop(columns = ['Taxonomy Code Number','Taxonomy Switch Number'])
            )

primary_taxes
# Out:
#                NPI Taxonomy Code Taxonomy Switch
# 0       1962405183    2085R0202X               Y
# 1       1871596098    174400000X               Y
# 2       1780687905    207RG0100X               Y
# 3       1598768715    174400000X               Y
# 4       1407859622    363LF0000X               Y
# ...            ...           ...             ...
# 96505   1568465789    225100000X               Y
# 128559  1295738409    3336H0001X               Y
# 144705  1962405159    261QP0905X               Y
# 208019  1952304164    225100000X               Y
# 224035  1114920329    207Q00000X               Y
#
# [924 rows x 3 columns]

# %%
 profile_cols = ['NPI',
                 'Entity Type Code',
                 'Provider Organization Name (Legal Business Name)',
                 'Provider Last Name (Legal Name)',
                 'Provider First Name',
                 'Provider Middle Name',
                 'Provider Name Prefix Text',
                 'Provider Name Suffix Text',
                 'Provider Credential Text',
                 'Provider First Line Business Practice Location Address',
                 'Provider Second Line Business Practice Location Address',
                 'Provider Business Practice Location Address City Name',
                 'Provider Business Practice Location Address State Name',
                 'Provider Business Practice Location Address Postal Code']
profile = npi_chunk1.filter(items = profile_cols)
profile
# Out:
#              NPI  Entity Type Code  \
# 1000  1962405183               1.0
# 1001  1871596098               1.0
# 1002  1780687905               1.0
# 1003  1598768715               1.0
# 1004  1407859622               1.0
# ...          ...               ...
# 1995  1659374775               1.0
# 1996  1568465680               1.0
# 1997  1477556595               1.0
# 1998  1386647402               2.0
# 1999  1295738318               1.0
#
#      Provider Organization Name (Legal Business Name)  \
# 1000                                              NaN
# 1001                                              NaN
# 1002                                              NaN
# 1003                                              NaN
# 1004                                              NaN
# ...                                               ...
# 1995                                              NaN
# 1996                                              NaN
# 1997                                              NaN
# 1998               PHYSICIANS DAY SURGERY CENTER, LLC
# 1999                                              NaN
#
#      Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 1000                             FOX              DANIEL                    R
# 1001                     DIAZ-LACAYO              MARVIN                  NaN
# 1002                            KIRK              ROBERT                    M
# 1003                           MOSCA              PHILIP                  NaN
# 1004                       MARKWARDT              GEORGE                  LEE
# ...                              ...                 ...                  ...
# 1995                           CLARK                MARY               MCGINN
# 1996                          HORGAN                JOHN                   D.
# 1997                           CLOYD               DAVID                    G
# 1998                             NaN                 NaN                  NaN
# 1999                           FIRTH              WINONA                   J.
#
#      Provider Name Prefix Text Provider Name Suffix Text  \
# 1000                       DR.                       NaN
# 1001                       NaN                       NaN
# 1002                       DR.                       NaN
# 1003                       DR.                       NaN
# 1004                       MR.                       NaN
# ...                        ...                       ...
# 1995                       DR.                       NaN
# 1996                       NaN                       NaN
# 1997                       DR.                       NaN
# 1998                       NaN                       NaN
# 1999                       DR.                       NaN
#
#      Provider Credential Text  \
# 1000                       MD
# 1001                       MD
# 1002                     M.D.
# 1003                       MD
# 1004                       NP
# ...                       ...
# 1995                    PH.D.
# 1996                     M.D.
# 1997                       MD
# 1998                      NaN
# 1999                     O.D.
#
#      Provider First Line Business Practice Location Address  \
# 1000                        11995 SINGLETREE LN STE 500
# 1001                                21150 BISCAYNE BLVD
# 1002                                  815 E PARRISH AVE
# 1003                                 4200 S DOUGLAS AVE
# 1004                                     55 CENTRAL PLZ
# ...                                                 ...
# 1995                         10981 SAN DIEGO MISSION RD
# 1996                                   10707 PACIFIC ST
# 1997                                   2710 E HARNEY ST
# 1998                                    850 111TH AVE N
# 1999                                           840 A ST
#
#      Provider Second Line Business Practice Location Address  \
# 1000                                                NaN
# 1001                                            STE 101
# 1002                                            STE 450
# 1003                                            STE 300
# 1004                                                NaN
# ...                                                 ...
# 1995                                            STE 114
# 1996                                          SUITE 101
# 1997                                          SUITE 100
# 1998                                                NaN
# 1999                                                NaN
#
#      Provider Business Practice Location Address City Name  \
# 1000                                       EDEN PRAIRIE
# 1001                                           AVENTURA
# 1002                                          OWENSBORO
# 1003                                      OKLAHOMA CITY
# 1004                                              ILION
# ...                                                 ...
# 1995                                          SAN DIEGO
# 1996                                              OMAHA
# 1997                                            LARAMIE
# 1998                                             NAPLES
# 1999                                        SPRINGFIELD
#
#      Provider Business Practice Location Address State Name  \
# 1000                                                 MN
# 1001                                                 FL
# 1002                                                 KY
# 1003                                                 OK
# 1004                                                 NY
# ...                                                 ...
# 1995                                                 CA
# 1996                                                 NE
# 1997                                                 WY
# 1998                                                 FL
# 1999                                                 OR
#
#       Provider Business Practice Location Address Postal Code
# 1000                                        553445349.0
# 1001                                        331801226.0
# 1002                                        423033223.0
# 1003                                        731093215.0
# 1004                                        133571701.0
# ...                                                 ...
# 1995                                        921082448.0
# 1996                                        681144762.0
# 1997                                        820722884.0
# 1998                                        341081803.0
# 1999                                        974774710.0
#
# [1000 rows x 14 columns]

# %%
nppes_chunk = pd.merge(profile, primary_taxes)
nppes_chunk
# Out:
#             NPI  Entity Type Code  \
# 0    1962405183               1.0
# 1    1871596098               1.0
# 2    1780687905               1.0
# 3    1598768715               1.0
# 4    1407859622               1.0
# ..          ...               ...
# 919  1659374775               1.0
# 920  1568465680               1.0
# 921  1477556595               1.0
# 922  1386647402               2.0
# 923  1295738318               1.0
#
#     Provider Organization Name (Legal Business Name)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 919                                              NaN
# 920                                              NaN
# 921                                              NaN
# 922               PHYSICIANS DAY SURGERY CENTER, LLC
# 923                                              NaN
#
#     Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                               FOX              DANIEL                    R
# 1                       DIAZ-LACAYO              MARVIN                  NaN
# 2                              KIRK              ROBERT                    M
# 3                             MOSCA              PHILIP                  NaN
# 4                         MARKWARDT              GEORGE                  LEE
# ..                              ...                 ...                  ...
# 919                           CLARK                MARY               MCGINN
# 920                          HORGAN                JOHN                   D.
# 921                           CLOYD               DAVID                    G
# 922                             NaN                 NaN                  NaN
# 923                           FIRTH              WINONA                   J.
#
#     Provider Name Prefix Text Provider Name Suffix Text  \
# 0                         DR.                       NaN
# 1                         NaN                       NaN
# 2                         DR.                       NaN
# 3                         DR.                       NaN
# 4                         MR.                       NaN
# ..                        ...                       ...
# 919                       DR.                       NaN
# 920                       NaN                       NaN
# 921                       DR.                       NaN
# 922                       NaN                       NaN
# 923                       DR.                       NaN
#
#     Provider Credential Text  \
# 0                         MD
# 1                         MD
# 2                       M.D.
# 3                         MD
# 4                         NP
# ..                       ...
# 919                    PH.D.
# 920                     M.D.
# 921                       MD
# 922                      NaN
# 923                     O.D.
#
#     Provider First Line Business Practice Location Address  \
# 0                          11995 SINGLETREE LN STE 500
# 1                                  21150 BISCAYNE BLVD
# 2                                    815 E PARRISH AVE
# 3                                   4200 S DOUGLAS AVE
# 4                                       55 CENTRAL PLZ
# ..                                                 ...
# 919                         10981 SAN DIEGO MISSION RD
# 920                                   10707 PACIFIC ST
# 921                                   2710 E HARNEY ST
# 922                                    850 111TH AVE N
# 923                                           840 A ST
#
#     Provider Second Line Business Practice Location Address  \
# 0                                                  NaN
# 1                                              STE 101
# 2                                              STE 450
# 3                                              STE 300
# 4                                                  NaN
# ..                                                 ...
# 919                                            STE 114
# 920                                          SUITE 101
# 921                                          SUITE 100
# 922                                                NaN
# 923                                                NaN
#
#     Provider Business Practice Location Address City Name  \
# 0                                         EDEN PRAIRIE
# 1                                             AVENTURA
# 2                                            OWENSBORO
# 3                                        OKLAHOMA CITY
# 4                                                ILION
# ..                                                 ...
# 919                                          SAN DIEGO
# 920                                              OMAHA
# 921                                            LARAMIE
# 922                                             NAPLES
# 923                                        SPRINGFIELD
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   MN
# 1                                                   FL
# 2                                                   KY
# 3                                                   OK
# 4                                                   NY
# ..                                                 ...
# 919                                                 CA
# 920                                                 NE
# 921                                                 WY
# 922                                                 FL
# 923                                                 OR
#
#      Provider Business Practice Location Address Postal Code Taxonomy Code  \
# 0                                          553445349.0          2085R0202X
# 1                                          331801226.0          174400000X
# 2                                          423033223.0          207RG0100X
# 3                                          731093215.0          174400000X
# 4                                          133571701.0          363LF0000X
# ..                                                 ...                 ...
# 919                                        921082448.0          103TC1900X
# 920                                        681144762.0          208800000X
# 921                                        820722884.0          207V00000X
# 922                                        341081803.0          261QA1903X
# 923                                        974774710.0          152W00000X
#
#     Taxonomy Switch
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y
# ..              ...
# 919               Y
# 920               Y
# 921               Y
# 922               Y
# 923               Y
#
# [924 rows x 16 columns]

# %% [markdown]
# ## pl

# %% [markdown]
# ## Hopteam

# %%
ht = pd.read_csv('../data/hop_team/DocGraph_Hop_Teaming.csv', chunksize = 1000)
ht_chunk = next(ht)

# %%
ht_chunk
# Out:
#        from_npi      to_npi  patient_count  transaction_count  \
# 0    1508062167  1730166109            350                370
# 1    1508065640  1730166109             25                 25
# 2    1508052093  1730166109             16                 16
# 3    1508172545  1730166109             14                 14
# 4    1508285131  1730166109             20                 21
# ..          ...         ...            ...                ...
# 995  1508868506  1730177452             13                 13
# 996  1508864257  1730177452             17                 18
# 997  1508875980  1730177452             15                 16
# 998  1508870163  1730177478             18                 18
# 999  1508266347  1730177478             30                 34
#
#      average_day_wait  std_day_wait
# 0              53.922        72.612
# 1              49.800        55.006
# 2             109.500        70.593
# 3             103.357        75.483
# 4              89.952        89.880
# ..                ...           ...
# 995           131.154       118.476
# 996            61.222        53.114
# 997           107.500        80.602
# 998            68.667        53.639
# 999            49.088        48.754
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Create SQLite Database

# %% [markdown]
# ## Build and Insert nppes Table into Referral Database

# %%
# Save these column names for later
 profile_cols = ['NPI',
             'Entity Type Code',
             'Provider Organization Name (Legal Business Name)',
             'Provider Last Name (Legal Name)',
             'Provider First Name',
             'Provider Middle Name',
             'Provider Name Prefix Text',
             'Provider Name Suffix Text',
             'Provider Credential Text',
             'Provider First Line Business Practice Location Address',
             'Provider Second Line Business Practice Location Address',
             'Provider Business Practice Location Address City Name',
             'Provider Business Practice Location Address State Name',
             'Provider Business Practice Location Address Postal Code']

# Create the SQLite database
db = sqlite3.connect('data/hopteam.sqlite')    

# Chunk loop through npidata to build the nppes table in the hopteam database
for chunk in tqdm(pd.read_csv('../data/NPPES/npidata.csv', chunksize = 10000)):
  
    # Build the primary taxonomy table for this chunk
    taxes = chunk.filter(regex = '^NPI$|(Taxonomy (Code|Switch))')

    taxes_code_long = taxes.melt(id_vars = [col for col in taxes.columns if 'NPI' in col or 'Taxonomy Switch' in col],
               var_name = 'Taxonomy Code Number',
               value_name = 'Taxonomy Code'
              )
    taxes_long = taxes_code_long.melt(id_vars = [col for col in taxes_code_long.columns if 'NPI' in col or 'Taxonomy Code' in col],
                     var_name = 'Taxonomy Switch Number',
                     value_name = 'Taxonomy Switch'
                )

    taxes_long['Taxonomy Code Number'] = taxes_long['Taxonomy Code Number'].str.extract('(\d+)')
    taxes_long['Taxonomy Switch Number'] = taxes_long['Taxonomy Switch Number'].str.extract('(\d+)')

    primary_taxes = (taxes_long[(taxes_long['Taxonomy Code Number'] == taxes_long['Taxonomy Switch Number']) 
                    & 
                    (taxes_long['Taxonomy Switch'] == 'Y')]
                    .drop(columns = ['Taxonomy Code Number','Taxonomy Switch Number'])
                )
    
    # Build the profile table for this chunk
    
    profile = chunk.filter(items = profile_cols)
    
    # Merge profile and taxonomy tables to get
    
    nppes_chunk = pd.merge(profile, primary_taxes)
    
    # Append chunk to nppes table in hopteam database
    
    chunk.to_sql('nppes', db, if_exists = 'append', index = False)

# %% [markdown]
# # Insert hopteam Table into Referral Database

# %%
for chunk in tqdm(pd.read_csv('../data/hop_team/DocGraph_Hop_Teaming.csv', chunksize = 10000)):
    chunk.to_sql('hopteam', db, if_exists = 'append', index = False)

# %%
db.close()
