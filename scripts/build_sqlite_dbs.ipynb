# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import sqlite3

# %% [markdown]
# # Formulas

# %%
def zip_filler(x):
    try:
        if len(x) > 5:
            return x.zfill(9)[:5]
        elif len(x) > 0:
            return x.zfill(5)
    except:
        return np.nan

# %% [markdown]
# # Create SQLite DBs from Hopteam and NPPES

# %% [markdown]
# ## Taxonomy Detail

# %%
tax_detail = pd.read_csv('../data/NPPES/nucc_taxonomy_220.csv')
tax_detail
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 863  343800000X              Transportation Services
# 864  344600000X              Transportation Services
# 865  347D00000X              Transportation Services
# 866  347E00000X              Transportation Services
# 867  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# 3               Allergy & Immunology                           Allergy
# 4               Allergy & Immunology  Clinical & Laboratory Immunology
# ..                               ...                               ...
# 863  Secured Medical Transport (VAN)                               NaN
# 864                             Taxi                               NaN
# 865                            Train                               NaN
# 866            Transportation Broker                               NaN
# 867   Transportation Network Company                               NaN
#
#                                             Definition  \
# 0    A business group of one or more individual pra...
# 1    A business group of one or more individual pra...
# 2    An allergist-immunologist is trained in evalua...
# 3                                Definition to come...
# 4                                Definition to come...
# ..                                                 ...
# 863  A public or privately owned transportation ser...
# 864  A land commercial vehicle used for the transpo...
# 865  An organization or business licensed to provid...
# 866  An organization that provides transportation f...
# 867  A ride-sharing company that provides prearrang...
#
#                                                  Notes  \
# 0                                      [7/1/2003: new]
# 1                                      [7/1/2003: new]
# 2    Source: American Board of Medical Specialties,...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 863                                                NaN
# 864                                                NaN
# 865                                                NaN
# 866  Source: Section 6083 of the Deficit Reduction ...
# 867  Source:  National Uniform Claim Committee, www...
#
#                                           Display Name         Section
# 0                                Multi-Specialty Group      Individual
# 1                               Single Specialty Group      Individual
# 2                       Allergy & Immunology Physician      Individual
# 3                                    Allergy Physician      Individual
# 4    Clinical & Laboratory Immunology (Allergy & Im...      Individual
# ..                                                 ...             ...
# 863                    Secured Medical Transport (VAN)  Non-Individual
# 864                                               Taxi  Non-Individual
# 865                                              Train  Non-Individual
# 866                              Transportation Broker  Non-Individual
# 867                     Transportation Network Company  Non-Individual
#
# [868 rows x 8 columns]

# %% [markdown]
# ## npi
#     - 'NPI'
#     - 'Entity Type Code'
#     - 'Provider Organization Name (Legal Business Name)'
#     - 'Provider Last Name (Legal Name)'
#     - 'Provider First Name'
#     - 'Provider Middle Name'
#     - 'Provider Name Prefix Text'
#     - 'Provider Name Suffix Text'
#     - 'Provider Credential Text'
#     - 'Provider First Line Business Practice Location Address'
#     - 'Provider Second Line Business Practice Location Address'
#     - 'Provider Business Practice Location Address City Name'
#     - 'Provider Business Practice Location Address State Name'
#     - 'Provider Business Practice Location Address Postal Code'

# %%
npi = pd.read_csv('../data/NPPES/npidata.csv', chunksize = 1000)
npi_chunk1 = next(npi)

# %%
taxes = npi_chunk1.filter(regex = '^NPI$|(Taxonomy (Code|Switch))')

taxes_code_long = taxes.melt(id_vars = [col for col in taxes.columns if 'NPI' in col or 'Taxonomy Switch' in col],
           var_name = 'Taxonomy Code Number',
           value_name = 'Taxonomy Code'
          )
taxes_long = taxes_code_long.melt(id_vars = [col for col in taxes_code_long.columns if 'NPI' in col or 'Taxonomy Code' in col],
                 var_name = 'Taxonomy Switch Number',
                 value_name = 'Taxonomy Switch'
            )

taxes_long['Taxonomy Code Number'] = taxes_long['Taxonomy Code Number'].str.extract('(\d+)')
taxes_long['Taxonomy Switch Number'] = taxes_long['Taxonomy Switch Number'].str.extract('(\d+)')

primary_taxes = (taxes_long[(taxes_long['Taxonomy Code Number'] == taxes_long['Taxonomy Switch Number']) 
                & 
                (taxes_long['Taxonomy Switch'] == 'Y')]
                .drop(columns = ['Taxonomy Code Number','Taxonomy Switch Number'])
            )

primary_taxes
# Out:
#                NPI Taxonomy Code Taxonomy Switch
# 0       1679576722    207X00000X               Y
# 1       1588667638    207RC0000X               Y
# 2       1497758544    251G00000X               Y
# 5       1023011178    251G00000X               Y
# 7       1841293990    231H00000X               Y
# ...            ...           ...             ...
# 96426   1699778829    207X00000X               Y
# 112942  1811990047    333600000X               Y
# 128714  1164425336    3336H0001X               Y
# 128964  1619970845    3336H0001X               Y
# 192688  1215930490    207XX0005X               Y
#
# [932 rows x 3 columns]

# %%
 prof_cols = ['NPI',
                 'Entity Type Code',
                 'Provider Organization Name (Legal Business Name)',
                 'Provider Last Name (Legal Name)',
                 'Provider First Name',
                 'Provider Middle Name',
                 'Provider Name Prefix Text',
                 'Provider Name Suffix Text',
                 'Provider Credential Text',
                 'Provider First Line Business Practice Location Address',
                 'Provider Second Line Business Practice Location Address',
                 'Provider Business Practice Location Address City Name',
                 'Provider Business Practice Location Address State Name',
                 'Provider Business Practice Location Address Postal Code']
prof = npi_chunk1.filter(items = prof_cols)

# %%
prof['Provider Business Practice Location Address Postal Code'] = (prof['Provider Business Practice Location Address Postal Code']
                                                                      .astype(str)
                                                                      .str.replace('.0', '', regex = True)
                                                                      .apply(zip_filler)
                                                                     )
prof
# Out:
#             NPI  Entity Type Code  \
# 0    1679576722               1.0
# 1    1588667638               1.0
# 2    1497758544               2.0
# 3    1306849450               NaN
# 4    1215930367               1.0
# ..          ...               ...
# 995  1417950635               1.0
# 996  1326041542               1.0
# 997  1235132457               1.0
# 998  1144223363               1.0
# 999  1053314278               1.0
#
#     Provider Organization Name (Legal Business Name)  \
# 0                                                NaN
# 1                                                NaN
# 2             CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 995                                              NaN
# 996                                              NaN
# 997                                              NaN
# 998                                              NaN
# 999                                              NaN
#
#     Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                             WIEBE               DAVID                    A
# 1                           PILCHER             WILLIAM                    C
# 2                               NaN                 NaN                  NaN
# 3                               NaN                 NaN                  NaN
# 4                           GRESSOT             LAURENT                  NaN
# ..                              ...                 ...                  ...
# 995                          MARINO               CHRIS                    J
# 996                           TAFEL               ALLEN                    C
# 997                         ADAMSON               BRENT                    E
# 998                            KATZ                MARC                    A
# 999                            KUNS               BRETT                ROGER
#
#     Provider Name Prefix Text Provider Name Suffix Text  \
# 0                         NaN                       NaN
# 1                         DR.                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         DR.                       NaN
# ..                        ...                       ...
# 995                       DR.                       NaN
# 996                       DR.                       NaN
# 997                       NaN                       NaN
# 998                       DR.                       NaN
# 999                       DR.                       NaN
#
#     Provider Credential Text  \
# 0                       M.D.
# 1                         MD
# 2                        NaN
# 3                        NaN
# 4                       M.D.
# ..                       ...
# 995                     M.D.
# 996                     M.D.
# 997                     M.D.
# 998                      DPM
# 999                     D.O.
#
#     Provider First Line Business Practice Location Address  \
# 0                                     3500 CENTRAL AVE
# 1                                     1824 KING STREET
# 2                                      3418 VILLAGE DR
# 3                                                  NaN
# 4                                     17323 RED OAK DR
# ..                                                 ...
# 995                                 12670 WHITEHALL DR
# 996                                 2531 CLEVELAND AVE
# 997                                   3500 CENTRAL AVE
# 998                                   2919 W SWANN AVE
# 999                                101 S WASHINGTON ST
#
#     Provider Second Line Business Practice Location Address  \
# 0                                                  NaN
# 1                                            SUITE 300
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                              STE 1
# 997                                                NaN
# 998                                            STE 203
# 999                                                NaN
#
#     Provider Business Practice Location Address City Name  \
# 0                                              KEARNEY
# 1                                         JACKSONVILLE
# 2                                         FAYETTEVILLE
# 3                                                  NaN
# 4                                              HOUSTON
# ..                                                 ...
# 995                                         FORT MYERS
# 996                                           FT MYERS
# 997                                            KEARNEY
# 998                                              TAMPA
# 999                                           CASTALIA
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   NE
# 1                                                   FL
# 2                                                   NC
# 3                                                  NaN
# 4                                                   TX
# ..                                                 ...
# 995                                                 FL
# 996                                                 FL
# 997                                                 NE
# 998                                                 FL
# 999                                                 OH
#
#     Provider Business Practice Location Address Postal Code
# 0                                                68847
# 1                                                00324
# 2                                                00284
# 3                                                00nan
# 4                                                71243
# ..                                                 ...
# 995                                              00337
# 996                                              33140
# 997                                              68847
# 998                                              33938
# 999                                              44824
#
# [1000 rows x 14 columns]

# %%
# Save these cols for chunking later
npi_cols = prof.columns.tolist() + taxes.columns[1:].tolist()

# %%
profile_chunk = pd.merge(prof, primary_taxes)
profile_chunk.columns = [x.lower().replace(' ', '_') for x in profile_chunk.columns]
profile_chunk
# Out:
#             npi  entity_type_code  \
# 0    1679576722               1.0
# 1    1588667638               1.0
# 2    1497758544               2.0
# 3    1215930367               1.0
# 4    1023011178               2.0
# ..          ...               ...
# 927  1417950635               1.0
# 928  1326041542               1.0
# 929  1235132457               1.0
# 930  1144223363               1.0
# 931  1053314278               1.0
#
#     provider_organization_name_(legal_business_name)  \
# 0                                                NaN
# 1                                                NaN
# 2             CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                                NaN
# 4                                     COLLABRIA CARE
# ..                                               ...
# 927                                              NaN
# 928                                              NaN
# 929                                              NaN
# 930                                              NaN
# 931                                              NaN
#
#     provider_last_name_(legal_name) provider_first_name provider_middle_name  \
# 0                             WIEBE               DAVID                    A
# 1                           PILCHER             WILLIAM                    C
# 2                               NaN                 NaN                  NaN
# 3                           GRESSOT             LAURENT                  NaN
# 4                               NaN                 NaN                  NaN
# ..                              ...                 ...                  ...
# 927                          MARINO               CHRIS                    J
# 928                           TAFEL               ALLEN                    C
# 929                         ADAMSON               BRENT                    E
# 930                            KATZ                MARC                    A
# 931                            KUNS               BRETT                ROGER
#
#     provider_name_prefix_text provider_name_suffix_text  \
# 0                         NaN                       NaN
# 1                         DR.                       NaN
# 2                         NaN                       NaN
# 3                         DR.                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 927                       DR.                       NaN
# 928                       DR.                       NaN
# 929                       NaN                       NaN
# 930                       DR.                       NaN
# 931                       DR.                       NaN
#
#     provider_credential_text  \
# 0                       M.D.
# 1                         MD
# 2                        NaN
# 3                       M.D.
# 4                        NaN
# ..                       ...
# 927                     M.D.
# 928                     M.D.
# 929                     M.D.
# 930                      DPM
# 931                     D.O.
#
#     provider_first_line_business_practice_location_address  \
# 0                                     3500 CENTRAL AVE
# 1                                     1824 KING STREET
# 2                                      3418 VILLAGE DR
# 3                                     17323 RED OAK DR
# 4                                   414 S JEFFERSON ST
# ..                                                 ...
# 927                                 12670 WHITEHALL DR
# 928                                 2531 CLEVELAND AVE
# 929                                   3500 CENTRAL AVE
# 930                                   2919 W SWANN AVE
# 931                                101 S WASHINGTON ST
#
#     provider_second_line_business_practice_location_address  \
# 0                                                  NaN
# 1                                            SUITE 300
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 927                                                NaN
# 928                                              STE 1
# 929                                                NaN
# 930                                            STE 203
# 931                                                NaN
#
#     provider_business_practice_location_address_city_name  \
# 0                                              KEARNEY
# 1                                         JACKSONVILLE
# 2                                         FAYETTEVILLE
# 3                                              HOUSTON
# 4                                                 NAPA
# ..                                                 ...
# 927                                         FORT MYERS
# 928                                           FT MYERS
# 929                                            KEARNEY
# 930                                              TAMPA
# 931                                           CASTALIA
#
#     provider_business_practice_location_address_state_name  \
# 0                                                   NE
# 1                                                   FL
# 2                                                   NC
# 3                                                   TX
# 4                                                   CA
# ..                                                 ...
# 927                                                 FL
# 928                                                 FL
# 929                                                 NE
# 930                                                 FL
# 931                                                 OH
#
#     provider_business_practice_location_address_postal_code taxonomy_code  \
# 0                                                68847         207X00000X
# 1                                                00324         207RC0000X
# 2                                                00284         251G00000X
# 3                                                71243         207RH0003X
# 4                                                94559         251G00000X
# ..                                                 ...                ...
# 927                                              00337         2084N0400X
# 928                                              33140         2081P2900X
# 929                                              68847         207X00000X
# 930                                              33938         213E00000X
# 931                                              44824         207Q00000X
#
#     taxonomy_switch
# 0                 Y
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y
# ..              ...
# 927               Y
# 928               Y
# 929               Y
# 930               Y
# 931               Y
#
# [932 rows x 16 columns]

# %% [markdown]
# ## hopteam

# %%
ht = pd.read_csv('../data/hop_team/DocGraph_Hop_Teaming.csv', chunksize = 1000)
ht_chunk = next(ht)

# %%
ht_chunk
# Out:
#        from_npi      to_npi  patient_count  transaction_count  \
# 0    1508062167  1730166109            350                370
# 1    1508065640  1730166109             25                 25
# 2    1508052093  1730166109             16                 16
# 3    1508172545  1730166109             14                 14
# 4    1508285131  1730166109             20                 21
# ..          ...         ...            ...                ...
# 995  1508868506  1730177452             13                 13
# 996  1508864257  1730177452             17                 18
# 997  1508875980  1730177452             15                 16
# 998  1508870163  1730177478             18                 18
# 999  1508266347  1730177478             30                 34
#
#      average_day_wait  std_day_wait
# 0              53.922        72.612
# 1              49.800        55.006
# 2             109.500        70.593
# 3             103.357        75.483
# 4              89.952        89.880
# ..                ...           ...
# 995           131.154       118.476
# 996            61.222        53.114
# 997           107.500        80.602
# 998            68.667        53.639
# 999            49.088        48.754
#
# [1000 rows x 6 columns]

# %%
ht_chunk = ht_chunk.reset_index().rename(columns = {'index': 'referral_id'})
from_npi = ht_chunk[['referral_id', 'from_npi']]
to_npi = ht_chunk[['referral_id', 'to_npi']]
referrals = ht_chunk[['referral_id', 
                      'patient_count',
                      'transaction_count',
                      'average_day_wait',
                      'std_day_wait']]

# %%
referrals
# Out:
#      referral_id  patient_count  transaction_count  average_day_wait  \
# 0              0            350                370            53.922
# 1              1             25                 25            49.800
# 2              2             16                 16           109.500
# 3              3             14                 14           103.357
# 4              4             20                 21            89.952
# ..           ...            ...                ...               ...
# 995          995             13                 13           131.154
# 996          996             17                 18            61.222
# 997          997             15                 16           107.500
# 998          998             18                 18            68.667
# 999          999             30                 34            49.088
#
#      std_day_wait
# 0          72.612
# 1          55.006
# 2          70.593
# 3          75.483
# 4          89.880
# ..            ...
# 995       118.476
# 996        53.114
# 997        80.602
# 998        53.639
# 999        48.754
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## cbsa data

# %%
zip_cbsa = pd.read_excel('../data/NPPES/ZIP_CBSA_122021.xlsx')

# %%
zip_cbsa['zip'] = zip_cbsa['zip'].astype(str).str.zfill(5)
zip_cbsa['cbsa'] = zip_cbsa['cbsa'].astype(str).str.zfill(5)
zip_cbsa = zip_cbsa.rename(columns = {'usps_zip_pref_city': 'city',
                                      'usps_zip_pref_state': 'state'})

# %%
zip_cbsa
# Out:
#          zip   cbsa         city state  res_ratio  bus_ratio  oth_ratio  \
# 0      00683  41900   SAN GERMAN    PR   0.999842        1.0        1.0
# 1      00683  32420   SAN GERMAN    PR   0.000158        0.0        0.0
# 2      00923  41980     SAN JUAN    PR   1.000000        1.0        1.0
# 3      01010  44140    BRIMFIELD    MA   0.976896        1.0        1.0
# 4      01010  49340    BRIMFIELD    MA   0.023104        0.0        0.0
# ...      ...    ...          ...   ...        ...        ...        ...
# 47479  60684  16980      CHICAGO    IL   0.000000        1.0        0.0
# 47480  33945  15980     PINELAND    FL   0.000000        0.0        1.0
# 47481  78144  99999  PANNA MARIA    TX   0.000000        1.0        0.0
# 47482  12257  10580       ALBANY    NY   0.000000        1.0        0.0
# 47483  42061  32460        LOWES    KY   0.000000        0.0        1.0
#
#        tot_ratio
# 0       0.999855
# 1       0.000145
# 2       1.000000
# 3       0.977816
# 4       0.022184
# ...          ...
# 47479   1.000000
# 47480   1.000000
# 47481   1.000000
# 47482   1.000000
# 47483   1.000000
#
# [47484 rows x 8 columns]

# %% [markdown]
# # Create SQLite Database
#     - profile
#     - referral_from
#     - referral_to
#     - referral
#     - taxonomy
#     - zip_cbsa

# %% [markdown]
# ## Build and Insert profile Table into hopteam Database

# %%
# Save these column names for later
prof_cols = ['NPI',
             'Entity Type Code',
             'Provider Organization Name (Legal Business Name)',
             'Provider Last Name (Legal Name)',
             'Provider First Name',
             'Provider Middle Name',
             'Provider Name Prefix Text',
             'Provider Name Suffix Text',
             'Provider Credential Text',
             'Provider First Line Business Practice Location Address',
             'Provider Second Line Business Practice Location Address',
             'Provider Business Practice Location Address City Name',
             'Provider Business Practice Location Address State Name',
             'Provider Business Practice Location Address Postal Code']

# Create the SQLite database
db = sqlite3.connect('../data/hopteam.sqlite')    

# Chunk loop through npidata to build the nppes table in the hopteam database
for chunk in tqdm(pd.read_csv('../data/NPPES/npidata.csv', 
                              usecols = npi_cols,
                              dtype = {'Provider Business Practice Location Address Postal Code': str},
                              chunksize = 100000)):
  
    # Build the primary taxonomy table for this chunk
    taxes = chunk.filter(regex = '^NPI$|(Taxonomy (Code|Switch))')

    taxes_code_long = taxes.melt(id_vars = [col for col in taxes.columns if 'NPI' in col or 'Taxonomy Switch' in col],
               var_name = 'Taxonomy Code Number',
               value_name = 'Taxonomy Code'
              )
    taxes_long = taxes_code_long.melt(id_vars = [col for col in taxes_code_long.columns if 'NPI' in col or 'Taxonomy Code' in col],
                     var_name = 'Taxonomy Switch Number',
                     value_name = 'Taxonomy Switch'
                )

    taxes_long['Taxonomy Code Number'] = taxes_long['Taxonomy Code Number'].str.extract('(\d+)')
    taxes_long['Taxonomy Switch Number'] = taxes_long['Taxonomy Switch Number'].str.extract('(\d+)')

    primary_taxes = (taxes_long[(taxes_long['Taxonomy Code Number'] == taxes_long['Taxonomy Switch Number']) 
                    & 
                    (taxes_long['Taxonomy Switch'] == 'Y')]
                    .drop(columns = ['Taxonomy Code Number','Taxonomy Switch Number'])
                )
    
    # Build the profile table for this chunk
    
    prof = chunk.filter(items = prof_cols)
    prof['Provider Business Practice Location Address Postal Code'] = (prof['Provider Business Practice Location Address Postal Code']
                                                                      .apply(zip_filler)
                                                                     )
    
    # Merge profile and taxonomy tables to get
    
    profile_chunk = pd.merge(prof, primary_taxes)
    
    profile_chunk.columns = [x.lower().replace(' ', '_') for x in profile_chunk.columns]
    
    # Append chunk to nppes table in hopteam database
    
    profile_chunk.to_sql('profile', db, if_exists = 'append', index = False)
# Out:
# 0it [00:00, ?it/s]
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (71,74,75,78,79,82,83,86,87,90,91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (75,78,79,82,83,86,87,90,91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (87,90,91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (83,86,87,90,91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\jrior\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (67,70,71,74,75,78,79,82,83,86,87,90,91,94,95,98,99,102,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Build and Insert referral tables into hopteam Database

# %%
for chunk in tqdm(pd.read_csv('../data/hop_team/DocGraph_Hop_Teaming.csv', chunksize = 10000)):
    ht_chunk = chunk.reset_index().rename(columns = {'index': 'referral_id'})
    from_npi_chunk = ht_chunk[['referral_id', 'from_npi']]
    to_npi_chunk = ht_chunk[['referral_id', 'to_npi']]
    referrals_chunk = ht_chunk[['referral_id', 
                          'patient_count',
                          'transaction_count',
                          'average_day_wait',
                          'std_day_wait']]
    
    from_npi_chunk.to_sql('referral_from', db, if_exists = 'append', index = False)
    to_npi_chunk.to_sql('referral_to', db, if_exists = 'append', index = False)
    referrals_chunk.to_sql('referrals', db, if_exists = 'append', index = False)

# %%
tax_detail.to_sql('taxonomy', db, if_exists = 'append', index = False)
zip_cbsa.to_sql('zip_cbsa', db, if_exists = 'append', index = False)

# %%
db.close()
