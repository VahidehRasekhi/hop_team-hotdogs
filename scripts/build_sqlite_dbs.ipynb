# %% [markdown]
# # Imports

# %%
import pandas as pd
from tqdm.notebook import tqdm
import sqlite3

# %% [markdown]
# # Create SQLite DBs from Hopteam and NPPES

# %% [markdown]
# ## Explore NPPES CSVs

# %%
end = pd.read_csv('../data/NPPES/endpoint.csv', chunksize = 1000)
npi = pd.read_csv('../data/NPPES/npidata.csv', chunksize = 1000)
other = pd.read_csv('../data/NPPES/othername.csv', chunksize = 1000)
pl = pd.read_csv('../data/NPPES/pl.csv', chunksize = 1000)

# %%
for df in [end, npi, other, pl]:
    next(df)

# %% [markdown]
# ## endpoint

# %%
next(end).head()
# Out:
#              NPI Endpoint Type Endpoint Type Description  \
# 2000  1376548982        DIRECT  Direct Messaging Address
# 2001  1902801517        DIRECT  Direct Messaging Address
# 2002  1720083330       CONNECT               CONNECT URL
# 2003  1720083330       CONNECT               CONNECT URL
# 2004  1457356073        DIRECT  Direct Messaging Address
#
#                                            Endpoint Affiliation  \
# 2000        jmeans6748@phsdirect.pinnaclehealth.org           N
# 2001  jeffrey.norris.1@3326.direct.athenahealth.com           N
# 2002                       mcarim@cer.ecldirect.net           N
# 2003                       mcarim@cer.ecldirect.net           N
# 2004                       mroy294769@direct.sw.org           N
#
#      Endpoint Description Affiliation Legal Business Name Use Code  \
# 2000                  NaN                             NaN      NaN
# 2001           Athena EMR                             NaN      NaN
# 2002     Direct Messaging                             NaN      HIE
# 2003     Direct Messaging                             NaN    OTHER
# 2004                  NaN                             NaN   DIRECT
#
#                         Use Description Other Use Description Content Type  \
# 2000                                NaN                   NaN          NaN
# 2001                                NaN                   NaN          NaN
# 2002  Health Information Exchange (HIE)                   NaN          CSV
# 2003                              Other         CMS esMD eMDR          NaN
# 2004                             Direct                   NaN          NaN
#
#      Content Description Other Content Description  \
# 2000                 NaN                       NaN
# 2001                 NaN                       NaN
# 2002                 CSV                       NaN
# 2003                 NaN                       NaN
# 2004                 NaN                       NaN
#
#        Affiliation Address Line One Affiliation Address Line Two  \
# 2000     2201 Brunswick Dr Ste 1200                          NaN
# 2001         4300 W Main St Ste 405                          NaN
# 2002               2630 Westview Dr                          NaN
# 2003               2630 Westview Dr                          NaN
# 2004  10815 Ranch Road 2222 Bldg 3A                          NaN
#
#      Affiliation Address City Affiliation Address State  \
# 2000                  Hanover                        PA
# 2001                   Dothan                        AL
# 2002               Wyomissing                        PA
# 2003               Wyomissing                        PA
# 2004                   Austin                        TX
#
#      Affiliation Address Country  Affiliation Address Postal Code
# 2000                          US                      173318350.0
# 2001                          US                      363051086.0
# 2002                          US                      196101130.0
# 2003                          US                      196101130.0
# 2004                          US                      787301159.0

# %%
next(end).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 3000 to 3999
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   NPI                              1000 non-null   int64
#  1   Endpoint Type                    1000 non-null   object
#  2   Endpoint Type Description        1000 non-null   object
#  3   Endpoint                         999 non-null    object
#  4   Affiliation                      1000 non-null   object
#  5   Endpoint Description             265 non-null    object
#  6   Affiliation Legal Business Name  124 non-null    object
#  7   Use Code                         477 non-null    object
#  8   Use Description                  477 non-null    object
#  9   Other Use Description            33 non-null     object
#  10  Content Type                     262 non-null    object
#  11  Content Description              262 non-null    object
#  12  Other Content Description        187 non-null    object
#  13  Affiliation Address Line One     998 non-null    object
#  14  Affiliation Address Line Two     224 non-null    object
#  15  Affiliation Address City         998 non-null    object
#  16  Affiliation Address State        998 non-null    object
#  17  Affiliation Address Country      998 non-null    object
#  18  Affiliation Address Postal Code  998 non-null    float64
# dtypes: float64(1), int64(1), object(17)
# memory usage: 148.6+ KB

# %% [markdown]
# ## npi
#     - 'NPI'
#     - 'Entity Type Code'
#     - 'Provider Organization Name (Legal Business Name)'
#     - 'Provider Last Name (Legal Name)'
#     - 'Provider First Name'
#     - 'Provider Middle Name'
#     - 'Provider Name Prefix Text'
#     - 'Provider Name Suffix Text'
#     - 'Provider Credential Text'
#     - 'Provider First Line Business Practice Location Address'
#     - 'Provider Second Line Business Practice Location Address'
#     - 'Provider Business Practice Location Address City Name'
#     - 'Provider Business Practice Location Address State Name'
#     - 'Provider Business Practice Location Address Postal Code'

# %%
next(npi).head()
# Out:
#              NPI  Entity Type Code  Replacement NPI  \
# 1000  1962405183               1.0              NaN
# 1001  1871596098               1.0              NaN
# 1002  1780687905               1.0              NaN
# 1003  1598768715               1.0              NaN
# 1004  1407859622               1.0              NaN
#
#      Employer Identification Number (EIN)  \
# 1000                                  NaN
# 1001                                  NaN
# 1002                                  NaN
# 1003                                  NaN
# 1004                                  NaN
#
#      Provider Organization Name (Legal Business Name)  \
# 1000                                              NaN
# 1001                                              NaN
# 1002                                              NaN
# 1003                                              NaN
# 1004                                              NaN
#
#      Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 1000                             FOX              DANIEL                    R
# 1001                     DIAZ-LACAYO              MARVIN                  NaN
# 1002                            KIRK              ROBERT                    M
# 1003                           MOSCA              PHILIP                  NaN
# 1004                       MARKWARDT              GEORGE                  LEE
#
#      Provider Name Prefix Text Provider Name Suffix Text  ...  \
# 1000                       DR.                       NaN  ...
# 1001                       NaN                       NaN  ...
# 1002                       DR.                       NaN  ...
# 1003                       DR.                       NaN  ...
# 1004                       MR.                       NaN  ...
#
#      Healthcare Provider Taxonomy Group_7  \
# 1000                                  NaN
# 1001                                  NaN
# 1002                                  NaN
# 1003                                  NaN
# 1004                                  NaN
#
#      Healthcare Provider Taxonomy Group_8  \
# 1000                                  NaN
# 1001                                  NaN
# 1002                                  NaN
# 1003                                  NaN
# 1004                                  NaN
#
#       Healthcare Provider Taxonomy Group_9  \
# 1000                                   NaN
# 1001                                   NaN
# 1002                                   NaN
# 1003                                   NaN
# 1004                                   NaN
#
#      Healthcare Provider Taxonomy Group_10  \
# 1000                                   NaN
# 1001                                   NaN
# 1002                                   NaN
# 1003                                   NaN
# 1004                                   NaN
#
#      Healthcare Provider Taxonomy Group_11  \
# 1000                                   NaN
# 1001                                   NaN
# 1002                                   NaN
# 1003                                   NaN
# 1004                                   NaN
#
#      Healthcare Provider Taxonomy Group_12  \
# 1000                                   NaN
# 1001                                   NaN
# 1002                                   NaN
# 1003                                   NaN
# 1004                                   NaN
#
#      Healthcare Provider Taxonomy Group_13  \
# 1000                                   NaN
# 1001                                   NaN
# 1002                                   NaN
# 1003                                   NaN
# 1004                                   NaN
#
#       Healthcare Provider Taxonomy Group_14  \
# 1000                                    NaN
# 1001                                    NaN
# 1002                                    NaN
# 1003                                    NaN
# 1004                                    NaN
#
#      Healthcare Provider Taxonomy Group_15  Certification Date
# 1000                                   NaN          07/08/2020
# 1001                                   NaN                 NaN
# 1002                                   NaN                 NaN
# 1003                                   NaN                 NaN
# 1004                                   NaN                 NaN
#
# [5 rows x 330 columns]

# %%
next(npi).columns
[col for col in next(npi).columns if 'NPI' in col or 'Taxonomy' in col]
# Out:
# ['NPI',
#  'Replacement NPI',
#  'NPI Deactivation Reason Code',
#  'NPI Deactivation Date',
#  'NPI Reactivation Date',
#  'Healthcare Provider Taxonomy Code_1',
#  'Healthcare Provider Primary Taxonomy Switch_1',
#  'Healthcare Provider Taxonomy Code_2',
#  'Healthcare Provider Primary Taxonomy Switch_2',
#  'Healthcare Provider Taxonomy Code_3',
#  'Healthcare Provider Primary Taxonomy Switch_3',
#  'Healthcare Provider Taxonomy Code_4',
#  'Healthcare Provider Primary Taxonomy Switch_4',
#  'Healthcare Provider Taxonomy Code_5',
#  'Healthcare Provider Primary Taxonomy Switch_5',
#  'Healthcare Provider Taxonomy Code_6',
#  'Healthcare Provider Primary Taxonomy Switch_6',
#  'Healthcare Provider Taxonomy Code_7',
#  'Healthcare Provider Primary Taxonomy Switch_7',
#  'Healthcare Provider Taxonomy Code_8',
#  'Healthcare Provider Primary Taxonomy Switch_8',
#  'Healthcare Provider Taxonomy Code_9',
#  'Healthcare Provider Primary Taxonomy Switch_9',
#  'Healthcare Provider Taxonomy Code_10',
#  'Healthcare Provider Primary Taxonomy Switch_10',
#  'Healthcare Provider Taxonomy Code_11',
#  'Healthcare Provider Primary Taxonomy Switch_11',
#  'Healthcare Provider Taxonomy Code_12',
#  'Healthcare Provider Primary Taxonomy Switch_12',
#  'Healthcare Provider Taxonomy Code_13',
#  'Healthcare Provider Primary Taxonomy Switch_13',
#  'Healthcare Provider Taxonomy Code_14',
#  'Healthcare Provider Primary Taxonomy Switch_14',
#  'Healthcare Provider Taxonomy Code_15',
#  'Healthcare Provider Primary Taxonomy Switch_15',
#  'Healthcare Provider Taxonomy Group_1',
#  'Healthcare Provider Taxonomy Group_2',
#  'Healthcare Provider Taxonomy Group_3',
#  'Healthcare Provider Taxonomy Group_4',
#  'Healthcare Provider Taxonomy Group_5',
#  'Healthcare Provider Taxonomy Group_6',
#  'Healthcare Provider Taxonomy Group_7',
#  'Healthcare Provider Taxonomy Group_8',
#  'Healthcare Provider Taxonomy Group_9',
#  'Healthcare Provider Taxonomy Group_10',
#  'Healthcare Provider Taxonomy Group_11',
#  'Healthcare Provider Taxonomy Group_12',
#  'Healthcare Provider Taxonomy Group_13',
#  'Healthcare Provider Taxonomy Group_14',
#  'Healthcare Provider Taxonomy Group_15']

# %%
taxes = next(npi).filter(regex = 'NPI|(Taxonomy (Code|Switch))')

# %%
taxes
# Out:
#               NPI  Replacement NPI  NPI Deactivation Reason Code  \
# 14000  1154325199              NaN                           NaN
# 14001  1063416006              NaN                           NaN
# 14002  1972507911              NaN                           NaN
# 14003  1881698827              NaN                           NaN
# 14004  1699779637              NaN                           NaN
# ...           ...              ...                           ...
# 14995  1154325959              NaN                           NaN
# 14996  1063416865              NaN                           NaN
# 14997  1972507770              NaN                           NaN
# 14998  1881698686              NaN                           NaN
# 14999  1699779496              NaN                           NaN
#
#       NPI Deactivation Date NPI Reactivation Date  \
# 14000                   NaN                   NaN
# 14001                   NaN                   NaN
# 14002                   NaN                   NaN
# 14003            01/28/2022                   NaN
# 14004                   NaN                   NaN
# ...                     ...                   ...
# 14995                   NaN                   NaN
# 14996                   NaN                   NaN
# 14997                   NaN                   NaN
# 14998                   NaN                   NaN
# 14999                   NaN                   NaN
#
#       Healthcare Provider Taxonomy Code_1  \
# 14000                          333600000X
# 14001                          207N00000X
# 14002                          207VG0400X
# 14003                                 NaN
# 14004                          207RC0000X
# ...                                   ...
# 14995                          208VP0014X
# 14996                          163W00000X
# 14997                          164X00000X
# 14998                          207RP1001X
# 14999                          367500000X
#
#       Healthcare Provider Primary Taxonomy Switch_1  \
# 14000                                             N
# 14001                                             Y
# 14002                                             X
# 14003                                           NaN
# 14004                                             N
# ...                                             ...
# 14995                                             N
# 14996                                             N
# 14997                                             Y
# 14998                                             Y
# 14999                                             Y
#
#       Healthcare Provider Taxonomy Code_2  \
# 14000                          3336C0004X
# 14001                                 NaN
# 14002                          207VX0000X
# 14003                                 NaN
# 14004                          207RI0011X
# ...                                   ...
# 14995                          208VP0014X
# 14996                          363L00000X
# 14997                                 NaN
# 14998                                 NaN
# 14999                                 NaN
#
#       Healthcare Provider Primary Taxonomy Switch_2  \
# 14000                                             N
# 14001                                           NaN
# 14002                                             X
# 14003                                           NaN
# 14004                                             Y
# ...                                             ...
# 14995                                             N
# 14996                                             N
# 14997                                           NaN
# 14998                                           NaN
# 14999                                           NaN
#
#       Healthcare Provider Taxonomy Code_3  ...  \
# 14000                          3336C0003X  ...
# 14001                                 NaN  ...
# 14002                                 NaN  ...
# 14003                                 NaN  ...
# 14004                                 NaN  ...
# ...                                   ...  ...
# 14995                          208VP0014X  ...
# 14996                          363L00000X  ...
# 14997                                 NaN  ...
# 14998                                 NaN  ...
# 14999                                 NaN  ...
#
#       Healthcare Provider Taxonomy Code_11  \
# 14000                                  NaN
# 14001                                  NaN
# 14002                                  NaN
# 14003                                  NaN
# 14004                                  NaN
# ...                                    ...
# 14995                                  NaN
# 14996                                  NaN
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
#
#       Healthcare Provider Primary Taxonomy Switch_11  \
# 14000                                            NaN
# 14001                                            NaN
# 14002                                            NaN
# 14003                                            NaN
# 14004                                            NaN
# ...                                              ...
# 14995                                            NaN
# 14996                                            NaN
# 14997                                            NaN
# 14998                                            NaN
# 14999                                            NaN
#
#       Healthcare Provider Taxonomy Code_12  \
# 14000                                  NaN
# 14001                                  NaN
# 14002                                  NaN
# 14003                                  NaN
# 14004                                  NaN
# ...                                    ...
# 14995                                  NaN
# 14996                                  NaN
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
#
#       Healthcare Provider Primary Taxonomy Switch_12  \
# 14000                                            NaN
# 14001                                            NaN
# 14002                                            NaN
# 14003                                            NaN
# 14004                                            NaN
# ...                                              ...
# 14995                                            NaN
# 14996                                            NaN
# 14997                                            NaN
# 14998                                            NaN
# 14999                                            NaN
#
#       Healthcare Provider Taxonomy Code_13  \
# 14000                                  NaN
# 14001                                  NaN
# 14002                                  NaN
# 14003                                  NaN
# 14004                                  NaN
# ...                                    ...
# 14995                                  NaN
# 14996                                  NaN
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
#
#       Healthcare Provider Primary Taxonomy Switch_13  \
# 14000                                            NaN
# 14001                                            NaN
# 14002                                            NaN
# 14003                                            NaN
# 14004                                            NaN
# ...                                              ...
# 14995                                            NaN
# 14996                                            NaN
# 14997                                            NaN
# 14998                                            NaN
# 14999                                            NaN
#
#       Healthcare Provider Taxonomy Code_14  \
# 14000                                  NaN
# 14001                                  NaN
# 14002                                  NaN
# 14003                                  NaN
# 14004                                  NaN
# ...                                    ...
# 14995                                  NaN
# 14996                                  NaN
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
#
#       Healthcare Provider Primary Taxonomy Switch_14  \
# 14000                                            NaN
# 14001                                            NaN
# 14002                                            NaN
# 14003                                            NaN
# 14004                                            NaN
# ...                                              ...
# 14995                                            NaN
# 14996                                            NaN
# 14997                                            NaN
# 14998                                            NaN
# 14999                                            NaN
#
#       Healthcare Provider Taxonomy Code_15  \
# 14000                                  NaN
# 14001                                  NaN
# 14002                                  NaN
# 14003                                  NaN
# 14004                                  NaN
# ...                                    ...
# 14995                                  NaN
# 14996                                  NaN
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
#
#       Healthcare Provider Primary Taxonomy Switch_15
# 14000                                            NaN
# 14001                                            NaN
# 14002                                            NaN
# 14003                                            NaN
# 14004                                            NaN
# ...                                              ...
# 14995                                            NaN
# 14996                                            NaN
# 14997                                            NaN
# 14998                                            NaN
# 14999                                            NaN
#
# [1000 rows x 35 columns]

# %%
taxes.columns
# Out:
# Index(['NPI', 'Replacement NPI', 'NPI Deactivation Reason Code',
#        'NPI Deactivation Date', 'NPI Reactivation Date',
#        'Healthcare Provider Taxonomy Code_1',
#        'Healthcare Provider Primary Taxonomy Switch_1',
#        'Healthcare Provider Taxonomy Code_2',
#        'Healthcare Provider Primary Taxonomy Switch_2',
#        'Healthcare Provider Taxonomy Code_3',
#        'Healthcare Provider Primary Taxonomy Switch_3',
#        'Healthcare Provider Taxonomy Code_4',
#        'Healthcare Provider Primary Taxonomy Switch_4',
#        'Healthcare Provider Taxonomy Code_5',
#        'Healthcare Provider Primary Taxonomy Switch_5',
#        'Healthcare Provider Taxonomy Code_6',
#        'Healthcare Provider Primary Taxonomy Switch_6',
#        'Healthcare Provider Taxonomy Code_7',
#        'Healthcare Provider Primary Taxonomy Switch_7',
#        'Healthcare Provider Taxonomy Code_8',
#        'Healthcare Provider Primary Taxonomy Switch_8',
#        'Healthcare Provider Taxonomy Code_9',
#        'Healthcare Provider Primary Taxonomy Switch_9',
#        'Healthcare Provider Taxonomy Code_10',
#        'Healthcare Provider Primary Taxonomy Switch_10',
#        'Healthcare Provider Taxonomy Code_11',
#        'Healthcare Provider Primary Taxonomy Switch_11',
#        'Healthcare Provider Taxonomy Code_12',
#        'Healthcare Provider Primary Taxonomy Switch_12',
#        'Healthcare Provider Taxonomy Code_13',
#        'Healthcare Provider Primary Taxonomy Switch_13',
#        'Healthcare Provider Taxonomy Code_14',
#        'Healthcare Provider Primary Taxonomy Switch_14',
#        'Healthcare Provider Taxonomy Code_15',
#        'Healthcare Provider Primary Taxonomy Switch_15'],
#       dtype='object')

# %%
taxes_code_long = taxes.melt(id_vars = [col for col in taxes.columns if 'NPI' in col or 'Taxonomy Switch' in col],
           var_name = 'Taxonomy Code Number',
           value_name = 'Taxonomy Code'
          )
taxes_long = taxes_code_long.melt(id_vars = [col for col in taxes_code_long.columns if 'NPI' in col or 'Taxonomy Code' in col],
                 var_name = 'Taxonomy Switch Number',
                 value_name = 'Taxonomy Switch')

# %%
primary_taxes = (taxes_long.loc[taxes_long['Taxonomy Switch'] == 'Y']
                           .drop(columns = ['Taxonomy Code Number','Taxonomy Switch Number'])
                )

# %%
primary_taxes
# Out:
#                NPI  Replacement NPI  NPI Deactivation Reason Code  \
# 1       1063416006              NaN                           NaN
# 5       1508860545              NaN                           NaN
# 6       1417951450              NaN                           NaN
# 7       1326042367              NaN                           NaN
# 8       1235133273              NaN                           NaN
# ...            ...              ...                           ...
# 220797  1346244100              NaN                           NaN
# 221797  1346244100              NaN                           NaN
# 222797  1346244100              NaN                           NaN
# 223797  1346244100              NaN                           NaN
# 224797  1346244100              NaN                           NaN
#
#        NPI Deactivation Date NPI Reactivation Date Taxonomy Code  \
# 1                        NaN                   NaN    207N00000X
# 5                        NaN                   NaN    2085R0001X
# 6                        NaN                   NaN    207N00000X
# 7                        NaN                   NaN    225100000X
# 8                        NaN                   NaN    225100000X
# ...                      ...                   ...           ...
# 220797                   NaN                   NaN    208M00000X
# 221797                   NaN                   NaN    2084N0400X
# 222797                   NaN                   NaN    207RP1001X
# 223797                   NaN                   NaN    363A00000X
# 224797                   NaN                   NaN    207Q00000X
#
#        Taxonomy Switch
# 1                    Y
# 5                    Y
# 6                    Y
# 7                    Y
# 8                    Y
# ...                ...
# 220797               Y
# 221797               Y
# 222797               Y
# 223797               Y
# 224797               Y
#
# [13995 rows x 7 columns]
