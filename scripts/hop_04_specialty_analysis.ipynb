# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import re
import plotly.express as px
from jupyterthemes import jtplot
jtplot.style()

# %% [markdown]
# # Read in full_refs_hosp as refs

# %%
refs = pd.read_csv('../data/neo4j/full_refs_hosp.csv') 
refs.head()
# Out:
#      from_npi  referral_id  entity_type_code_provider                 name  \
# 0  1790730448     13418843                        1.0      STAFFORD, JAMES
# 1  1790762219     13418844                        1.0        GOODIN, ELLIS
# 2  1801017116     13418846                        1.0      STEWART, BRANDY
# 3  1811077712     17417315                        1.0  SHOEMAKER, BENJAMIN
# 4  1821060526     19402345                        1.0       WATERS, RONALD
#
#   taxonomy_code_provider classification_provider specialization_provider  \
# 0             2085R0202X               Radiology    Diagnostic Radiology
# 1             2085R0202X               Radiology    Diagnostic Radiology
# 2             363LF0000X      Nurse Practitioner                  Family
# 3             207Q00000X         Family Medicine                     NaN
# 4             2085R0202X               Radiology    Diagnostic Radiology
#
#    organization_provider   address_line1_provider address_line2_provider  ...  \
# 0                    NaN  210 25TH AVE N STE 1204                    NaN  ...
# 1                    NaN  210 25TH AVE N STE 1204                    NaN  ...
# 2                    NaN            313 N MAIN ST                    NaN  ...
# 3                    NaN            302 N MAIN ST                    NaN  ...
# 4                    NaN  210 25TH AVE N STE 1204                    NaN  ...
#
#   address_line1_hospital address_line2_hospital  city_hospital state_hospital  \
# 0          313 N MAIN ST                    NaN   ASHLAND CITY             TN
# 1          313 N MAIN ST                    NaN   ASHLAND CITY             TN
# 2          313 N MAIN ST                    NaN   ASHLAND CITY             TN
# 3          313 N MAIN ST                    NaN   ASHLAND CITY             TN
# 4          313 N MAIN ST                    NaN   ASHLAND CITY             TN
#
#    zip_hospital                       address_hospital patient_count  \
# 0         37015  313 N MAIN ST, ASHLAND CITY, TN 37015            65
# 1         37015  313 N MAIN ST, ASHLAND CITY, TN 37015            61
# 2         37015  313 N MAIN ST, ASHLAND CITY, TN 37015           104
# 3         37015  313 N MAIN ST, ASHLAND CITY, TN 37015            50
# 4         37015  313 N MAIN ST, ASHLAND CITY, TN 37015            62
#
#   transaction_count average_day_wait std_day_wait
# 0                67           24.552       50.253
# 1                63           17.238       35.569
# 2               186           19.129       51.613
# 3                90           17.611       47.253
# 4                66           12.697       29.350
#
# [5 rows x 30 columns]

# %% [markdown]
# # Summarize Vandy vs. not Vandy referrals

# %% [markdown]
# ## overview of top 20 taxonomies by referral patient count

# %%
(refs.groupby(['taxonomy_code_provider', 'classification_provider', 'specialization_provider'])
     ['patient_count']
     .sum()
     .sort_values(ascending = False)
     .nlargest(20)
)
# Out:
# taxonomy_code_provider  classification_provider  specialization_provider
# 2085R0202X              Radiology                Diagnostic Radiology                                448885
# 207RC0000X              Internal Medicine        Cardiovascular Disease                              154245
# 363LF0000X              Nurse Practitioner       Family                                               61071
# 207ZP0102X              Pathology                Anatomic Pathology & Clinical Pathology              57185
# 207RP1001X              Internal Medicine        Pulmonary Disease                                    36691
# 207RN0300X              Internal Medicine        Nephrology                                           33908
# 207RG0100X              Internal Medicine        Gastroenterology                                     27214
# 207RI0011X              Internal Medicine        Interventional Cardiology                            25750
# 363LA2100X              Nurse Practitioner       Acute Care                                           24698
# 2084N0400X              Psychiatry & Neurology   Neurology                                            22908
# 207RH0003X              Internal Medicine        Hematology & Oncology                                21400
# 207RC0001X              Internal Medicine        Clinical Cardiac Electrophysiology                   18227
# 207RX0202X              Internal Medicine        Medical Oncology                                     14317
# 2084P0800X              Psychiatry & Neurology   Psychiatry                                           11618
# 363LA2200X              Nurse Practitioner       Adult Health                                         11544
# 207RE0101X              Internal Medicine        Endocrinology, Diabetes & Metabolism                 11427
# 2086S0129X              Surgery                  Vascular Surgery                                     10859
# 207RA0001X              Internal Medicine        Advanced Heart Failure and Transplant Cardiology      9380
# 2085R0204X              Radiology                Vascular & Interventional Radiology                   9318
# 207RI0200X              Internal Medicine        Infectious Disease                                    9217
# Name: patient_count, dtype: int64

# %% [markdown]
# ## make a function to prepare a dataframe showing highest number of potential patients: make_not_to_vandy
# The output dataframe will also contain a useful column showing what percentage of patients are being referred somewhere other than Vanderbilt, which will help gauge growth potential.

# %%
def make_not_to_vandy(df, group):

    # create a column that labels whether the recommendation went to Vanderbilt or not
    df['to_vandy'] = df['organization_hospital'].str.contains("VANDERBILT")

    # for each specialty, determine the count of patients recommended to and not recommended to Vanderbilt
    to_vandy = (df.groupby(group + ['to_vandy'])
         ['patient_count']
         .sum()
         .reset_index()
    )

    # add a column for overall count of referrals by specialty, then determine proportion
    # of referrals to Vanderbilt vs proportion not to Vanderbilt
    to_vandy['patient_count_overall'] = (to_vandy.groupby(group)
                                     ['patient_count']
                                     .transform(sum)
                                    )
    to_vandy['patient_prop'] = (to_vandy['patient_count']/
                                     to_vandy['patient_count_overall']
                                    )

    # filter to focus just on referrals not to Vanderbilt
    not_to_vandy = to_vandy[to_vandy['to_vandy'] == False]
    
    return not_to_vandy.sort_values('patient_count', ascending = False)

# %% [markdown]
# ## results by classification and specialization

# %% [markdown]
# Far and away the most potential is in Diagnostic Radiology, where about 81.5% of patients are being referred somewhere other than Vanderbilt, comprising 365,807 potential patients.
#
# Note that Internal Medicine specializations comprise 12 of the top 25; however, the proportions of patients not going to Vanderbilt vary greatly by specialization, so our recommendation would be to focus on specific specializations and not just the Internal Medicine classification as a whole.
#
# The top 5 could reasonably be divided into four tiers; however, they still stand apart from the rest as specializations to target for volume.
#
#     - Radiology: Diagnostic Radiology
#     - Internal Medicine: Cardiovascular Disease
#     - Nurse Practitioner: Family
#     - Pathology: Anatomic Pathology & Clinical Pathology
#     - Internal Medicine: Pulmonary Disease

# %%
spec_not_to_vandy = make_not_to_vandy(refs, ['taxonomy_code_provider', 'classification_provider', 'specialization_provider'])

# get the top 25 potential patients to be gained
spec_not_to_vandy.nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider classification_provider  \
# 152             2085R0202X               Radiology
# 39              207RC0000X       Internal Medicine
# 195             363LF0000X      Nurse Practitioner
# 107             207ZP0102X               Pathology
# 65              207RP1001X       Internal Medicine
# 63              207RN0300X       Internal Medicine
# 59              207RI0011X       Internal Medicine
# 47              207RG0100X       Internal Medicine
# 41              207RC0001X       Internal Medicine
# 129             2084N0400X  Psychiatry & Neurology
# 55              207RH0003X       Internal Medicine
# 189             363LA2100X      Nurse Practitioner
# 72              207RX0202X       Internal Medicine
# 155             2085R0204X               Radiology
# 165             2086S0129X                 Surgery
# 134             2084P0800X  Psychiatry & Neurology
# 36              207RA0001X       Internal Medicine
# 185             363AM0700X     Physician Assistant
# 61              207RI0200X       Internal Medicine
# 22              207PE0004X      Emergency Medicine
# 45              207RE0101X       Internal Medicine
# 191             363LA2200X      Nurse Practitioner
# 177             213ES0103X              Podiatrist
# 15              207LC0200X          Anesthesiology
# 43              207RC0200X       Internal Medicine
#
#                               specialization_provider  to_vandy  \
# 152                              Diagnostic Radiology     False
# 39                             Cardiovascular Disease     False
# 195                                            Family     False
# 107           Anatomic Pathology & Clinical Pathology     False
# 65                                  Pulmonary Disease     False
# 63                                         Nephrology     False
# 59                          Interventional Cardiology     False
# 47                                   Gastroenterology     False
# 41                 Clinical Cardiac Electrophysiology     False
# 129                                         Neurology     False
# 55                              Hematology & Oncology     False
# 189                                        Acute Care     False
# 72                                   Medical Oncology     False
# 155               Vascular & Interventional Radiology     False
# 165                                  Vascular Surgery     False
# 134                                        Psychiatry     False
# 36   Advanced Heart Failure and Transplant Cardiology     False
# 185                                           Medical     False
# 61                                 Infectious Disease     False
# 22                         Emergency Medical Services     False
# 45               Endocrinology, Diabetes & Metabolism     False
# 191                                      Adult Health     False
# 177                              Foot & Ankle Surgery     False
# 15                             Critical Care Medicine     False
# 43                             Critical Care Medicine     False
#
#      patient_count  patient_count_overall  patient_prop
# 152         365807                 448885      0.814924
# 39           93743                 154245      0.607754
# 195          45689                  61071      0.748129
# 107          45602                  57185      0.797447
# 65           30967                  36691      0.843994
# 63           23863                  33908      0.703757
# 59           23259                  25750      0.903262
# 47           19345                  27214      0.710847
# 41           14947                  18227      0.820047
# 129          13275                  22908      0.579492
# 55           11741                  21400      0.548645
# 189          11015                  24698      0.445988
# 72            9030                  14317      0.630719
# 155           8024                   9318      0.861129
# 165           7869                  10859      0.724652
# 134           7055                  11618      0.607247
# 36            6299                   9380      0.671535
# 185           5749                   7111      0.808466
# 61            5640                   9217      0.611913
# 22            5447                   5728      0.950943
# 45            5071                  11427      0.443774
# 191           4957                  11544      0.429401
# 177           4022                   6432      0.625311
# 15            4008                   7206      0.556203
# 43            3647                   4005      0.910612

# %% [markdown]
# These results are not dramatically different, but this list is filtered to only include specializations referring to Vanderbilt for less than half the time.
#
# One specialization of interest that creeps into the top 25 is Emergency Medical Services. Here Vanderbilt is the referent less than 5% of the time.
#
# Vanderbilt is never referred to for Orthopedic Surgery of the Spine.

# %%
# to ensure there's room to grow, filter only to specialties where at least 50% of patients
# are being referred somewhere other than Vanderbilt
spec_not_to_vandy[spec_not_to_vandy['patient_prop'] >= 0.5].nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider classification_provider  \
# 152             2085R0202X               Radiology
# 39              207RC0000X       Internal Medicine
# 195             363LF0000X      Nurse Practitioner
# 107             207ZP0102X               Pathology
# 65              207RP1001X       Internal Medicine
# 63              207RN0300X       Internal Medicine
# 59              207RI0011X       Internal Medicine
# 47              207RG0100X       Internal Medicine
# 41              207RC0001X       Internal Medicine
# 129             2084N0400X  Psychiatry & Neurology
# 55              207RH0003X       Internal Medicine
# 72              207RX0202X       Internal Medicine
# 155             2085R0204X               Radiology
# 165             2086S0129X                 Surgery
# 134             2084P0800X  Psychiatry & Neurology
# 36              207RA0001X       Internal Medicine
# 185             363AM0700X     Physician Assistant
# 61              207RI0200X       Internal Medicine
# 22              207PE0004X      Emergency Medicine
# 177             213ES0103X              Podiatrist
# 15              207LC0200X          Anesthesiology
# 43              207RC0200X       Internal Medicine
# 187             363AS0400X     Physician Assistant
# 91              207XS0117X     Orthopaedic Surgery
# 150             2085R0001X               Radiology
#
#                               specialization_provider  to_vandy  \
# 152                              Diagnostic Radiology     False
# 39                             Cardiovascular Disease     False
# 195                                            Family     False
# 107           Anatomic Pathology & Clinical Pathology     False
# 65                                  Pulmonary Disease     False
# 63                                         Nephrology     False
# 59                          Interventional Cardiology     False
# 47                                   Gastroenterology     False
# 41                 Clinical Cardiac Electrophysiology     False
# 129                                         Neurology     False
# 55                              Hematology & Oncology     False
# 72                                   Medical Oncology     False
# 155               Vascular & Interventional Radiology     False
# 165                                  Vascular Surgery     False
# 134                                        Psychiatry     False
# 36   Advanced Heart Failure and Transplant Cardiology     False
# 185                                           Medical     False
# 61                                 Infectious Disease     False
# 22                         Emergency Medical Services     False
# 177                              Foot & Ankle Surgery     False
# 15                             Critical Care Medicine     False
# 43                             Critical Care Medicine     False
# 187                                          Surgical     False
# 91                   Orthopaedic Surgery of the Spine     False
# 150                                Radiation Oncology     False
#
#      patient_count  patient_count_overall  patient_prop
# 152         365807                 448885      0.814924
# 39           93743                 154245      0.607754
# 195          45689                  61071      0.748129
# 107          45602                  57185      0.797447
# 65           30967                  36691      0.843994
# 63           23863                  33908      0.703757
# 59           23259                  25750      0.903262
# 47           19345                  27214      0.710847
# 41           14947                  18227      0.820047
# 129          13275                  22908      0.579492
# 55           11741                  21400      0.548645
# 72            9030                  14317      0.630719
# 155           8024                   9318      0.861129
# 165           7869                  10859      0.724652
# 134           7055                  11618      0.607247
# 36            6299                   9380      0.671535
# 185           5749                   7111      0.808466
# 61            5640                   9217      0.611913
# 22            5447                   5728      0.950943
# 177           4022                   6432      0.625311
# 15            4008                   7206      0.556203
# 43            3647                   4005      0.910612
# 187           3319                   4074      0.814678
# 91            3139                   3139      1.000000
# 150           2340                   4615      0.507042

# %% [markdown]
# Here is an ordered list of all specializations for which Vanderbilt is never the referent.
#
# Orthodpedic Surgery of the Spine is in a class of its own with regard to patient count.

# %%
# look at all specialties where all patients are referred somewhere other than Vanderbilt
spec_not_to_vandy[spec_not_to_vandy['patient_prop'] == 1].nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider             classification_provider  \
# 91              207XS0117X                 Orthopaedic Surgery
# 144             2085D0003X                           Radiology
# 184             261QP2300X                       Clinic/Center
# 98              207YX0007X                      Otolaryngology
# 154             2085R0203X                           Radiology
# 212             364SW0102X           Clinical Nurse Specialist
# 160             2086S0105X                             Surgery
# 115             2080P0207X                          Pediatrics
# 85              207WX0200X                       Ophthalmology
# 24              207PP0204X                  Emergency Medicine
# 79              207VX0000X             Obstetrics & Gynecology
# 122             2083A0300X                 Preventive Medicine
# 119             2081P0301X  Physical Medicine & Rehabilitation
# 25              207QA0401X                     Family Medicine
# 12              163WG0600X                    Registered Nurse
# 8               111NS0005X                        Chiropractor
# 11              163WG0000X                    Registered Nurse
# 2               103TC1900X                        Psychologist
# 210             364SM0705X           Clinical Nurse Specialist
# 9               1223S0112X                             Dentist
#
#                            specialization_provider  to_vandy  patient_count  \
# 91                Orthopaedic Surgery of the Spine     False           3139
# 144                        Diagnostic Neuroimaging     False            497
# 184                                   Primary Care     False            311
# 98          Plastic Surgery within the Head & Neck     False            294
# 154                          Therapeutic Radiology     False            218
# 212                                 Women's Health     False            206
# 160                            Surgery of the Hand     False            194
# 115                  Pediatric Hematology-Oncology     False            139
# 85   Ophthalmic Plastic and Reconstructive Surgery     False            131
# 24                    Pediatric Emergency Medicine     False            107
# 79                                      Obstetrics     False             94
# 122                             Addiction Medicine     False             90
# 119                          Brain Injury Medicine     False             84
# 25                              Addiction Medicine     False             81
# 12                                     Gerontology     False             71
# 8                                 Sports Physician     False             65
# 11                                General Practice     False             60
# 2                                       Counseling     False             55
# 210                               Medical-Surgical     False             46
# 9                   Oral and Maxillofacial Surgery     False             38
#
#      patient_count_overall  patient_prop
# 91                    3139           1.0
# 144                    497           1.0
# 184                    311           1.0
# 98                     294           1.0
# 154                    218           1.0
# 212                    206           1.0
# 160                    194           1.0
# 115                    139           1.0
# 85                     131           1.0
# 24                     107           1.0
# 79                      94           1.0
# 122                     90           1.0
# 119                     84           1.0
# 25                      81           1.0
# 12                      71           1.0
# 8                       65           1.0
# 11                      60           1.0
# 2                       55           1.0
# 210                     46           1.0
# 9                       38           1.0

# %% [markdown]
# ## results by provider

# %% [markdown]
# Derek Welch, a pathologist who works for Tristar (HCA) is by far the provider with the most potential patients for Vanderbilt.
#
# With a nearly a third of the volume, the runner up is also an HCA doctor, John Riddick.
#
# Strikingly, the rest of the top 25 are Diagnostic Radiology doctors.

# %%
prov_not_to_vandy = make_not_to_vandy(refs, ['from_npi', 'name', 'classification_provider', 'specialization_provider'])
prov_not_to_vandy.nlargest(25, 'patient_count')
# Out:
#         from_npi                name classification_provider  \
# 238   1093753303        WELCH, DEREK               Pathology
# 1232  1417131715       RIDDICK, JOHN       Internal Medicine
# 120   1043232879    GORDON, JONATHAN               Radiology
# 2799  1912984758   LASSITER, GREGORY               Radiology
# 2654  1871548818      KLEIN, WILLIAM               Radiology
# 366   1134321235       PARIKH, VIRAJ               Radiology
# 901   1306993282      SHIPMAN, JASON               Radiology
# 1097  1376756742   GRIFFIN, BENJAMIN               Radiology
# 2517  1821060526      WATERS, RONALD               Radiology
# 1328  1447234141      CAPLAN, STUART               Radiology
# 1477  1487816948     PATTERSON, GARY               Radiology
# 2431  1790762219       GOODIN, ELLIS               Radiology
# 186   1073531042       GRIPPO, JAMES               Radiology
# 944   1326023789        MOYERS, JOHN               Radiology
# 2326  1760672026         HAQUE, AMER               Radiology
# 1674  1548467319    RISSING, MICHAEL               Radiology
# 2187  1710932017  HIMMELFARB, ELLIOT               Radiology
# 2419  1790730448     STAFFORD, JAMES               Radiology
# 2798  1912982513       FREEMAN, MARK               Radiology
# 2594  1851339634      HARNEY, IANTHA               Radiology
# 636   1215257670    HUTCHENS, ANDREW               Radiology
# 1635  1538216403     BERKLEY, NATHAN               Radiology
# 2100  1689617433       MASSIE, JAMES               Radiology
# 2877  1942254883     BURCHAM, ROBERT               Radiology
# 1170  1396721106       BERGER, BRIAN               Radiology
#
#                       specialization_provider  to_vandy  patient_count  \
# 238   Anatomic Pathology & Clinical Pathology     False          19165
# 1232                Interventional Cardiology     False           6360
# 120                      Diagnostic Radiology     False           5305
# 2799                     Diagnostic Radiology     False           5216
# 2654                     Diagnostic Radiology     False           5184
# 366                      Diagnostic Radiology     False           4914
# 901                      Diagnostic Radiology     False           4737
# 1097                     Diagnostic Radiology     False           4679
# 2517                     Diagnostic Radiology     False           4215
# 1328                     Diagnostic Radiology     False           4033
# 1477                     Diagnostic Radiology     False           3952
# 2431                     Diagnostic Radiology     False           3829
# 186                      Diagnostic Radiology     False           3824
# 944                      Diagnostic Radiology     False           3786
# 2326                     Diagnostic Radiology     False           3780
# 1674                     Diagnostic Radiology     False           3740
# 2187                     Diagnostic Radiology     False           3735
# 2419                     Diagnostic Radiology     False           3721
# 2798                     Diagnostic Radiology     False           3675
# 2594                     Diagnostic Radiology     False           3642
# 636                      Diagnostic Radiology     False           3634
# 1635                     Diagnostic Radiology     False           3633
# 2100                     Diagnostic Radiology     False           3573
# 2877                     Diagnostic Radiology     False           3551
# 1170                     Diagnostic Radiology     False           3551
#
#       patient_count_overall  patient_prop
# 238                   20018      0.957388
# 1232                   6360      1.000000
# 120                    5817      0.911982
# 2799                   5216      1.000000
# 2654                   5184      1.000000
# 366                    5063      0.970571
# 901                    4737      1.000000
# 1097                   4679      1.000000
# 2517                   4215      1.000000
# 1328                   4033      1.000000
# 1477                   3952      1.000000
# 2431                   3829      1.000000
# 186                    3824      1.000000
# 944                    3786      1.000000
# 2326                   4066      0.929661
# 1674                   3740      1.000000
# 2187                   3735      1.000000
# 2419                   3721      1.000000
# 2798                   3675      1.000000
# 2594                   3738      0.974318
# 636                    4112      0.883755
# 1635                   3633      1.000000
# 2100                   3573      1.000000
# 2877                   3701      0.959470
# 1170                   3551      1.000000

# %% [markdown]
# # Summarize specialty referrals by hospital
# Here we're asking similar questions to the ones investigated above, but instead of using the Vanderbilt/non-Vanderbilt binary, we're looking at specific hospitals (where address is used to distinguish between hospitals within an organization).

# %%
spec_to_hosp = (refs.groupby(['taxonomy_code_provider', 'classification_provider', 'specialization_provider', 'to_npi', 'organization_hospital', 'address_hospital'])
     ['patient_count']
     .sum()
     .sort_values(ascending = False)
     .reset_index()
)

spec_to_hosp
# Out:
#     taxonomy_code_provider  classification_provider  \
# 0               2085R0202X                Radiology
# 1               207RC0000X        Internal Medicine
# 2               2085R0202X                Radiology
# 3               2085R0202X                Radiology
# 4               2085R0202X                Radiology
# ..                     ...                      ...
# 933             207VX0201X  Obstetrics & Gynecology
# 934             2080P0210X               Pediatrics
# 935             207RR0500X        Internal Medicine
# 936             363LF0000X       Nurse Practitioner
# 937             103TC2200X             Psychologist
#
#          specialization_provider      to_npi  \
# 0           Diagnostic Radiology  1396882205
# 1         Cardiovascular Disease  1396882205
# 2           Diagnostic Radiology  1023055126
# 3           Diagnostic Radiology  1861479545
# 4           Diagnostic Radiology  1629025648
# ..                           ...         ...
# 933         Gynecologic Oncology  1538114434
# 934         Pediatric Nephrology  1396882205
# 935                 Rheumatology  1568551455
# 936                       Family  1568551455
# 937  Clinical Child & Adolescent  1558408633
#
#                       organization_hospital  \
# 0      VANDERBILT UNIVERSITY MEDICAL CENTER
# 1      VANDERBILT UNIVERSITY MEDICAL CENTER
# 2    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3                   MAURY REGIONAL HOSPITAL
# 4                SAINT THOMAS WEST HOSPITAL
# ..                                      ...
# 933     HENDERSONVILLE HOSPITAL CORPORATION
# 934    VANDERBILT UNIVERSITY MEDICAL CENTER
# 935              NASHVILLE GENERAL HOSPITAL
# 936              NASHVILLE GENERAL HOSPITAL
# 937    VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                                       address_hospital  patient_count
# 0       1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          71894
# 1       1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 2               2300 PATTERSON ST, NASHVILLE, TN 37203          42282
# 3                1224 TROTWOOD AVE, COLUMBIA, TN 38401          38907
# 4                 4220 HARDING RD, NASHVILLE, TN 37205          36715
# ..                                                 ...            ...
# 933  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...             21
# 934     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232             19
# 935  1818 ALBION ST, ATTN: MARTHA LAMPLEY, NASHVILL...             17
# 936  1818 ALBION ST, ATTN: MARTHA LAMPLEY, NASHVILL...             12
# 937               1601 23RD AVE S, NASHVILLE, TN 37212             12
#
# [938 rows x 7 columns]

# %% [markdown]
# As noted earlier, there's still a lot of ground to cover in Diagnostic Radiology. Probably the first new piece of information here is that Anatomic Pathology & Clinical Pathology is sending a lot of patients to Tristar Centennial.

# %%
spec_to_hosp.nlargest(20, 'patient_count')
# Out:
#    taxonomy_code_provider classification_provider  \
# 0              2085R0202X               Radiology
# 1              207RC0000X       Internal Medicine
# 2              2085R0202X               Radiology
# 3              2085R0202X               Radiology
# 4              2085R0202X               Radiology
# 5              2085R0202X               Radiology
# 6              2085R0202X               Radiology
# 7              2085R0202X               Radiology
# 8              2085R0202X               Radiology
# 9              2085R0202X               Radiology
# 10             207RC0000X       Internal Medicine
# 11             2085R0202X               Radiology
# 12             2085R0202X               Radiology
# 13             363LF0000X      Nurse Practitioner
# 14             207ZP0102X               Pathology
# 15             363LF0000X      Nurse Practitioner
# 16             363LA2100X      Nurse Practitioner
# 17             2085R0202X               Radiology
# 18             2085R0202X               Radiology
# 19             207RC0000X       Internal Medicine
#
#                     specialization_provider      to_npi  \
# 0                      Diagnostic Radiology  1396882205
# 1                    Cardiovascular Disease  1396882205
# 2                      Diagnostic Radiology  1023055126
# 3                      Diagnostic Radiology  1861479545
# 4                      Diagnostic Radiology  1629025648
# 5                      Diagnostic Radiology  1780778969
# 6                      Diagnostic Radiology  1982650024
# 7                      Diagnostic Radiology  1295780476
# 8                      Diagnostic Radiology  1164590386
# 9                      Diagnostic Radiology  1265445506
# 10                   Cardiovascular Disease  1629025648
# 11                     Diagnostic Radiology  1538114434
# 12                     Diagnostic Radiology  1871530832
# 13                                   Family  1396882205
# 14  Anatomic Pathology & Clinical Pathology  1023055126
# 15                                   Family  1861479545
# 16                               Acute Care  1396882205
# 17                     Diagnostic Radiology  1447571658
# 18                     Diagnostic Radiology  1497827364
# 19                   Cardiovascular Disease  1265445506
#
#                      organization_hospital  \
# 0     VANDERBILT UNIVERSITY MEDICAL CENTER
# 1     VANDERBILT UNIVERSITY MEDICAL CENTER
# 2   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3                  MAURY REGIONAL HOSPITAL
# 4               SAINT THOMAS WEST HOSPITAL
# 5               SAINT THOMAS WEST HOSPITAL
# 6   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 7        HTI MEMORIAL HOSPITAL CORPORATION
# 8         SAINT THOMAS RUTHERFORD HOSPITAL
# 9      WILLIAMSON COUNTY HOSPITAL DISTRICT
# 10              SAINT THOMAS WEST HOSPITAL
# 11     HENDERSONVILLE HOSPITAL CORPORATION
# 12  CENTRAL TENNESSEE HOSPITAL CORPORATION
# 13    VANDERBILT UNIVERSITY MEDICAL CENTER
# 14  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 15                 MAURY REGIONAL HOSPITAL
# 16    VANDERBILT UNIVERSITY MEDICAL CENTER
# 17      SUMNER REGIONAL MEDICAL CENTER LLC
# 18            MIDDLE TENNESSEE HOSPITALIST
# 19     WILLIAMSON COUNTY HOSPITAL DISTRICT
#
#                                      address_hospital  patient_count
# 0      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          71894
# 1      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 2              2300 PATTERSON ST, NASHVILLE, TN 37203          42282
# 3               1224 TROTWOOD AVE, COLUMBIA, TN 38401          38907
# 4                4220 HARDING RD, NASHVILLE, TN 37205          36715
# 5                 2000 CHURCH ST, NASHVILLE, TN 37236          28344
# 6                5655 FRIST BLVD, HERMITAGE, TN 37076          27590
# 7            3441 DICKERSON PIKE, NASHVILLE, TN 37207          27111
# 8    1700 MEDICAL CENTER PKWY, MURFREESBORO, TN 37129          21610
# 9          4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          20038
# 10               4220 HARDING RD, NASHVILLE, TN 37205          16639
# 11  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...          15831
# 12                111 HIGHWAY 70 E, DICKSON, TN 37055          13837
# 13     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13725
# 14             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 15              1224 TROTWOOD AVE, COLUMBIA, TN 38401          13527
# 16     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13294
# 17            555 HARTSVILLE PIKE, GALLATIN, TN 37066          13191
# 18  3443 DICKERSON PK, SUITE 680, NASHVILLE, TN 37207          12871
# 19         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258

# %% [markdown]
# We already knew Diagnostic Radiology is a point of focus. Looking beyond that Cardiovascular Disease, Family medicine, and Anatomic Pathology & Clinical Pathology come into focus.

# %%
spec_to_hosp[spec_to_hosp['specialization_provider'] != 'Diagnostic Radiology'].nlargest(20, 'patient_count')
# Out:
#    taxonomy_code_provider classification_provider  \
# 1              207RC0000X       Internal Medicine
# 10             207RC0000X       Internal Medicine
# 13             363LF0000X      Nurse Practitioner
# 14             207ZP0102X               Pathology
# 15             363LF0000X      Nurse Practitioner
# 16             363LA2100X      Nurse Practitioner
# 19             207RC0000X       Internal Medicine
# 21             207ZP0102X               Pathology
# 25             207RI0011X       Internal Medicine
# 26             207RH0003X       Internal Medicine
# 27             207RN0300X       Internal Medicine
# 28             2084N0400X  Psychiatry & Neurology
# 30             207RC0000X       Internal Medicine
# 31             207RG0100X       Internal Medicine
# 32             207RC0000X       Internal Medicine
# 33             207RE0101X       Internal Medicine
# 34             363LA2200X      Nurse Practitioner
# 35             207RC0000X       Internal Medicine
# 36             207RC0000X       Internal Medicine
# 37             207ZP0102X               Pathology
#
#                     specialization_provider      to_npi  \
# 1                    Cardiovascular Disease  1396882205
# 10                   Cardiovascular Disease  1629025648
# 13                                   Family  1396882205
# 14  Anatomic Pathology & Clinical Pathology  1023055126
# 15                                   Family  1861479545
# 16                               Acute Care  1396882205
# 19                   Cardiovascular Disease  1265445506
# 21  Anatomic Pathology & Clinical Pathology  1396882205
# 25                Interventional Cardiology  1023055126
# 26                    Hematology & Oncology  1396882205
# 27                               Nephrology  1396882205
# 28                                Neurology  1396882205
# 30                   Cardiovascular Disease  1023055126
# 31                         Gastroenterology  1396882205
# 32                   Cardiovascular Disease  1861479545
# 33     Endocrinology, Diabetes & Metabolism  1396882205
# 34                             Adult Health  1396882205
# 35                   Cardiovascular Disease  1538114434
# 36                   Cardiovascular Disease  1447571658
# 37  Anatomic Pathology & Clinical Pathology  1780778969
#
#                      organization_hospital  \
# 1     VANDERBILT UNIVERSITY MEDICAL CENTER
# 10              SAINT THOMAS WEST HOSPITAL
# 13    VANDERBILT UNIVERSITY MEDICAL CENTER
# 14  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 15                 MAURY REGIONAL HOSPITAL
# 16    VANDERBILT UNIVERSITY MEDICAL CENTER
# 19     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 21    VANDERBILT UNIVERSITY MEDICAL CENTER
# 25  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 26    VANDERBILT UNIVERSITY MEDICAL CENTER
# 27    VANDERBILT UNIVERSITY MEDICAL CENTER
# 28    VANDERBILT UNIVERSITY MEDICAL CENTER
# 30  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 31    VANDERBILT UNIVERSITY MEDICAL CENTER
# 32                 MAURY REGIONAL HOSPITAL
# 33    VANDERBILT UNIVERSITY MEDICAL CENTER
# 34    VANDERBILT UNIVERSITY MEDICAL CENTER
# 35     HENDERSONVILLE HOSPITAL CORPORATION
# 36      SUMNER REGIONAL MEDICAL CENTER LLC
# 37              SAINT THOMAS WEST HOSPITAL
#
#                                      address_hospital  patient_count
# 1      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 10               4220 HARDING RD, NASHVILLE, TN 37205          16639
# 13     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13725
# 14             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 15              1224 TROTWOOD AVE, COLUMBIA, TN 38401          13527
# 16     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13294
# 19         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258
# 21     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          10145
# 25             2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# 26     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9659
# 27     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9432
# 28     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9113
# 30             2300 PATTERSON ST, NASHVILLE, TN 37203           7902
# 31     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           7615
# 32              1224 TROTWOOD AVE, COLUMBIA, TN 38401           7212
# 33     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           6356
# 34     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           6305
# 35  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...           6270
# 36            555 HARTSVILLE PIKE, GALLATIN, TN 37066           6170
# 37                2000 CHURCH ST, NASHVILLE, TN 37236           5882

# %%
(spec_to_hosp[(spec_to_hosp['specialization_provider'] != 'Diagnostic Radiology')
             &
             (spec_to_hosp['organization_hospital'] != 'VANDERBILT UNIVERSITY MEDICAL CENTER')]
             .nlargest(20, 'patient_count')
)
# Out:
#    taxonomy_code_provider classification_provider  \
# 10             207RC0000X       Internal Medicine
# 14             207ZP0102X               Pathology
# 15             363LF0000X      Nurse Practitioner
# 19             207RC0000X       Internal Medicine
# 25             207RI0011X       Internal Medicine
# 30             207RC0000X       Internal Medicine
# 32             207RC0000X       Internal Medicine
# 35             207RC0000X       Internal Medicine
# 36             207RC0000X       Internal Medicine
# 37             207ZP0102X               Pathology
# 38             207RC0000X       Internal Medicine
# 42             207RC0000X       Internal Medicine
# 43             207ZP0102X               Pathology
# 45             207RC0000X       Internal Medicine
# 47             207RP1001X       Internal Medicine
# 48             207RC0000X       Internal Medicine
# 51             363LA2100X      Nurse Practitioner
# 52             207RN0300X       Internal Medicine
# 53             207RP1001X       Internal Medicine
# 54             207RG0100X       Internal Medicine
#
#                     specialization_provider      to_npi  \
# 10                   Cardiovascular Disease  1629025648
# 14  Anatomic Pathology & Clinical Pathology  1023055126
# 15                                   Family  1861479545
# 19                   Cardiovascular Disease  1265445506
# 25                Interventional Cardiology  1023055126
# 30                   Cardiovascular Disease  1023055126
# 32                   Cardiovascular Disease  1861479545
# 35                   Cardiovascular Disease  1538114434
# 36                   Cardiovascular Disease  1447571658
# 37  Anatomic Pathology & Clinical Pathology  1780778969
# 38                   Cardiovascular Disease  1780778969
# 42                   Cardiovascular Disease  1164590386
# 43  Anatomic Pathology & Clinical Pathology  1629025648
# 45                   Cardiovascular Disease  1982650024
# 47                        Pulmonary Disease  1780778969
# 48                   Cardiovascular Disease  1295780476
# 51                               Acute Care  1629025648
# 52                               Nephrology  1023055126
# 53                        Pulmonary Disease  1629025648
# 54                         Gastroenterology  1861479545
#
#                      organization_hospital  \
# 10              SAINT THOMAS WEST HOSPITAL
# 14  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 15                 MAURY REGIONAL HOSPITAL
# 19     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 25  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 30  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 32                 MAURY REGIONAL HOSPITAL
# 35     HENDERSONVILLE HOSPITAL CORPORATION
# 36      SUMNER REGIONAL MEDICAL CENTER LLC
# 37              SAINT THOMAS WEST HOSPITAL
# 38              SAINT THOMAS WEST HOSPITAL
# 42        SAINT THOMAS RUTHERFORD HOSPITAL
# 43              SAINT THOMAS WEST HOSPITAL
# 45  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 47              SAINT THOMAS WEST HOSPITAL
# 48       HTI MEMORIAL HOSPITAL CORPORATION
# 51              SAINT THOMAS WEST HOSPITAL
# 52  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 53              SAINT THOMAS WEST HOSPITAL
# 54                 MAURY REGIONAL HOSPITAL
#
#                                      address_hospital  patient_count
# 10               4220 HARDING RD, NASHVILLE, TN 37205          16639
# 14             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 15              1224 TROTWOOD AVE, COLUMBIA, TN 38401          13527
# 19         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258
# 25             2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# 30             2300 PATTERSON ST, NASHVILLE, TN 37203           7902
# 32              1224 TROTWOOD AVE, COLUMBIA, TN 38401           7212
# 35  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...           6270
# 36            555 HARTSVILLE PIKE, GALLATIN, TN 37066           6170
# 37                2000 CHURCH ST, NASHVILLE, TN 37236           5882
# 38                2000 CHURCH ST, NASHVILLE, TN 37236           5571
# 42   1700 MEDICAL CENTER PKWY, MURFREESBORO, TN 37129           5140
# 43               4220 HARDING RD, NASHVILLE, TN 37205           5012
# 45               5655 FRIST BLVD, HERMITAGE, TN 37076           4925
# 47                2000 CHURCH ST, NASHVILLE, TN 37236           4585
# 48           3441 DICKERSON PIKE, NASHVILLE, TN 37207           4166
# 51               4220 HARDING RD, NASHVILLE, TN 37205           3715
# 52             2300 PATTERSON ST, NASHVILLE, TN 37203           3692
# 53               4220 HARDING RD, NASHVILLE, TN 37205           3545
# 54              1224 TROTWOOD AVE, COLUMBIA, TN 38401           3505

# %% [markdown]
# # Summarize top potential patient referrer for each specialty
# A lot of these are people 100% referring away from Vanderbilt. The top referrer, ALBERTO GONZALEZ-BERNAL, is Tristar affiliated (per Google search).
#
# Follow-up question related to this: Are providers who 100% refer outside of Vanderbilt realistic targets for patient transfer, or do those numbers suggest an affiliation that can't be overcome? Are we mostly interested in providers who do not have an affiliation. Specifically, should Vanderbilt try to recruit providers whose proportion of patients not sent to Vanderbilt is _NOT_ significantly high or low?

# %%
prosp_prov_npi = (prov_not_to_vandy.groupby(['classification_provider', 'specialization_provider'])
                  .max('patient_count')
                  .sort_values('patient_count', ascending = False)
                  .reset_index()
                )
prosp_prov_by_spec = prosp_prov_npi.merge(prov_not_to_vandy)

prosp_prov_by_spec
# Out:
#                classification_provider  \
# 0                    Internal Medicine
# 1                            Pathology
# 2                       Anesthesiology
# 3                            Pathology
# 4                            Radiology
# 5               Psychiatry & Neurology
# 6                    Internal Medicine
# 7            Clinical Nurse Specialist
# 8                        Clinic/Center
# 9                       Otolaryngology
# 10                Allergy & Immunology
# 11                           Radiology
# 12                           Pathology
# 13                             Surgery
# 14                             Surgery
# 15                     Family Medicine
# 16                 Orthopaedic Surgery
# 17           Clinical Nurse Specialist
# 18                      Otolaryngology
# 19                          Podiatrist
# 20              Psychiatry & Neurology
# 21                          Pediatrics
# 22                   Internal Medicine
# 23                        Psychologist
# 24                             Urology
# 25                  Emergency Medicine
# 26                 Preventive Medicine
# 27  Physical Medicine & Rehabilitation
# 28                     Family Medicine
# 29                          Pediatrics
# 30                  Nurse Practitioner
# 31                    Registered Nurse
# 32                        Chiropractor
# 33                          Pediatrics
# 34                           Radiology
# 35                    Registered Nurse
# 36                        Psychologist
# 37                           Radiology
# 38              Psychiatry & Neurology
# 39                  Physical Therapist
# 40           Clinical Nurse Specialist
# 41                 Preventive Medicine
# 42                             Dentist
# 43                     Family Medicine
# 44                        Psychologist
#
#                               specialization_provider    from_npi  to_vandy  \
# 0                              Critical Care Medicine  1952415499     False
# 1                                       Cytopathology  1780687830     False
# 2                              Critical Care Medicine  1902049893     False
# 3              Clinical Pathology/Laboratory Medicine  1023078243     False
# 4                             Diagnostic Neuroimaging  1578772570     False
# 5                                  Vascular Neurology  1033179858     False
# 6                                      Sleep Medicine  1467456228     False
# 7                                       Family Health  1376777508     False
# 8                                        Primary Care  1295170025     False
# 9              Plastic Surgery within the Head & Neck  1821068040     False
# 10                                            Allergy  1417085606     False
# 11                              Therapeutic Radiology  1003905969     False
# 12                                         Hematology  1003871815     False
# 13                                Surgery of the Hand  1912999863     False
# 14                 Plastic and Reconstructive Surgery  1841406063     False
# 15                    Hospice and Palliative Medicine  1205978152     False
# 16                             Foot and Ankle Surgery  1386848869     False
# 17                                         Acute Care  1447794755     False
# 18                              Otology & Neurotology  1629050372     False
# 19                                       Foot Surgery  1306825211     False
# 20                             Neuromuscular Medicine  1568501005     False
# 21                      Pediatric Hematology-Oncology  1003173592     False
# 22                                         Hematology  1588621031     False
# 23                                           Clinical  1659541969     False
# 24  Female Pelvic Medicine and Reconstructive Surgery  1952388977     False
# 25                       Pediatric Emergency Medicine  1457351165     False
# 26                                 Addiction Medicine  1497970636     False
# 27                              Brain Injury Medicine  1902127582     False
# 28                                 Addiction Medicine  1033343728     False
# 29                               Pediatric Cardiology  1417004136     False
# 30                             Critical Care Medicine  1871887463     False
# 31                                        Gerontology  1588861207     False
# 32                                   Sports Physician  1942306253     False
# 33                                    Sports Medicine  1215105895     False
# 34                                Pediatric Radiology  1376630475     False
# 35                                   General Practice  1841278546     False
# 36                                         Counseling  1639435159     False
# 37                              Diagnostic Ultrasound  1922155894     False
# 38                                     Sleep Medicine  1154303592     False
# 39                                         Orthopedic  1629320130     False
# 40                                   Medical-Surgical  1144412958     False
# 41                              Occupational Medicine  1235137183     False
# 42                     Oral and Maxillofacial Surgery  1013054113     False
# 43                                    Sports Medicine  1033316484     False
# 44                        Clinical Child & Adolescent  1407050180     False
#
#     patient_count  patient_count_overall  patient_prop  \
# 0            1511                   1511      1.000000
# 1            1033                   1180      0.875424
# 2             817                    817      1.000000
# 3             626                    626      1.000000
# 4             497                    497      1.000000
# 5             489                    489      1.000000
# 6             432                    432      1.000000
# 7             333                    333      1.000000
# 8             311                    311      1.000000
# 9             294                    294      1.000000
# 10            226                    226      1.000000
# 11            218                    218      1.000000
# 12            213                    213      1.000000
# 13            194                    194      1.000000
# 14            193                    193      1.000000
# 15            189                    189      1.000000
# 16            173                    173      1.000000
# 17            166                    166      1.000000
# 18            155                    155      1.000000
# 19            147                    189      0.777778
# 20            145                    145      1.000000
# 21            139                    139      1.000000
# 22            135                    135      1.000000
# 23            128                    128      1.000000
# 24            117                    212      0.551887
# 25            107                    107      1.000000
# 26             90                     90      1.000000
# 27             84                     84      1.000000
# 28             81                     81      1.000000
# 29             76                     76      1.000000
# 30             73                     73      1.000000
# 31             71                     71      1.000000
# 32             65                     65      1.000000
# 33             61                    169      0.360947
# 34             61                   1044      0.058429
# 35             60                     60      1.000000
# 36             55                     55      1.000000
# 37             53                     53      1.000000
# 38             48                    396      0.121212
# 39             47                     47      1.000000
# 40             46                     46      1.000000
# 41             41                    642      0.063863
# 42             38                     38      1.000000
# 43             38                     38      1.000000
# 44             36                     36      1.000000
#
#                         name
# 0   GONZALEZ-BERNAL, ALBERTO
# 1                 MANI, VENK
# 2       CROPSEY, CHRISTOPHER
# 3        MICHAELSON, RICHARD
# 4           EMMANUEL, MILROY
# 5         SENGSTOCK, GREGORY
# 6                JOHN, BIJOY
# 7             WRIGHT, EVELYN
# 8           ANIKWE, FREDRICK
# 9           STEWART, WILLIAM
# 10            SULLIVAN, RYAN
# 11          ROSENBLATT, PAUL
# 12           KINGMA, DOUGLAS
# 13          STAELIN, STEPHEN
# 14             GARZA, ROBERT
# 15        STEUART, CATHERINE
# 16             CORN, WILLIAM
# 17            MEEKS, MELYNDA
# 18        SCHWABER, MITCHELL
# 19                 RETIEF, I
# 20                LE, CHUONG
# 21                HSU, PETER
# 22           BACHIER, CARLOS
# 23           VICTORY, ALICIA
# 24               ABEL, MARCY
# 25             SLOAS, HAROLD
# 26               ELKIN, CHAD
# 27            MEHTA, SRAVANI
# 28         COLLINS, KIMBERLY
# 29                CLAY, MARK
# 30            BENNETT, KATHY
# 31           EUBANK, ABIGAIL
# 32         MCKINLEY, JEFFREY
# 33               SCOTT, LEON
# 34         WUSHENSKY, CURTIS
# 35              KING, KRISTY
# 36           SLATTEN, MARSHA
# 37              BIRCHER, ANA
# 38            UPENDER, RAGHU
# 39            LAY, NATHANIEL
# 40      EVANGELIST, JENNIFER
# 41           SINGH, NARENDRA
# 42             PRESS, STEVEN
# 43          KINDRED, JEFFRIE
# 44           SANGER, MAUREEN

# %% [markdown]
# # Test to see if affiliations table is useful for our data
# It is not. Most NPIs do not have an affiliation response, and the ones that do have a response tend not to say no affiliation.

# %%
query = """

SELECT *
FROM affiliations;

"""

with sqlite3.connect('../data/hopteam.sqlite') as db:
    affiliations = pd.read_sql(query, db)

# %%
prosp_prov_by_spec.merge(affiliations, how = 'left', left_on = 'from_npi', right_on = 'npi')
# Out:
#                classification_provider  \
# 0                    Internal Medicine
# 1                            Pathology
# 2                       Anesthesiology
# 3                            Pathology
# 4                            Radiology
# 5               Psychiatry & Neurology
# 6                    Internal Medicine
# 7            Clinical Nurse Specialist
# 8                        Clinic/Center
# 9                       Otolaryngology
# 10                Allergy & Immunology
# 11                           Radiology
# 12                           Pathology
# 13                             Surgery
# 14                             Surgery
# 15                     Family Medicine
# 16                 Orthopaedic Surgery
# 17           Clinical Nurse Specialist
# 18                      Otolaryngology
# 19                          Podiatrist
# 20              Psychiatry & Neurology
# 21                          Pediatrics
# 22                   Internal Medicine
# 23                        Psychologist
# 24                             Urology
# 25                  Emergency Medicine
# 26                 Preventive Medicine
# 27  Physical Medicine & Rehabilitation
# 28                     Family Medicine
# 29                          Pediatrics
# 30                  Nurse Practitioner
# 31                    Registered Nurse
# 32                        Chiropractor
# 33                          Pediatrics
# 34                           Radiology
# 35                    Registered Nurse
# 36                        Psychologist
# 37                           Radiology
# 38              Psychiatry & Neurology
# 39                  Physical Therapist
# 40           Clinical Nurse Specialist
# 41                 Preventive Medicine
# 42                             Dentist
# 43                     Family Medicine
# 44                        Psychologist
#
#                               specialization_provider    from_npi  to_vandy  \
# 0                              Critical Care Medicine  1952415499     False
# 1                                       Cytopathology  1780687830     False
# 2                              Critical Care Medicine  1902049893     False
# 3              Clinical Pathology/Laboratory Medicine  1023078243     False
# 4                             Diagnostic Neuroimaging  1578772570     False
# 5                                  Vascular Neurology  1033179858     False
# 6                                      Sleep Medicine  1467456228     False
# 7                                       Family Health  1376777508     False
# 8                                        Primary Care  1295170025     False
# 9              Plastic Surgery within the Head & Neck  1821068040     False
# 10                                            Allergy  1417085606     False
# 11                              Therapeutic Radiology  1003905969     False
# 12                                         Hematology  1003871815     False
# 13                                Surgery of the Hand  1912999863     False
# 14                 Plastic and Reconstructive Surgery  1841406063     False
# 15                    Hospice and Palliative Medicine  1205978152     False
# 16                             Foot and Ankle Surgery  1386848869     False
# 17                                         Acute Care  1447794755     False
# 18                              Otology & Neurotology  1629050372     False
# 19                                       Foot Surgery  1306825211     False
# 20                             Neuromuscular Medicine  1568501005     False
# 21                      Pediatric Hematology-Oncology  1003173592     False
# 22                                         Hematology  1588621031     False
# 23                                           Clinical  1659541969     False
# 24  Female Pelvic Medicine and Reconstructive Surgery  1952388977     False
# 25                       Pediatric Emergency Medicine  1457351165     False
# 26                                 Addiction Medicine  1497970636     False
# 27                              Brain Injury Medicine  1902127582     False
# 28                                 Addiction Medicine  1033343728     False
# 29                               Pediatric Cardiology  1417004136     False
# 30                             Critical Care Medicine  1871887463     False
# 31                                        Gerontology  1588861207     False
# 32                                   Sports Physician  1942306253     False
# 33                                    Sports Medicine  1215105895     False
# 34                                Pediatric Radiology  1376630475     False
# 35                                   General Practice  1841278546     False
# 36                                         Counseling  1639435159     False
# 37                              Diagnostic Ultrasound  1922155894     False
# 38                                     Sleep Medicine  1154303592     False
# 39                                         Orthopedic  1629320130     False
# 40                                   Medical-Surgical  1144412958     False
# 41                              Occupational Medicine  1235137183     False
# 42                     Oral and Maxillofacial Surgery  1013054113     False
# 43                                    Sports Medicine  1033316484     False
# 44                        Clinical Child & Adolescent  1407050180     False
#
#     patient_count  patient_count_overall  patient_prop  \
# 0            1511                   1511      1.000000
# 1            1033                   1180      0.875424
# 2             817                    817      1.000000
# 3             626                    626      1.000000
# 4             497                    497      1.000000
# 5             489                    489      1.000000
# 6             432                    432      1.000000
# 7             333                    333      1.000000
# 8             311                    311      1.000000
# 9             294                    294      1.000000
# 10            226                    226      1.000000
# 11            218                    218      1.000000
# 12            213                    213      1.000000
# 13            194                    194      1.000000
# 14            193                    193      1.000000
# 15            189                    189      1.000000
# 16            173                    173      1.000000
# 17            166                    166      1.000000
# 18            155                    155      1.000000
# 19            147                    189      0.777778
# 20            145                    145      1.000000
# 21            139                    139      1.000000
# 22            135                    135      1.000000
# 23            128                    128      1.000000
# 24            117                    212      0.551887
# 25            107                    107      1.000000
# 26             90                     90      1.000000
# 27             84                     84      1.000000
# 28             81                     81      1.000000
# 29             76                     76      1.000000
# 30             73                     73      1.000000
# 31             71                     71      1.000000
# 32             65                     65      1.000000
# 33             61                    169      0.360947
# 34             61                   1044      0.058429
# 35             60                     60      1.000000
# 36             55                     55      1.000000
# 37             53                     53      1.000000
# 38             48                    396      0.121212
# 39             47                     47      1.000000
# 40             46                     46      1.000000
# 41             41                    642      0.063863
# 42             38                     38      1.000000
# 43             38                     38      1.000000
# 44             36                     36      1.000000
#
#                         name           npi endpoint_type  \
# 0   GONZALEZ-BERNAL, ALBERTO           NaN           NaN
# 1                 MANI, VENK           NaN           NaN
# 2       CROPSEY, CHRISTOPHER           NaN           NaN
# 3        MICHAELSON, RICHARD           NaN           NaN
# 4           EMMANUEL, MILROY           NaN           NaN
# 5         SENGSTOCK, GREGORY           NaN           NaN
# 6                JOHN, BIJOY           NaN           NaN
# 7             WRIGHT, EVELYN           NaN           NaN
# 8           ANIKWE, FREDRICK           NaN           NaN
# 9           STEWART, WILLIAM           NaN           NaN
# 10            SULLIVAN, RYAN           NaN           NaN
# 11          ROSENBLATT, PAUL           NaN           NaN
# 12           KINGMA, DOUGLAS           NaN           NaN
# 13          STAELIN, STEPHEN           NaN           NaN
# 14             GARZA, ROBERT           NaN           NaN
# 15        STEUART, CATHERINE           NaN           NaN
# 16             CORN, WILLIAM           NaN           NaN
# 17            MEEKS, MELYNDA           NaN           NaN
# 18        SCHWABER, MITCHELL           NaN           NaN
# 19                 RETIEF, I           NaN           NaN
# 20                LE, CHUONG           NaN           NaN
# 21                HSU, PETER           NaN           NaN
# 22           BACHIER, CARLOS           NaN           NaN
# 23           VICTORY, ALICIA           NaN           NaN
# 24               ABEL, MARCY           NaN           NaN
# 25             SLOAS, HAROLD           NaN           NaN
# 26               ELKIN, CHAD           NaN           NaN
# 27            MEHTA, SRAVANI           NaN           NaN
# 28         COLLINS, KIMBERLY           NaN           NaN
# 29                CLAY, MARK  1.417004e+09        DIRECT
# 30            BENNETT, KATHY           NaN           NaN
# 31           EUBANK, ABIGAIL           NaN           NaN
# 32         MCKINLEY, JEFFREY           NaN           NaN
# 33               SCOTT, LEON  1.215106e+09        DIRECT
# 34         WUSHENSKY, CURTIS           NaN           NaN
# 35              KING, KRISTY           NaN           NaN
# 36           SLATTEN, MARSHA           NaN           NaN
# 37              BIRCHER, ANA           NaN           NaN
# 38            UPENDER, RAGHU  1.154304e+09        DIRECT
# 39            LAY, NATHANIEL           NaN           NaN
# 40      EVANGELIST, JENNIFER  1.144413e+09        DIRECT
# 41           SINGH, NARENDRA  1.235137e+09        DIRECT
# 42             PRESS, STEVEN           NaN           NaN
# 43          KINDRED, JEFFRIE           NaN           NaN
# 44           SANGER, MAUREEN           NaN           NaN
#
#    endpoint_type_description  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29  Direct Messaging Address
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33  Direct Messaging Address
# 34                       NaN
# 35                       NaN
# 36                       NaN
# 37                       NaN
# 38  Direct Messaging Address
# 39                       NaN
# 40  Direct Messaging Address
# 41  Direct Messaging Address
# 42                       NaN
# 43                       NaN
# 44                       NaN
#
#                                             endpoint affiliation  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
# 5                                                NaN         NaN
# 6                                                NaN         NaN
# 7                                                NaN         NaN
# 8                                                NaN         NaN
# 9                                                NaN         NaN
# 10                                               NaN         NaN
# 11                                               NaN         NaN
# 12                                               NaN         NaN
# 13                                               NaN         NaN
# 14                                               NaN         NaN
# 15                                               NaN         NaN
# 16                                               NaN         NaN
# 17                                               NaN         NaN
# 18                                               NaN         NaN
# 19                                               NaN         NaN
# 20                                               NaN         NaN
# 21                                               NaN         NaN
# 22                                               NaN         NaN
# 23                                               NaN         NaN
# 24                                               NaN         NaN
# 25                                               NaN         NaN
# 26                                               NaN         NaN
# 27                                               NaN         NaN
# 28                                               NaN         NaN
# 29            MARK.CLAY@hca7.eclinicaldirectplus.com           N
# 30                                               NaN         NaN
# 31                                               NaN         NaN
# 32                                               NaN         NaN
# 33                       lscott32782@direct.vumc.org           N
# 34                                               NaN         NaN
# 35                                               NaN         NaN
# 36                                               NaN         NaN
# 37                                               NaN         NaN
# 38                     rupender35077@direct.vumc.org           N
# 39                                               NaN         NaN
# 40  JENNIFER.EVANGELIST@hca1.eclinicaldirectplus.com           N
# 41                       nsingh33323@direct.vumc.org           N
# 42                                               NaN         NaN
# 43                                               NaN         NaN
# 44                                               NaN         NaN
#
#    endpoint_description affiliation_legal_business_name
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
# 3                   NaN                             NaN
# 4                   NaN                             NaN
# 5                   NaN                             NaN
# 6                   NaN                             NaN
# 7                   NaN                             NaN
# 8                   NaN                             NaN
# 9                   NaN                             NaN
# 10                  NaN                             NaN
# 11                  NaN                             NaN
# 12                  NaN                             NaN
# 13                  NaN                             NaN
# 14                  NaN                             NaN
# 15                  NaN                             NaN
# 16                  NaN                             NaN
# 17                  NaN                             NaN
# 18                  NaN                             NaN
# 19                  NaN                             NaN
# 20                  NaN                             NaN
# 21                  NaN                             NaN
# 22                  NaN                             NaN
# 23                  NaN                             NaN
# 24                  NaN                             NaN
# 25                  NaN                             NaN
# 26                  NaN                             NaN
# 27                  NaN                             NaN
# 28                  NaN                             NaN
# 29                 None                            None
# 30                  NaN                             NaN
# 31                  NaN                             NaN
# 32                  NaN                             NaN
# 33                 None                            None
# 34                  NaN                             NaN
# 35                  NaN                             NaN
# 36                  NaN                             NaN
# 37                  NaN                             NaN
# 38                 None                            None
# 39                  NaN                             NaN
# 40                 None                            None
# 41                 None                            None
# 42                  NaN                             NaN
# 43                  NaN                             NaN
# 44                  NaN                             NaN
