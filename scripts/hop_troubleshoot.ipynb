# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# # groups_test

# %%
# %%time
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time
query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT *
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT npi
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT 
            to_npi,
            referral_id,
            qf.entity_type_code,
            qf.taxonomy_code,
            classification,
            specialization,
            qf."provider_organization_name_(legal_business_name)" AS organization,
            qf.provider_first_line_business_practice_location_address AS address_line1,
            qf.provider_second_line_business_practice_location_address AS address_line2,
            qf.provider_business_practice_location_address_city_name AS city,
            qf.provider_business_practice_location_address_state_name AS state,
            qf.provider_business_practice_location_address_postal_code AS zip
        FROM qualifying_refs AS qf
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""
with sqlite3.connect('../data/hopteam.sqlite') as db:
    groups_test = pd.read_sql(query, db)
    
groups_test
# Out:
# Wall time: 45.8 s
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 0      1013012616     18854880               2.0    207Q00000X
# 1      1013012616    131966153               2.0    207Q00000X
# 2      1013012616    146169993               2.0    207Q00000X
# 3      1902804271       320488               2.0    208VP0014X
# 4      1902804271      6754370               2.0    208VP0014X
# ...           ...          ...               ...           ...
# 69422  1669872735     30083148               2.0    363LF0000X
# 69423  1669872735    114150220               2.0    363LF0000X
# 69424  1669872735    178563129               2.0    363LF0000X
# 69425  1669872735    184096138               2.0    363LF0000X
# 69426  1053867184     97303120               2.0    363LF0000X
#
#            classification                specialization  \
# 0         Family Medicine                          None
# 1         Family Medicine                          None
# 2         Family Medicine                          None
# 3           Pain Medicine  Interventional Pain Medicine
# 4           Pain Medicine  Interventional Pain Medicine
# ...                   ...                           ...
# 69422  Nurse Practitioner                        Family
# 69423  Nurse Practitioner                        Family
# 69424  Nurse Practitioner                        Family
# 69425  Nurse Practitioner                        Family
# 69426  Nurse Practitioner                        Family
#
#                              organization        address_line1 address_line2  \
# 0            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 1            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 2            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 3             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# 4             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# ...                                   ...                  ...           ...
# 69422  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69423  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69424  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69425  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69426     SMITH COUNTY FAMILY MEDICAL LLC  8 NEW MIDDLETON HWY         STE A
#
#                city state    zip
# 0        ALEXANDRIA    TN  37012
# 1        ALEXANDRIA    TN  37012
# 2        ALEXANDRIA    TN  37012
# 3           ANTIOCH    TN  37013
# 4           ANTIOCH    TN  37013
# ...             ...   ...    ...
# 69422  GORDONSVILLE    TN  38563
# 69423  GORDONSVILLE    TN  38563
# 69424  GORDONSVILLE    TN  38563
# 69425  GORDONSVILLE    TN  38563
# 69426  GORDONSVILLE    TN  38563
#
# [69427 rows x 12 columns]

# %% [markdown]
# # group_providers

# %%
# %%time
# profiles of all providers
# with referrals to metro nashville groups (entity 2) having
# referrals of over 50 transactions and under 50 average wait time
query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT 
                referral_id
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT
            from_npi,
            referral_id,
            entity_type_code,
            "provider_last_name_(legal_name)" || ', ' || provider_first_name AS name,
            taxonomy_code,
            classification,
            specialization,
            "provider_organization_name_(legal_business_name)" AS organization,
            provider_first_line_business_practice_location_address AS address_line1,
            provider_second_line_business_practice_location_address AS address_line2,
            provider_business_practice_location_address_city_name AS city,
            provider_business_practice_location_address_state_name AS state,
            provider_business_practice_location_address_postal_code AS zip     
        FROM qualifying_refs
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""

with sqlite3.connect('../data/hopteam.sqlite') as db:
    providers_test = pd.read_sql(query, db)
    
providers_test
# Out:
# Wall time: 18.3 s
#          from_npi  referral_id  entity_type_code                 name  \
# 0      1821080961     18854880               1.0    SHERWOOD, WILLIAM
# 1      1841282779    131966153               1.0         RHODY, KEVIN
# 2      1770575607    146169993               1.0       COOPER, STEVEN
# 3      1508804337       320488               1.0       SHARMA, VINEET
# 4      1538109103      6754370               1.0            NAU, PAUL
# ...           ...          ...               ...                  ...
# 69422  1558355941     30083148               1.0         JOSEPH, JOJU
# 69423  1023099074    114150220               1.0     LAMBERT, HEATHER
# 69424  1184619124    178563129               1.0  RUTHERFORD, RICHARD
# 69425  1205931565    184096138               1.0       NOBLE, MICHAEL
# 69426  1912156696     97303120               1.0    GREGORY, KIMBERLY
#
#       taxonomy_code      classification        specialization organization  \
# 0        207Q00000X     Family Medicine                  None         None
# 1        207Q00000X     Family Medicine                  None         None
# 2        207Q00000X     Family Medicine                  None         None
# 3        2085R0202X           Radiology  Diagnostic Radiology         None
# 4        2085R0202X           Radiology  Diagnostic Radiology         None
# ...             ...                 ...                   ...          ...
# 69422    207RN0300X   Internal Medicine            Nephrology         None
# 69423    363LW0102X  Nurse Practitioner        Women's Health         None
# 69424    207Q00000X     Family Medicine                  None         None
# 69425    207Q00000X     Family Medicine                  None         None
# 69426    363LF0000X  Nurse Practitioner                Family         None
#
#                 address_line1 address_line2            city state    zip
# 0         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 1         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 2         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 3      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# 4      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# ...                       ...           ...             ...   ...    ...
# 69422    270 EAST MAIN STREET     SUITE 200        GALLATIN    TN  37066
# 69423    507 GORDONSVILLE HWY     SUITE 203    GORDONSVILLE    TN  38563
# 69424         133 HOSPITAL DR     SUITE 500        CARTHAGE    TN  37030
# 69425            37 PALMER ST          None          CALAIS    ME  04619
# 69426     8 NEW MIDDLETON HWY         STE A    GORDONSVILLE    TN  38563
#
# [69427 rows x 13 columns]

# %% [markdown]
# # Comparing test results with Alex's results

# %%
(groups_test.loc[(groups_test['organization'] == 'VANDERBILT UNIVERSITY MEDICAL CENTER') 
#          & 
         #~(groups_test['classification'].isin(['Internal Medicine', 'Pharmacy'])
#          &
#           (groups_test['specialization'].isnull()))
        ]
        .drop_duplicates(['classification','specialization'])
        .sort_values(['classification','specialization'])
)
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 41143  1740319847     30227209               2.0    261QE0700X
# 18185  1306889597      1003005               2.0    282N00000X
# 61594  1104202761       690514               2.0    207R00000X
# 65179  1285091330       962232               2.0    3336C0003X
# 65173  1649637794      1530270               2.0    333600000X
# 18178  1821030842     29056973               2.0    273R00000X
# 18182  1215979190    117291950               2.0    273Y00000X
#
#                     classification                            specialization  \
# 41143                Clinic/Center  End-Stage Renal Disease (ESRD) Treatment
# 18185  General Acute Care Hospital                                      None
# 61594            Internal Medicine                                      None
# 65179                     Pharmacy                 Community/Retail Pharmacy
# 65173                     Pharmacy                                      None
# 18178             Psychiatric Unit                                      None
# 18182          Rehabilitation Unit                                      None
#
#                                organization                     address_line1  \
# 41143  VANDERBILT UNIVERSITY MEDICAL CENTER  2906 FOSTER CREIGHTON DR STE 100
# 18185  VANDERBILT UNIVERSITY MEDICAL CENTER           1411 W. BADDOUR PARKWAY
# 61594  VANDERBILT UNIVERSITY MEDICAL CENTER                   1301 22ND AVE S
# 65179  VANDERBILT UNIVERSITY MEDICAL CENTER            1211 MEDICAL CENTER DR
# 65173  VANDERBILT UNIVERSITY MEDICAL CENTER                   1215 21ST AVE S
# 18178  VANDERBILT UNIVERSITY MEDICAL CENTER                   500 PARK AVENUE
# 18182  VANDERBILT UNIVERSITY MEDICAL CENTER                   500 PARK AVENUE
#
#       address_line2       city state    zip
# 41143          None  NASHVILLE    TN  37204
# 18185          None    LEBANON    TN  37087
# 61594          None  NASHVILLE    TN  37232
# 65179      TVC 1815  NASHVILLE    TN  37232
# 65173     ROOM 1006  NASHVILLE    TN  37232
# 18178          None    LEBANON    TN  37087
# 18182          None    LEBANON    TN  37087

# %%
groups_test.loc[(groups_test['organization'] == 'VANDERBILT UNIVERSITY MEDICAL CENTER') 
         & 
         (groups_test['classification'].isin(['General Acute Care Hospital']))
         &
         (groups_test['specialization'] == 'None')].shape
# Out:
# (0, 12)

# %% [markdown]
# # Reconciling groups data with Alex's group data

# %%
groups_alex = pd.read_csv('../data/teammates/groups_alex.csv').drop(columns = ['Unnamed: 0'])

# %%
groups_alex.shape
# Out:
# (45595, 11)

# %%
groups_test.shape
# Out:
# (69427, 12)

# %%
checker = groups_test['referral_id'].to_frame().assign(df_label_joshua = 'Joshua').merge(groups_alex['referral_id'].to_frame().assign(df_label_alex = 'Alex'), how = 'outer')

# %% [markdown]
# test data has all the rows that Alex has

# %%
checker[checker['df_label_joshua'].isnull()]
# Out:
# Empty DataFrame
# Columns: [referral_id, df_label_joshua, df_label_alex]
# Index: []

# %% [markdown]
# test data has 23,832 rows that Alex's data doesn't have

# %%
checker[checker['df_label_alex'].isnull()]
# Out:
#        referral_id df_label_joshua df_label_alex
# 102       20166848          Joshua           NaN
# 103       45071264          Joshua           NaN
# 104      148635690          Joshua           NaN
# 117       99871103          Joshua           NaN
# 118      123331410          Joshua           NaN
# ...            ...             ...           ...
# 69370    116773375          Joshua           NaN
# 69371    131865100          Joshua           NaN
# 69372    156111327          Joshua           NaN
# 69373    184731114          Joshua           NaN
# 69374    196611127          Joshua           NaN
#
# [23832 rows x 3 columns]

# %%
providers_test.merge(checker.loc[checker['df_label_alex'].isnull(), ['referral_id']]).drop_duplicates(subset = ['from_npi'])
# Out:
#          from_npi  referral_id  entity_type_code               name  \
# 0      1043524283     20166848               1.0           YI, ANNA
# 1      1437598992     45071264               1.0  KRAGENBRINK, KYLE
# 2      1093753303    148635690               1.0       WELCH, DEREK
# 3      1649584962     99871103               1.0       POWERS, ALAN
# 4      1700274974    123331410               1.0     JENKENS, KIETH
# ...           ...          ...               ...                ...
# 23736  1629116843     85619453               1.0  SEEBACH, JENNIFER
# 23740  1750320453    142569086               1.0    GORDON, TIMOTHY
# 23747  1245343003    190906237               1.0     ATNIP, CHARLES
# 23751  1366777864    208046834               1.0      MCCURRY, BRIE
# 23793  1568886406     33188043               1.0       SMITH, JAMES
#
#       taxonomy_code                           classification  \
# 0        152W00000X                              Optometrist
# 1        152W00000X                              Optometrist
# 2        207ZP0102X                                Pathology
# 3        208D00000X                         General Practice
# 4        363LF0000X                       Nurse Practitioner
# ...             ...                                      ...
# 23736    207L00000X                           Anesthesiology
# 23740    207W00000X                            Ophthalmology
# 23747    207W00000X                            Ophthalmology
# 23751    367500000X  Nurse Anesthetist, Certified Registered
# 23793    363A00000X                      Physician Assistant
#
#                                 specialization organization  \
# 0                                         None         None
# 1                                         None         None
# 2      Anatomic Pathology & Clinical Pathology         None
# 3                                         None         None
# 4                                       Family         None
# ...                                        ...          ...
# 23736                                     None         None
# 23740                                     None         None
# 23747                                     None         None
# 23751                                     None         None
# 23793                                     None         None
#
#                             address_line1 address_line2           city state  \
# 0                      5323 MOUNT VIEW RD          None        ANTIOCH    TN
# 1                      5323 MOUNT VIEW RD          None        ANTIOCH    TN
# 2                       5301 VIRGINIA WAY     SUITE 300      BRENTWOOD    TN
# 3                          600 12TH AVE S          #709      NASHVILLE    TN
# 4                    843 SUMPTER RD # 424          None  VAN BUREN TWP    MI
# ...                                   ...           ...            ...   ...
# 23736                    677 CHURCH ST NE          None       MARIETTA    GA
# 23740  1050 N JAMES CAMPBELL BLVD STE 100          None       COLUMBIA    TN
# 23747          1050 N JAMES CAMPBELL BLVD     SUITE 100       COLUMBIA    TN
# 23751                     4230 HARDING RD     SUITE 435      NASHVILLE    TN
# 23793                   4566 E HIGHWAY 20          None      NICEVILLE    FL
#
#          zip
# 0      37013
# 1      37013
# 2      37027
# 3      37203
# 4      48111
# ...      ...
# 23736  30060
# 23740  38401
# 23747  38401
# 23751  37205
# 23793  32578
#
# [10757 rows x 13 columns]
