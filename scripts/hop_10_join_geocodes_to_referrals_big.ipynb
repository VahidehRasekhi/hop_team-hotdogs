# %% [markdown]
# # Import

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np
import sqlite3
import requests
import json
from math import radians, cos, sin, asin, sqrt

# %% [markdown]
# # Read in

# %%
referrals_big = pd.read_csv('../data/neo4j/referrals_big.csv')
to_addresses = pd.read_csv('../data/geocodes/to_address_geocodes_big.csv')
from_addresses = pd.read_csv('../data/geocodes/from_address_geocodes_big.csv')

# %%
ref_geo = (referrals_big.merge(from_addresses, on = 'address_from')
                         .merge(to_addresses, on = 'address_to', suffixes = ('_from', '_to'))
        )

# %% [markdown]
# # Write Haversine formula to calculate miles between coordinates

# %%
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3956 # Radius of earth in miles. Use 6371 for kilometers
    return c * r

# %% [markdown]
# # Apply Haversine Formula to hosp_geom and save CSV

# %%
ref_geo['distance_miles'] = [haversine(row['lng_from'], row['lat_from'], row['lng_to'], row['lat_to']) for ind, row in ref_geo.iterrows()]

# %%
ref_geo.head()
# Out:
#      from_npi  referral_id  entity_from          name_from  \
# 0  1821080961     18854880          1.0  SHERWOOD, WILLIAM
# 1  1679677199    104890727          2.0                NaN
# 2  1841282779    131966153          1.0       RHODY, KEVIN
# 3  1770575607    146169993          1.0     COOPER, STEVEN
# 4  1093741464     29450644          2.0                NaN
#
#                  organization_from taxonomy_code_from classification_from  \
# 0                              NaN         207Q00000X     Family Medicine
# 1     CRIPPS, HOOPER & RHODY, PLLC         207Q00000X     Family Medicine
# 2                              NaN         207Q00000X     Family Medicine
# 3                              NaN         207Q00000X     Family Medicine
# 4  ADVANCED DIAGNOSTIC IMAGING, PC         207R00000X   Internal Medicine
#
#   specialization_from      address_line1_from address_line2_from  ...  \
# 0                 NaN     302 N CONGRESS BLVD                NaN  ...
# 1                 NaN     302 N CONGRESS BLVD                NaN  ...
# 2                 NaN     302 N CONGRESS BLVD                NaN  ...
# 3                 NaN     302 N CONGRESS BLVD                NaN  ...
# 4                 NaN  3024 BUSINESS PARK CIR                NaN  ...
#
#   transaction_count average_day_wait  std_day_wait  \
# 0               238            9.924        40.266
# 1               758            0.000         0.000
# 2               236            7.695        36.447
# 3               320            2.725        18.756
# 4                60           36.300        43.394
#
#                                        address_from  \
# 0         302 N CONGRESS BLVD, SMITHVILLE, TN 37166
# 1         302 N CONGRESS BLVD, SMITHVILLE, TN 37166
# 2         302 N CONGRESS BLVD, SMITHVILLE, TN 37166
# 3         302 N CONGRESS BLVD, SMITHVILLE, TN 37166
# 4  3024 BUSINESS PARK CIR, GOODLETTSVILLE, TN 37072
#
#                                   address_to   lat_from   lng_from     lat_to  \
# 0  400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  35.969171 -85.807472  36.077559
# 1  400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  35.969171 -85.807472  36.077559
# 2  400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  35.969171 -85.807472  36.077559
# 3  400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  35.969171 -85.807472  36.077559
# 4  400 E PUBLIC SQUARE, ALEXANDRIA, TN 37012  36.332108 -86.700830  36.077559
#
#       lng_to distance_miles
# 0 -86.033322      14.665166
# 1 -86.033322      14.665166
# 2 -86.033322      14.665166
# 3 -86.033322      14.665166
# 4 -86.033322      41.132856
#
# [5 rows x 36 columns]

# %%
ref_geo.to_csv('../data/neo4j/referrals_big_geo.csv', index = False)
