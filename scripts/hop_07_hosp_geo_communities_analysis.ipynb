# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import re
import plotly.express as px
from jupyterthemes import jtplot
jtplot.style()

# %% [markdown]
# # Read in

# %%
hosp_geo = pd.read_csv('../data/neo4j/hosp_geo.csv')
hc = pd.read_csv('../data/neo4j/hosp_simple_communities.csv')

# %% [markdown]
# # Investigate the communities derived from Neo4J

# %% [markdown]
# Here we group by community and count the NPIs in each group. Because this came from a Neo4J output, where the nodes are all distinct, this is implicitly a distinct count.
#
# There are only 13 actual communities; all the other communities have no NPI associated with them.

# %%
hc_counts = (hc.groupby('communityId')['npi']
             .count()
             .reset_index()
             .rename(columns = {'npi':'count'})
             .sort_values('count', ascending = False)
            )
hc_counts.head(15)
# Out:
#      communityId  count
# 127         3302   1898
# 126         3300    926
# 109         2725    853
# 169         5231    637
# 0            859    501
# 178         5871    329
# 110         2727    327
# 1            861    221
# 2            862    121
# 125         3299     43
# 177         5870     32
# 86          1564     12
# 176         5867     10
# 131         3306      0
# 119         2736      0

# %% [markdown]
# Let's only keep the communities with NPIs in them.

# %%
real_coms = hc_counts.loc[hc_counts['count'] > 0, 'communityId']
hc_clean = hc[hc['communityId'].isin(real_coms)]

# %% [markdown]
# For the sake of combining the communities data with our hosp_geo data, let's create separate community tables for the providers and the hospitals.

# %%
prov_coms = hc_clean[hc_clean['organization'].isnull()]
hosp_coms = hc_clean[~hc_clean['organization'].isnull()]

# %% [markdown]
# These will also be useful for adding properties to the Neo4J graph, so save to disk.

# %%
hosp_coms.to_csv('../data/neo4j/hosp_simple_coms.csv', index = False)
prov_coms.to_csv('../data/neo4j/prov_simple_coms.csv', index = False)

# %% [markdown]
# Merge the communityIds columns as well as the count of NPIs in each community together with the hosp_coms table.

# %%
coms_counts = hc_clean.groupby('communityId')['npi'].count().reset_index().rename(columns = {'npi':'community_count'})
hosp_coms_counts = coms_counts.merge(hosp_coms).sort_values('community_count', ascending = False)

# %% [markdown]
# Now also merge in the addresses, latitudes, and longitudes from hosp_geo.
#
# The result is a summary table of all the hospitals in the Nashville CBSA together with their respective communityId, count, and address details.

# %%
hosp_addresses = hosp_geo[['to_npi', 'address_hospital', 'lng_hospital', 'lat_hospital']].drop_duplicates()

# %%
hospital_coms = hosp_coms_counts.merge(hosp_addresses, left_on = 'npi', right_on = 'to_npi')

# %%
hospital_coms
# Out:
#     communityId  community_count           npi name  \
# 0          3302             1898  1.396882e+09  NaN
# 1          3302             1898  1.558409e+09  NaN
# 2          3302             1898  1.598738e+09  NaN
# 3          3300              926  1.497827e+09  NaN
# 4          3300              926  1.023055e+09  NaN
# 5          3300              926  1.649576e+09  NaN
# 6          3300              926  1.679924e+09  NaN
# 7          3300              926  1.932146e+09  NaN
# 8          3300              926  1.265487e+09  NaN
# 9          3300              926  1.992776e+09  NaN
# 10         3300              926  1.720032e+09  NaN
# 11         3300              926  1.124065e+09  NaN
# 12         3300              926  1.093770e+09  NaN
# 13         3300              926  1.295780e+09  NaN
# 14         3300              926  1.881643e+09  NaN
# 15         2725              853  1.629026e+09  NaN
# 16         2725              853  1.992861e+09  NaN
# 17         2725              853  1.215938e+09  NaN
# 18         2725              853  1.780779e+09  NaN
# 19         2725              853  1.336120e+09  NaN
# 20         2725              853  1.518346e+09  NaN
# 21         5231              637  1.891001e+09  NaN
# 22         5231              637  1.396161e+09  NaN
# 23         5231              637  1.861480e+09  NaN
# 24         5231              637  1.578592e+09  NaN
# 25         5231              637  1.932171e+09  NaN
# 26          859              501  1.023062e+09  NaN
# 27          859              501  1.669568e+09  NaN
# 28          859              501  1.922319e+09  NaN
# 29          859              501  1.104137e+09  NaN
# 30          859              501  1.245541e+09  NaN
# 31          859              501  1.538114e+09  NaN
# 32          859              501  1.285644e+09  NaN
# 33          859              501  1.447572e+09  NaN
# 34          859              501  1.467763e+09  NaN
# 35          859              501  1.417939e+09  NaN
# 36         5871              329  1.164590e+09  NaN
# 37         5871              329  1.497013e+09  NaN
# 38         5871              329  1.184988e+09  NaN
# 39         2727              327  1.306890e+09  NaN
# 40         2727              327  1.821350e+09  NaN
# 41         2727              327  1.194869e+09  NaN
# 42         2727              327  1.164469e+09  NaN
# 43         2727              327  1.982650e+09  NaN
# 44          861              221  1.265446e+09  NaN
# 45          861              221  1.942676e+09  NaN
# 46          862              121  1.780622e+09  NaN
# 47          862              121  1.871531e+09  NaN
# 48         3299               43  1.568551e+09  NaN
# 49         5870               32  1.649660e+09  NaN
# 50         5870               32  1.447639e+09  NaN
# 51         1564               12  1.942443e+09  NaN
# 52         5867               10  1.770510e+09  NaN
#
#                                          organization      to_npi  \
# 0                VANDERBILT UNIVERSITY MEDICAL CENTER  1396882205
# 1                VANDERBILT UNIVERSITY MEDICAL CENTER  1558408633
# 2    VANDERBILT STALLWORTH REHABILITATION HOSPITAL LP  1598738205
# 3                        MIDDLE TENNESSEE HOSPITALIST  1497827364
# 4              HCA HEALTH SERVICES OF TENNESSEE, INC.  1023055126
# 5                         CRESCENT MEDICAL GROUP PLLC  1649576414
# 6                           CURAHEALTH NASHVILLE, LLC  1679924005
# 7              HCA HEALTH SERVICES OF TENNESSEE, INC.  1932146032
# 8              HCA HEALTH SERVICES OF TENNESSEE, INC.  1265487193
# 9              HCA HEALTH SERVICES OF TENNESSEE, INC.  1992776405
# 10             HCA HEALTH SERVICES OF TENNESSEE, INC.  1720032345
# 11             HCA HEALTH SERVICES OF TENNESSEE, INC.  1124065255
# 12                  HTI MEMORIAL HOSPITAL CORPORATION  1093769606
# 13                  HTI MEMORIAL HOSPITAL CORPORATION  1295780476
# 14                            RIVER PARK HOSPITAL LLC  1881642809
# 15                         SAINT THOMAS WEST HOSPITAL  1629025648
# 16                                  SETON CORPORATION  1992861314
# 17          SELECT SPECIALTY HOSPITAL - NASHVILLE LLC  1215937982
# 18                         SAINT THOMAS WEST HOSPITAL  1780778969
# 19                  BAPTIST WOMEN'S HEALTH CENTER LLC  1336119627
# 20              SAINT THOMAS RIVER PARK HOSPITAL, LLC  1518346469
# 21      BEHAVIORAL HEALTHCARE CENTER AT COLUMBIA, LLC  1891000923
# 22                          APP OF TENNESSEE HM, PLLC  1396160768
# 23                            MAURY REGIONAL HOSPITAL  1861479545
# 24                            MAURY REGIONAL HOSPITAL  1578591756
# 25                   SHELBYVILLE HOSPITAL COMPANY LLC  1932170750
# 26                                  SRHS HOLDINGS LLC  1023061520
# 27                          NORTHCREST MEDICAL CENTER  1669567897
# 28                       RIVERVIEW MEDICAL CENTER LLC  1922319037
# 22          2835 HIGHWAY 231 N, SHELBYVILLE, TN 37160    -86.448776
# 23              1224 TROTWOOD AVE, COLUMBIA, TN 38401    -87.067148
# 24         1080 N ELLINGTON PKWY, LEWISBURG, TN 37091    -86.785385
# 25              2835 HWY 231 N, SHELBYVILLE, TN 37160    -86.459209
# 26                158 HOSPITAL DR, CARTHAGE, TN 37030    -85.949974
# 27           100 NORTHCREST DR, SPRINGFIELD, TN 37172    -86.887084
# 28                158 HOSPITAL DR, CARTHAGE, TN 37030    -85.949974
# 29                158 HOSPITAL DR, CARTHAGE, TN 37030    -85.949974
# 30                158 HOSPITAL DR, CARTHAGE, TN 37030    -85.949974
# 31  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...    -86.622419
# 32            555 HARTSVILLE PIKE, GALLATIN, TN 37066    -86.432507
# 33            555 HARTSVILLE PIKE, GALLATIN, TN 37066    -86.432507
# 34                500 CHURCH ST, HARTSVILLE, TN 37074    -86.168102
# 35             204 MEDICAL DRIVE, LAFAYETTE, TN 37083    -86.026427
# 36   1700 MEDICAL CENTER PKWY, MURFREESBORO, TN 37129    -86.425216
# 37        1009 N. THOMPSON LN, MURFREESBORO, TN 37128    -86.430198
# 38        1009 N. THOMPSON LN, MURFREESBORO, TN 37128    -86.430198
# 39         1411 W. BADDOUR PARKWAY, LEBANON, TN 37087    -86.327880
# 40        1009 N. THOMPSON LN, MURFREESBORO, TN 37128    -86.430198
# 41       221 STEWARTS FERRY PIKE, NASHVILLE, TN 37214    -86.646939
# 42               5655 FRIST BLVD, HERMITAGE, TN 37076    -86.608062
# 43               5655 FRIST BLVD, HERMITAGE, TN 37076    -86.608062
# 44         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067    -86.820426
# 45            1000 PHYSICIANS WAY, FRANKLIN, TN 37067    -86.819249
# 46                111 HIGHWAY 70 E, DICKSON, TN 37055    -87.337358
# 47                111 HIGHWAY 70 E, DICKSON, TN 37055    -87.337358
# 48  1818 ALBION ST, ATTN: MARTHA LAMPLEY, NASHVILL...    -86.806717
# 49                520 W MAIN ST, SMITHVILLE, TN 37166    -85.829506
# 50               324 DOOLITTLE RD, WOODBURY, TN 37190    -86.071837
# 51          2014 QUAIL HOLLOW CIR, FRANKLIN, TN 37067    -86.815679
# 52                158 HOSPITAL DR, CARTHAGE, TN 37030    -85.949974
#
#     lat_hospital
# 0      36.142499
# 1      36.138489
# 2      36.138306
# 3      36.245245
# 4      36.153671
# 5      36.182484
# 6      36.182484
# 7      36.153671
# 8      36.277115
# 9      35.975763
# 10     36.076470
# 11     36.076470
# 12     36.245198
# 13     36.245198
# 14     35.700143
# 15     36.129253
# 16     36.154164
# 17     36.152514
# 18     36.154164
# 19     36.155170
# 20     35.700143
# 21     35.606000
# 22     35.563923
# 23     35.606755
# 24     35.465066
# 25     35.382661
# 26     36.263555
# 27     36.478214
# 28     36.263555
# 29     36.263555
# 30     36.263555
# 31     36.325391
# 32     36.390778
# 33     36.390778
# 34     36.387772
# 35     36.519583
# 36     35.861019
# 37     35.863804
# 38     35.863804
# 39     36.221530
# 40     35.863804
# 41     36.165103
# 42     36.176152
# 43     36.176152
# 44     35.916450
# 45     35.919140
# 46     36.082873
# 47     36.082873
# 48     36.166372
# 49     35.961452
# 50     35.832750
# 51     35.914241
# 52     36.263555
