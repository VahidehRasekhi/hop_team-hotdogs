# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import sqlite3
import matplotlib.pyplot as plt

# %%
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT *
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT npi
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT 
            to_npi,
            referral_id,
            qf.entity_type_code,
            qf.taxonomy_code,
            classification,
            specialization,
            qf."provider_organization_name_(legal_business_name)" AS organization,
            qf.provider_first_line_business_practice_location_address AS address_line1,
            qf.provider_second_line_business_practice_location_address AS address_line2,
            qf.provider_business_practice_location_address_city_name AS city,
            qf.provider_business_practice_location_address_state_name AS state,
            qf.provider_business_practice_location_address_postal_code AS zip
        FROM qualifying_refs AS qf
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""
with sqlite3.connect('data/hopteam.sqlite') as db:
    groups = pd.read_sql(query, db)

# %%
groups
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 0      1013012616     18854880               2.0    207Q00000X
# 1      1013012616    131966153               2.0    207Q00000X
# 2      1013012616    146169993               2.0    207Q00000X
# 3      1902804271       320488               2.0    208VP0014X
# 4      1902804271      6754370               2.0    208VP0014X
# ...           ...          ...               ...           ...
# 69422  1669872735     30083148               2.0    363LF0000X
# 69423  1669872735    114150220               2.0    363LF0000X
# 69424  1669872735    178563129               2.0    363LF0000X
# 69425  1669872735    184096138               2.0    363LF0000X
# 69426  1053867184     97303120               2.0    363LF0000X
#
#            Classification                Specialization  \
# 0         Family Medicine                          None
# 1         Family Medicine                          None
# 2         Family Medicine                          None
# 3           Pain Medicine  Interventional Pain Medicine
# 4           Pain Medicine  Interventional Pain Medicine
# ...                   ...                           ...
# 69422  Nurse Practitioner                        Family
# 69423  Nurse Practitioner                        Family
# 69424  Nurse Practitioner                        Family
# 69425  Nurse Practitioner                        Family
# 69426  Nurse Practitioner                        Family
#
#                              organization        address_line1 address_line2  \
# 0            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 1            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 2            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 3             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# 4             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# ...                                   ...                  ...           ...
# 69422  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69423  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69424  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69425  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69426     SMITH COUNTY FAMILY MEDICAL LLC  8 NEW MIDDLETON HWY         STE A
#
#                city state    zip
# 0        ALEXANDRIA    TN  37012
# 1        ALEXANDRIA    TN  37012
# 2        ALEXANDRIA    TN  37012
# 3           ANTIOCH    TN  37013
# 4           ANTIOCH    TN  37013
# ...             ...   ...    ...
# 69422  GORDONSVILLE    TN  38563
# 69423  GORDONSVILLE    TN  38563
# 69424  GORDONSVILLE    TN  38563
# 69425  GORDONSVILLE    TN  38563
# 69426  GORDONSVILLE    TN  38563
#
# [69427 rows x 12 columns]

# %%
# profiles of all providers
# with referrals to metro nashville groups (entity 2) 
#having referrals of over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT 
                referral_id
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT
            from_npi,
            referral_id,
            entity_type_code,
            "provider_last_name_(legal_name)" || ', ' || provider_first_name AS name,
            taxonomy_code,
            classification,
            specialization,
            "provider_organization_name_(legal_business_name)" AS organization,
            provider_first_line_business_practice_location_address AS address_line1,
            provider_second_line_business_practice_location_address AS address_line2,
            provider_business_practice_location_address_city_name AS city,
            provider_business_practice_location_address_state_name AS state,
            provider_business_practice_location_address_postal_code AS zip     
        FROM qualifying_refs
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    providers = pd.read_sql(query, db)

# %%
providers
# Out:
#          from_npi  referral_id  entity_type_code                 name  \
# 0      1821080961     18854880               1.0    SHERWOOD, WILLIAM
# 1      1841282779    131966153               1.0         RHODY, KEVIN
# 2      1770575607    146169993               1.0       COOPER, STEVEN
# 3      1508804337       320488               1.0       SHARMA, VINEET
# 4      1538109103      6754370               1.0            NAU, PAUL
# ...           ...          ...               ...                  ...
# 69422  1558355941     30083148               1.0         JOSEPH, JOJU
# 69423  1023099074    114150220               1.0     LAMBERT, HEATHER
# 69424  1184619124    178563129               1.0  RUTHERFORD, RICHARD
# 69425  1205931565    184096138               1.0       NOBLE, MICHAEL
# 69426  1912156696     97303120               1.0    GREGORY, KIMBERLY
#
#       taxonomy_code      Classification        Specialization organization  \
# 0        207Q00000X     Family Medicine                  None         None
# 1        207Q00000X     Family Medicine                  None         None
# 2        207Q00000X     Family Medicine                  None         None
# 3        2085R0202X           Radiology  Diagnostic Radiology         None
# 4        2085R0202X           Radiology  Diagnostic Radiology         None
# ...             ...                 ...                   ...          ...
# 69422    207RN0300X   Internal Medicine            Nephrology         None
# 69423    363LW0102X  Nurse Practitioner        Women's Health         None
# 69424    207Q00000X     Family Medicine                  None         None
# 69425    207Q00000X     Family Medicine                  None         None
# 69426    363LF0000X  Nurse Practitioner                Family         None
#
#                 address_line1 address_line2            city state    zip
# 0         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 1         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 2         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 3      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# 4      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# ...                       ...           ...             ...   ...    ...
# 69422    270 EAST MAIN STREET     SUITE 200        GALLATIN    TN  37066
# 69423    507 GORDONSVILLE HWY     SUITE 203    GORDONSVILLE    TN  38563
# 69424         133 HOSPITAL DR     SUITE 500        CARTHAGE    TN  37030
# 69425            37 PALMER ST          None          CALAIS    ME  04619
# 69426     8 NEW MIDDLETON HWY         STE A    GORDONSVILLE    TN  38563
#
# [69427 rows x 13 columns]

# %% [markdown]
# ### Top providers in terms of specialty

# %%
providers['Classification'].value_counts().head(20)

# %%
providers['Classification'].value_counts().head(15).plot(kind='bar', figsize= (10,6))
plt.xlabel('Specialties')
plt.ylabel('Count of Referrals')
plt.title('Referrals by Specialty')

# %%
providers.groupby(['name','Classification']).sum()

# %%
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT
                to_npi,
                referral_id,
                patient_count,
                transaction_count,
                average_day_wait,
                std_day_wait  
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT
            from_npi,
            to_npi,
            referral_id,
            patient_count,
            transaction_count,
            average_day_wait,
            std_day_wait
        FROM qualifying_refs
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    referrals = pd.read_sql(query, db)

# %%
referrals
# Out:
#          from_npi      to_npi  referral_id  patient_count  transaction_count  \
# 0      1821080961  1013012616     18854880             91                238
# 1      1841282779  1013012616    131966153             94                236
# 2      1770575607  1013012616    146169993            115                320
# 3      1508804337  1902804271       320488            157                163
# 4      1538109103  1902804271      6754370            312                320
# ...           ...         ...          ...            ...                ...
# 69422  1558355941  1669872735     30083148             31                 89
# 69423  1023099074  1669872735    114150220            256               1309
# 69424  1184619124  1669872735    178563129             40                 90
# 69425  1205931565  1669872735    184096138             35                 54
# 69426  1912156696  1053867184     97303120             97                428
#
#        average_day_wait  std_day_wait
# 0                 9.924        40.266
# 1                 7.695        36.447
# 2                 2.725        18.756
# 3                27.583        51.939
# 4                12.709        40.583
# ...                 ...           ...
# 69422            23.101        31.695
# 69423             0.214         5.207
# 69424            23.089        36.995
# 69425             1.315         6.815
# 69426             0.000         0.000
#
# [69427 rows x 7 columns]

# %%
density_patient_count = (referrals
    .groupby('from_npi')['transaction_count']
    .mean()
    .sort_values(ascending = False)
)
density_patient_count

# %%
#average count of patients by referring npi
density_patient_count = (referrals
    .groupby('from_npi')['patient_count']
    .mean()
    .sort_values(ascending = False)
)
density_patient_count

# %%
referrals[referrals['from_npi']==1457649139]

# %% [markdown]
# ### Top 6 provider referrals are from Berntwood, TN

# %%
providers[providers['from_npi']==1457649139]

# %%
providers[providers['from_npi']==1891955688]

# %%
providers[providers['from_npi']==1720314248]

# %%
providers[providers['from_npi']==1609848563]

# %%
providers[providers['from_npi']==1518046796]

# %%
# General Acute Care Hospitals in Nashville and nearby 


cities = ['NASHVILLE',
          'MURFREESBORO',
          'BRENTWOOD',
          'FRANKLIN',
          'HENDERSONVILLE',
          'GOODLETTSVILLE',
          'LA VERGNE',
          'SMYRNA',
          'MT. JULIET',
          'GALLATIN']

gach = (groups
     .loc[(groups['Classification'].str.contains('General Acute Care Hospital', na = False)) 
            & 
           (groups['city'].isin(cities))
           ,
          ]
     .drop_duplicates()
     .sort_values('organization')
)

gach
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 33687  1023055126     48731386               2.0    282N00000X
# 33707  1023055126     53473559               2.0    282N00000X
# 33708  1023055126     55525652               2.0    282N00000X
# 33709  1023055126     55525663               2.0    282N00000X
# 33710  1023055126     55525676               2.0    282N00000X
# ...           ...          ...               ...           ...
# 10962  1265445506     53960238               2.0    282N00000X
# 10961  1265445506     53960229               2.0    282N00000X
# 10960  1265445506     52260376               2.0    282N00000X
# 10967  1265445506     55966757               2.0    282N00000X
# 11062  1265445506    130486815               2.0    282N00000X
#
#                     Classification Specialization  \
# 33687  General Acute Care Hospital           None
# 33707  General Acute Care Hospital           None
# 33708  General Acute Care Hospital           None
# 33709  General Acute Care Hospital           None
# 33710  General Acute Care Hospital           None
# ...                            ...            ...
# 10962  General Acute Care Hospital           None
# 10961  General Acute Care Hospital           None
# 10960  General Acute Care Hospital           None
# 10967  General Acute Care Hospital           None
# 11062  General Acute Care Hospital           None
#
#                                  organization           address_line1  \
# 33687  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33707  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33708  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33709  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33710  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# ...                                       ...                     ...
# 10962     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10961     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10960     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10967     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 11062     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
#
#       address_line2       city state    zip
# 33687          None  NASHVILLE    TN  37203
# 33707          None  NASHVILLE    TN  37203
# 33708          None  NASHVILLE    TN  37203
# 33709          None  NASHVILLE    TN  37203
# 33710          None  NASHVILLE    TN  37203
# ...             ...        ...   ...    ...
# 10962          None   FRANKLIN    TN  37067
# 10961          None   FRANKLIN    TN  37067
# 10960          None   FRANKLIN    TN  37067
# 10967          None   FRANKLIN    TN  37067
# 11062          None   FRANKLIN    TN  37067
#
# [6875 rows x 12 columns]

# %%
gach.drop_duplicates(subset = ['organization', 'address_line1', 'city', 'state', 'zip']).reset_index().sort_values('organization')
# Out:
#     index      to_npi  referral_id  entity_type_code taxonomy_code  \
# 0   33687  1023055126     48731386               2.0    282N00000X
# 1   50076  1720032345    155535970               2.0    282N00000X
# 2   24794  1992776405    100689576               2.0    282N00000X
# 3   14903  1538114434    169422729               2.0    282N00000X
# 4   45127  1093769606     20019626               2.0    282N00000X
# 5   46796  1568551455    132969432               2.0    282N00000X
# 6   22376  1164590386    117188077               2.0    282N00000X
# 7   44234  1629025648    176011269               2.0    282N00000X
# 8   66179  1780778969    194249596               2.0    282N00000X
# 9   66249  1992861314    106709285               2.0    282N00000X
# 10   9506  1285644237    144750825               2.0    282N00000X
# 11   9933  1447571658    152868401               2.0    282N00000X
# 12  20704  1184987505    168584524               2.0    282N00000X
# 13  59249  1396882205     13694209               2.0    282N00000X
# 14  51120  1558408633     75013834               2.0    282N00000X
# 15  11173  1265445506    187509096               2.0    282N00000X
#
#                  Classification Specialization  \
# 0   General Acute Care Hospital           None
# 1   General Acute Care Hospital           None
# 2   General Acute Care Hospital           None
# 3   General Acute Care Hospital           None
# 4   General Acute Care Hospital           None
# 5   General Acute Care Hospital           None
# 6   General Acute Care Hospital           None
# 7   General Acute Care Hospital           None
# 8   General Acute Care Hospital           None
# 9   General Acute Care Hospital           None
# 10  General Acute Care Hospital           None
# 11  General Acute Care Hospital           None
# 12  General Acute Care Hospital           None
# 13  General Acute Care Hospital           None
# 14  General Acute Care Hospital           None
# 15  General Acute Care Hospital           None
#
#                               organization              address_line1  \
# 0   HCA HEALTH SERVICES OF TENNESSEE, INC.          2300 PATTERSON ST
# 1   HCA HEALTH SERVICES OF TENNESSEE, INC.             391 WALLACE RD
# 2   HCA HEALTH SERVICES OF TENNESSEE, INC.        200 STONECREST BLVD
# 3      HENDERSONVILLE HOSPITAL CORPORATION  355 NEW SHACKLE ISLAND RD
# 4        HTI MEMORIAL HOSPITAL CORPORATION        3441 DICKERSON PIKE
# 5               NASHVILLE GENERAL HOSPITAL             1818 ALBION ST
# 6         SAINT THOMAS RUTHERFORD HOSPITAL   1700 MEDICAL CENTER PKWY
# 7               SAINT THOMAS WEST HOSPITAL            4220 HARDING RD
# 8               SAINT THOMAS WEST HOSPITAL             2000 CHURCH ST
# 9                        SETON CORPORATION             2000 CHURCH ST
# 10     SUMNER REGIONAL HEALTH SYSTEMS, INC        555 HARTSVILLE PIKE
# 11      SUMNER REGIONAL MEDICAL CENTER LLC        555 HARTSVILLE PIKE
# 12                TRUSTPOINT HOSPITAL, LLC        1009 N. THOMPSON LN
# 13    VANDERBILT UNIVERSITY MEDICAL CENTER  1211 MEDICAL CENTER DRIVE
# 14    VANDERBILT UNIVERSITY MEDICAL CENTER            1601 23RD AVE S
# 15     WILLIAMSON COUNTY HOSPITAL DISTRICT     4321 CAROTHERS PARKWAY
#
#            address_line2            city state    zip
# 0                   None       NASHVILLE    TN  37203
# 1                   None       NASHVILLE    TN  37211
# 2                   None          SMYRNA    TN  37167
# 3                   None  HENDERSONVILLE    TN  37075
# 4                   None       NASHVILLE    TN  37207
# 5   ATTN: MARTHA LAMPLEY       NASHVILLE    TN  37208
# 6                   None    MURFREESBORO    TN  37129
# 7                   None       NASHVILLE    TN  37205
# 8                   None       NASHVILLE    TN  37236
# 9                   None       NASHVILLE    TN  37236
# 10                  None        GALLATIN    TN  37066
# 11                  None        GALLATIN    TN  37066
# 12                  None    MURFREESBORO    TN  37128
# 13                  None       NASHVILLE    TN  37232
# 14                  None       NASHVILLE    TN  37212
# 15                  None        FRANKLIN    TN  37067

# %%
#Vanderbilt organizations
(groups
     .loc[groups['organization'].str.contains('VANDERBILT', na = False),
          ['organization', 'Classification', 'Specialization', 'zip']]
     .drop_duplicates()
)
# Out:
#                                             organization  \
# 8700   VANDERBILT HEALTH AND WILLIAMSON MEDICAL CENTE...
# 18178               VANDERBILT UNIVERSITY MEDICAL CENTER
# 18182               VANDERBILT UNIVERSITY MEDICAL CENTER
# 18185               VANDERBILT UNIVERSITY MEDICAL CENTER
# 26037           VANDERBILT MAURY RADIATION ONCOLOGY, LLC
# 41143               VANDERBILT UNIVERSITY MEDICAL CENTER
# 44951                   VANDERBILT IMAGING SERVICES, LLC
# 50958   VANDERBILT STALLWORTH REHABILITATION HOSPITAL LP
# 51038                   VANDERBILT IMAGING SERVICES, LLC
# 51105               VANDERBILT UNIVERSITY MEDICAL CENTER
# 52649               VANDERBILT UNIVERSITY MEDICAL CENTER
# 59038                 VANDERBILT HOME CARE SERVICES, LLC
# 59044               VANDERBILT UNIVERSITY MEDICAL CENTER
# 61594               VANDERBILT UNIVERSITY MEDICAL CENTER
# 65173               VANDERBILT UNIVERSITY MEDICAL CENTER
# 65179               VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                     Classification                            Specialization  \
# 8700             Internal Medicine                                      None
# 18178             Psychiatric Unit                                      None
# 18182          Rehabilitation Unit                                      None
# 18185  General Acute Care Hospital                                      None
# 26037                Clinic/Center                       Oncology, Radiation
# 41143                Clinic/Center  End-Stage Renal Disease (ESRD) Treatment
# 44951                Clinic/Center                                 Radiology
# 50958      Rehabilitation Hospital                                      None
# 51038                    Radiology                      Diagnostic Radiology
# 51105  General Acute Care Hospital                                      None
# 52649                Clinic/Center  End-Stage Renal Disease (ESRD) Treatment
# 59038                  Home Health                                      None
# 59044  General Acute Care Hospital                                      None
# 61594            Internal Medicine                                      None
# 65173                     Pharmacy                                      None
# 65179                     Pharmacy                 Community/Retail Pharmacy
#
#          zip
# 8700   37064
# 18178  37087
# 18182  37087
# 18185  37087
# 26037  37174
# 41143  37204
# 44951  37205
# 50958  37212
# 51038  37212
# 51105  37212
# 52649  37214
# 59038  37232
# 59044  37232
# 61594  37232
# 65173  37232
# 65179  37232

# %%
#all classifications containing 'Hospital'

cities = ['NASHVILLE',
          'MURFREESBORO',
          'BRENTWOOD',
          'FRANKLIN',
          'HENDERSONVILLE',
          'GOODLETTSVILLE',
          'LA VERGNE',
          'SMYRNA',
          'MT. JULIET',
          'GALLATIN']

hospitals = (groups
     .loc[(groups['Classification'].str.contains('Hospital', na = False)) 
           & 
            (groups['city'].isin(cities))
           ,
          ]
     .drop_duplicates()
     .sort_values('organization')
)

hospitals
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 30398  1336119627    150892114               2.0    284300000X
# 30396  1336119627    140924362               2.0    284300000X
# 30395  1336119627    132542700               2.0    284300000X
# 30394  1336119627    125171740               2.0    284300000X
# 30393  1336119627    122892853               2.0    284300000X
# ...           ...          ...               ...           ...
# 10993  1265445506     74413116               2.0    282N00000X
# 10992  1265445506     74413113               2.0    282N00000X
# 10991  1265445506     72681241               2.0    282N00000X
# 10989  1265445506     67595932               2.0    282N00000X
# 11069  1265445506    134245451               2.0    282N00000X
#
#                     Classification Specialization  \
# 30398             Special Hospital           None
# 30396             Special Hospital           None
# 30395             Special Hospital           None
# 30394             Special Hospital           None
# 30393             Special Hospital           None
# ...                            ...            ...
# 10993  General Acute Care Hospital           None
# 10992  General Acute Care Hospital           None
# 10991  General Acute Care Hospital           None
# 10989  General Acute Care Hospital           None
# 11069  General Acute Care Hospital           None
#
#                               organization            address_line1  \
# 30398    BAPTIST WOMEN'S HEALTH CENTER LLC  2011 MURPHY AVE STE 400
# 30396    BAPTIST WOMEN'S HEALTH CENTER LLC  2011 MURPHY AVE STE 400
# 30395    BAPTIST WOMEN'S HEALTH CENTER LLC  2011 MURPHY AVE STE 400
# 30394    BAPTIST WOMEN'S HEALTH CENTER LLC  2011 MURPHY AVE STE 400
# 30393    BAPTIST WOMEN'S HEALTH CENTER LLC  2011 MURPHY AVE STE 400
# ...                                    ...                      ...
# 10993  WILLIAMSON COUNTY HOSPITAL DISTRICT   4321 CAROTHERS PARKWAY
# 10992  WILLIAMSON COUNTY HOSPITAL DISTRICT   4321 CAROTHERS PARKWAY
# 10991  WILLIAMSON COUNTY HOSPITAL DISTRICT   4321 CAROTHERS PARKWAY
# 10989  WILLIAMSON COUNTY HOSPITAL DISTRICT   4321 CAROTHERS PARKWAY
# 11069  WILLIAMSON COUNTY HOSPITAL DISTRICT   4321 CAROTHERS PARKWAY
#
#       address_line2       city state    zip
# 30398          None  NASHVILLE    TN  37203
# 30396          None  NASHVILLE    TN  37203
# 30395          None  NASHVILLE    TN  37203
# 30394          None  NASHVILLE    TN  37203
# 30393          None  NASHVILLE    TN  37203
# ...             ...        ...   ...    ...
# 10993          None   FRANKLIN    TN  37067
# 10992          None   FRANKLIN    TN  37067
# 10991          None   FRANKLIN    TN  37067
# 10989          None   FRANKLIN    TN  37067
# 11069          None   FRANKLIN    TN  37067
#
# [7254 rows x 12 columns]

# %%
#build full address, add to dfs

def build_address(df):
    address = ((df['address_line1'] + ', ' + df['address_line2']).mask(pd.isna, df['address_line1'])
         + ', ' 
         + df['city'] 
         + ', ' 
         + df['state']
         + ' '
         + df['zip']
    )
    return address

# %%
build_address(hospitals)
# Out:
# 30398    2011 MURPHY AVE STE 400, NASHVILLE, TN 37203
# 30396    2011 MURPHY AVE STE 400, NASHVILLE, TN 37203
# 30395    2011 MURPHY AVE STE 400, NASHVILLE, TN 37203
# 30394    2011 MURPHY AVE STE 400, NASHVILLE, TN 37203
# 30393    2011 MURPHY AVE STE 400, NASHVILLE, TN 37203
#                              ...
# 10993      4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067
# 10992      4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067
# 10991      4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067
# 10989      4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067
# 11069      4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067
# Length: 7254, dtype: object

# %%
providers['address'] = build_address(providers)
hospitals['address'] = build_address(hospitals)
gach['address'] = build_address(gach)

# %%
#Combine relevant dfs to make full_refs

full_refs = (providers.merge(gach, 
                on = 'referral_id',
               suffixes = ('_provider', '_hospital'))
          .merge(referrals,
                on = ['referral_id', 'from_npi', 'to_npi'])
)

full_refs
# Out:
#         from_npi  referral_id  entity_type_code_provider  \
# 0     1548466808      9550017                        1.0
# 1     1558355941      9550019                        1.0
# 2     1790891315     13457790                        1.0
# 3     1053366369     20389882                        1.0
# 4     1043663719     20389883                        1.0
# ...          ...          ...                        ...
# 6870  1174565543    167471199                        1.0
# 6871  1942254883    174721235                        1.0
# 6872  1194751354    181082032                        1.0
# 6873  1194743914    181082033                        1.0
# 6874  1265589139    196663623                        1.0
#
#                       name taxonomy_code_provider  \
# 0           JONES, MATTHEW             2085R0202X
# 1             JOSEPH, JOJU             207RN0300X
# 2            RUSSO, DONALD             207RC0000X
# 3            NABORS, GLENN             2085R0202X
# 4     GUSTAFSON, STEPHANIE             367500000X
# ...                    ...                    ...
# 6870           DOSS, HABIB             207RH0003X
# 6871       BURCHAM, ROBERT             2085R0202X
# 6872        PEACOCK, NANCY             207RX0202X
# 6873       PENLEY, WILLIAM             207RX0202X
# 6874            NICK, ALPA             207VX0201X
#
#                       Classification_provider Specialization_provider  \
# 0                                   Radiology    Diagnostic Radiology
# 1                           Internal Medicine              Nephrology
# 2                           Internal Medicine  Cardiovascular Disease
# 3                                   Radiology    Diagnostic Radiology
# 4     Nurse Anesthetist, Certified Registered                    None
# ...                                       ...                     ...
# 6870                        Internal Medicine   Hematology & Oncology
# 6871                                Radiology    Diagnostic Radiology
# 6872                        Internal Medicine        Medical Oncology
# 6873                        Internal Medicine        Medical Oncology
# 6874                  Obstetrics & Gynecology    Gynecologic Oncology
#
#      organization_provider     address_line1_provider address_line2_provider  \
# 0                     None             1265 UNION AVE                   None
# 1                     None       270 EAST MAIN STREET              SUITE 200
# 2                     None  353 NEW SHACKLE ISLAND RD                  #300C
# 3                     None        620 HARTSVILLE PIKE                   None
# 4                     None             110 29TH AVE N              SUITE 201
# ...                    ...                        ...                    ...
# 6870                  None      2004 HAYES ST STE 350                   None
# 6871                  None     3024 BUSINESS PARK CIR                   None
# 6872                  None      2004 HAYES ST STE 350                   None
# 6873                  None      2004 HAYES ST STE 350                   None
# 6874                  None      2004 HAYES ST STE 350                   None
#
#       ... address_line1_hospital address_line2_hospital city_hospital  \
# 0     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 1     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 2     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 3     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 4     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# ...   ...                    ...                    ...           ...
# 6870  ...         2000 CHURCH ST                   None     NASHVILLE
# 6871  ...         2000 CHURCH ST                   None     NASHVILLE
# 6872  ...         2000 CHURCH ST                   None     NASHVILLE
# 6873  ...         2000 CHURCH ST                   None     NASHVILLE
# 6874  ...         2000 CHURCH ST                   None     NASHVILLE
#
#      state_hospital  zip_hospital                         address_hospital  \
# 0                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 1                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 2                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 3                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 4                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# ...             ...           ...                                      ...
# 6870             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 6871             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 6872             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 6873             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 6874             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
#
#      patient_count transaction_count average_day_wait std_day_wait
# 0              121               135           32.563       62.417
# 1               81               292            6.767       30.330
# 2               70                71           47.254       75.620
# 3              141               154           38.636       68.659
# 4               71                73            5.808       21.015
# ...            ...               ...              ...          ...
# 6870            69               143            3.273       26.756
# 6871            52                65           13.154       32.501
# 6872            37                64           12.641       38.231
# 6873            43                69           23.420       48.484
# 6874            31                67            0.313        2.566
#
# [6875 rows x 30 columns]

# %%
#Combining relevant dfs to make full_refs_hosp

full_refs_hosp = (providers.merge(hospitals, 
                on = 'referral_id',
               suffixes = ('_provider', '_hospital'))
          .merge(referrals,
                on = ['referral_id', 'from_npi', 'to_npi'])
)

full_refs_hosp
# Out:
#         from_npi  referral_id  entity_type_code_provider  \
# 0     1548466808      9550017                        1.0
# 1     1558355941      9550019                        1.0
# 2     1790891315     13457790                        1.0
# 3     1053366369     20389882                        1.0
# 4     1043663719     20389883                        1.0
# ...          ...          ...                        ...
# 7249  1174565543    167471199                        1.0
# 7250  1942254883    174721235                        1.0
# 7251  1194751354    181082032                        1.0
# 7252  1194743914    181082033                        1.0
# 7253  1265589139    196663623                        1.0
#
#                       name taxonomy_code_provider  \
# 0           JONES, MATTHEW             2085R0202X
# 1             JOSEPH, JOJU             207RN0300X
# 2            RUSSO, DONALD             207RC0000X
# 3            NABORS, GLENN             2085R0202X
# 4     GUSTAFSON, STEPHANIE             367500000X
# ...                    ...                    ...
# 7249           DOSS, HABIB             207RH0003X
# 7250       BURCHAM, ROBERT             2085R0202X
# 7251        PEACOCK, NANCY             207RX0202X
# 7252       PENLEY, WILLIAM             207RX0202X
# 7253            NICK, ALPA             207VX0201X
#
#                       Classification_provider Specialization_provider  \
# 0                                   Radiology    Diagnostic Radiology
# 1                           Internal Medicine              Nephrology
# 2                           Internal Medicine  Cardiovascular Disease
# 3                                   Radiology    Diagnostic Radiology
# 4     Nurse Anesthetist, Certified Registered                    None
# ...                                       ...                     ...
# 7249                        Internal Medicine   Hematology & Oncology
# 7250                                Radiology    Diagnostic Radiology
# 7251                        Internal Medicine        Medical Oncology
# 7252                        Internal Medicine        Medical Oncology
# 7253                  Obstetrics & Gynecology    Gynecologic Oncology
#
#      organization_provider     address_line1_provider address_line2_provider  \
# 0                     None             1265 UNION AVE                   None
# 1                     None       270 EAST MAIN STREET              SUITE 200
# 2                     None  353 NEW SHACKLE ISLAND RD                  #300C
# 3                     None        620 HARTSVILLE PIKE                   None
# 4                     None             110 29TH AVE N              SUITE 201
# ...                    ...                        ...                    ...
# 7249                  None      2004 HAYES ST STE 350                   None
# 7250                  None     3024 BUSINESS PARK CIR                   None
# 7251                  None      2004 HAYES ST STE 350                   None
# 7252                  None      2004 HAYES ST STE 350                   None
# 7253                  None      2004 HAYES ST STE 350                   None
#
#       ... address_line1_hospital address_line2_hospital city_hospital  \
# 0     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 1     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 2     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 3     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# 4     ...    555 HARTSVILLE PIKE                   None      GALLATIN
# ...   ...                    ...                    ...           ...
# 7249  ...         2000 CHURCH ST                   None     NASHVILLE
# 7250  ...         2000 CHURCH ST                   None     NASHVILLE
# 7251  ...         2000 CHURCH ST                   None     NASHVILLE
# 7252  ...         2000 CHURCH ST                   None     NASHVILLE
# 7253  ...         2000 CHURCH ST                   None     NASHVILLE
#
#      state_hospital  zip_hospital                         address_hospital  \
# 0                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 1                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 2                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 3                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# 4                TN         37066  555 HARTSVILLE PIKE, GALLATIN, TN 37066
# ...             ...           ...                                      ...
# 7249             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 7250             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 7251             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 7252             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
# 7253             TN         37236      2000 CHURCH ST, NASHVILLE, TN 37236
#
#      patient_count transaction_count average_day_wait std_day_wait
# 0              121               135           32.563       62.417
# 1               81               292            6.767       30.330
# 2               70                71           47.254       75.620
# 3              141               154           38.636       68.659
# 4               71                73            5.808       21.015
# ...            ...               ...              ...          ...
# 7249            69               143            3.273       26.756
# 7250            52                65           13.154       32.501
# 7251            37                64           12.641       38.231
# 7252            43                69           23.420       48.484
# 7253            31                67            0.313        2.566
#
# [7254 rows x 30 columns]

# %%
#list of hospitals in the dataset
full_refs_hosp['organization_hospital'].unique()
# Out:
# array(['SUMNER REGIONAL HEALTH SYSTEMS, INC',
#        'SUMNER REGIONAL MEDICAL CENTER LLC',
#        'WILLIAMSON COUNTY HOSPITAL DISTRICT',
#        'ROLLING HILLS HOSPITAL LLC',
#        'ENCOMPASS HEALTH REHABILITATION HOSPITAL OF FRANKLIN, LLC',
#        'HENDERSONVILLE HOSPITAL CORPORATION', 'TRUSTPOINT HOSPITAL, LLC',
#        'SAINT THOMAS RUTHERFORD HOSPITAL',
#        'HCA HEALTH SERVICES OF TENNESSEE, INC.',
#        "BAPTIST WOMEN'S HEALTH CENTER LLC", 'SAINT THOMAS WEST HOSPITAL',
#        'HTI MEMORIAL HOSPITAL CORPORATION',
#        'MIDDLE TENNESSEE HOSPITALIST', 'NASHVILLE GENERAL HOSPITAL',
#        'VANDERBILT STALLWORTH REHABILITATION HOSPITAL LP',
#        'VANDERBILT UNIVERSITY MEDICAL CENTER',
#        'STATE OF TENNESSEE STATE F&A PAYROLL',
#        'CRESCENT MEDICAL GROUP PLLC', 'CURAHEALTH NASHVILLE, LLC',
#        'SELECT SPECIALTY HOSPITAL - NASHVILLE LLC', 'SETON CORPORATION'],
#       dtype=object)

# %%
#list of doctors referring patients to TriStar Centennial Medical Center

HCA=full_refs_hosp[full_refs_hosp['organization_hospital']== 'HCA HEALTH SERVICES OF TENNESSEE, INC.']
HCA.nlargest(40, 'patient_count')
# Out:
#         from_npi  referral_id  entity_type_code_provider               name  \
# 1823  1093753303     29474231                        1.0       WELCH, DEREK
# 2476  1417131715    217106230                        1.0      RIDDICK, JOHN
# 3876  1093753303    149736850                        1.0       WELCH, DEREK
# 1595  1093753303    150281402                        1.0       WELCH, DEREK
# 2082  1902823859     95264287                        1.0   HUNEYCUTT, DAVID
# 2213  1750410452    142389439                        1.0      YOUNG, ROBERT
# 1830  1558461970     30764459                        1.0   WHEATLEY, ROBERT
# 2275  1144283896    160175351                        1.0   TEPPER, PATRICIA
# 3882  1114961513    155535969                        1.0   HUMPHREY, STEVEN
# 2248  1114101128    152119863                        1.0       PATEL, PARAG
# 1881  1437136827     42787970                        1.0    WEAVER, GREGORY
# 2094  1912984758     98833187                        1.0  LASSITER, GREGORY
# 1920  1306993282     55525652                        1.0     SHIPMAN, JASON
# 2134  1023103462    112681115                        1.0   JOHNSTON, THOMAS
# 1619  1932274503    172820629                        1.0     CABELL, THOMAS
# 2201  1871548818    137486106                        1.0     KLEIN, WILLIAM
# 2363  1235242181    188884240                        1.0    WEBBER, JEFFREY
# 1945  1326023789     59338080                        1.0       MOYERS, JOHN
# 1887  1447234141     44774298                        1.0     CAPLAN, STUART
# 2046  1639226582     87393339                        1.0     PIERRE, KETSIA
# 1787  1821060526     18880182                        1.0     WATERS, RONALD
# 2458  1396721106    213201178                        1.0      BERGER, BRIAN
# 2440  1376756742    209858506                        1.0  GRIFFIN, BENJAMIN
# 2012  1508830407     77893523                        1.0   JEFFERSON, BRIAN
# 2473  1407833825    215258247                        1.0       BARTEK, JOHN
# 2187  1851478747    133817899                        1.0   PANZEGRAU, BEATA
# 1751  1790776672     12919012                        1.0     MALIK, FURRUKH
# 1754  1790730448     12919018                        1.0    STAFFORD, JAMES
# 1611  1164504544    165554491                        1.0   MANGIONE, NELSON
# 2023  1609014489     79630330                        1.0     BACON, WILLIAM
# 2378  1245449982    190718715                        1.0    MURPHY, PATRICK
# 2113  1689617433    106778084                        1.0      MASSIE, JAMES
# 2463  1396707923    213201216                        1.0         HORN, ALAN
# 1804  1073557831     25541772                        1.0  MEYEROWITZ, COLIN
# 1792  1043522311     19871513                        1.0        LONG, SCOTT
# 1992  1487934584     73919845                        1.0      BARRAZA, JOHN
# 1543  1487816948     75916219                        1.0    PATTERSON, GARY
# 2459  1396729091    213201179                        1.0        GRAY, SCOTT
# 1793  1053406405     19871523                        1.0      MCRAE, ANDREW
# 2217  1760478192    144252463                        1.0      LEWIS, THOMAS
#
#      taxonomy_code_provider Classification_provider  \
# 1823             207ZP0102X               Pathology
# 2476             207RI0011X       Internal Medicine
# 3876             207ZP0102X               Pathology
# 1595             207ZP0102X               Pathology
# 2082             207RC0000X       Internal Medicine
# 2213             2085R0204X               Radiology
# 1830             207RI0011X       Internal Medicine
# 2275             2085R0202X               Radiology
# 3882             207RC0000X       Internal Medicine
# 2248             207R00000X       Internal Medicine
# 1881             2085R0202X               Radiology
# 2094             2085R0202X               Radiology
# 1920             2085R0202X               Radiology
# 2134             207RA0001X       Internal Medicine
# 1619             207RC0000X       Internal Medicine
# 2201             2085R0202X               Radiology
# 2363             207RC0000X       Internal Medicine
# 1945             2085R0202X               Radiology
# 1887             2085R0202X               Radiology
# 2046             2085R0202X               Radiology
# 1787             2085R0202X               Radiology
# 2458             2085R0202X               Radiology
# 2440             2085R0202X               Radiology
# 2012             207RI0011X       Internal Medicine
# 2473             2085R0202X               Radiology
# 2187             2085R0202X               Radiology
# 1751             207RC0000X       Internal Medicine
# 1754             2085R0202X               Radiology
# 1611             207RC0000X       Internal Medicine
# 2023             2085R0202X               Radiology
# 2378             2085R0202X               Radiology
# 2113             2085R0202X               Radiology
# 2463             2085R0202X               Radiology
# 1804             2085R0202X               Radiology
# 1792             2085R0202X               Radiology
# 1992             2085R0202X               Radiology
# 1543             2085R0202X               Radiology
# 2459             2085R0202X               Radiology
# 1793             207RA0001X       Internal Medicine
# 2217             207RG0100X       Internal Medicine
#
#                                Specialization_provider organization_provider  \
# 1823           Anatomic Pathology & Clinical Pathology                  None
# 2476                         Interventional Cardiology                  None
# 3876           Anatomic Pathology & Clinical Pathology                  None
# 1595           Anatomic Pathology & Clinical Pathology                  None
# 2082                            Cardiovascular Disease                  None
# 2213               Vascular & Interventional Radiology                  None
# 1830                         Interventional Cardiology                  None
# 2275                              Diagnostic Radiology                  None
# 3882                            Cardiovascular Disease                  None
# 2248                                              None                  None
# 1881                              Diagnostic Radiology                  None
# 2094                              Diagnostic Radiology                  None
# 1920                              Diagnostic Radiology                  None
# 2134  Advanced Heart Failure and Transplant Cardiology                  None
# 1619                            Cardiovascular Disease                  None
# 2201                              Diagnostic Radiology                  None
# 2363                            Cardiovascular Disease                  None
# 1945                              Diagnostic Radiology                  None
# 1887                              Diagnostic Radiology                  None
# 2046                              Diagnostic Radiology                  None
# 1787                              Diagnostic Radiology                  None
# 2458                              Diagnostic Radiology                  None
# 2440                              Diagnostic Radiology                  None
# 2012                         Interventional Cardiology                  None
# 2473                              Diagnostic Radiology                  None
# 2187                              Diagnostic Radiology                  None
# 1751                            Cardiovascular Disease                  None
# 1754                              Diagnostic Radiology                  None
# 1611                            Cardiovascular Disease                  None
# 2023                              Diagnostic Radiology                  None
# 2378                              Diagnostic Radiology                  None
# 2113                              Diagnostic Radiology                  None
# 2463                              Diagnostic Radiology                  None
# 1804                              Diagnostic Radiology                  None
# 1792                              Diagnostic Radiology                  None
# 1992                              Diagnostic Radiology                  None
# 1543                              Diagnostic Radiology                  None
# 2459                              Diagnostic Radiology                  None
# 1793  Advanced Heart Failure and Transplant Cardiology                  None
# 2217                                  Gastroenterology                  None
#
#            address_line1_provider address_line2_provider  ...  \
# 1823            5301 VIRGINIA WAY              SUITE 300  ...
# 2476            2400 PATTERSON ST              SUITE 502  ...
# 3876            5301 VIRGINIA WAY              SUITE 300  ...
# 1595            5301 VIRGINIA WAY              SUITE 300  ...
# 2082            2400 PATTERSON ST              SUITE 502  ...
# 2213      210 25TH AVE N STE 1204                   None  ...
# 1830            2400 PATTERSON ST              SUITE 502  ...
# 2275               210 25TH AVE N              SUITE 602  ...
# 3882   3601 THE VANDERBILT CLINIC                   None  ...
# 2248            2400 PATTERSON ST                STE 502  ...
# 1881       210 25TH AVE N STE 602                   None  ...
# 2094      210 25TH AVE N STE 1204                   None  ...
# 1920      210 25TH AVE N STE 1204                   None  ...
# 2134            2400 PATTERSON ST              SUITE 502  ...
# 1619  300 STONECREST BLVD STE 410                   None  ...
# 2201      210 25TH AVE N STE 1204                   None  ...
# 2363            2400 PATTERSON ST              SUITE 304  ...
# 1945      210 25TH AVE N STE 1204                   None  ...
# 1887      210 25TH AVE N STE 1204                   None  ...
# 2046      210 25TH AVE N STE 1204                   None  ...
# 1787      210 25TH AVE N STE 1204                   None  ...
# 2458      210 25TH AVE N STE 1204                   None  ...
# 2440      210 25TH AVE N STE 1204                   None  ...
# 2012            2400 PATTERSON ST              SUITE 502  ...
# 2473               210 25TH AVE N                STE 602  ...
# 2187      210 25TH AVE N STE 1204                   None  ...
# 1751            2400 PATTERSON ST              SUITE 218  ...
# 1754      210 25TH AVE N STE 1204                   None  ...
# 1611          300 STONECREST BLVD              SUITE 410  ...
# 2023      210 25TH AVE N STE 1204                   None  ...
# 2378      210 25TH AVE N STE 1204                   None  ...
# 2113      210 25TH AVE N STE 1204                   None  ...
# 2463      210 25TH AVE N STE 1204                   None  ...
# 1804      210 25TH AVE N STE 1204                   None  ...
# 1792      210 25TH AVE N STE 1204                   None  ...
# 1992           5000 HENNESSY BLVD                   None  ...
# 1543      210 25TH AVE N STE 1204                   None  ...
# 2459      210 25TH AVE N STE 1204                   None  ...
# 1793            2400 PATTERSON ST              SUITE 502  ...
# 2217            2400 PATTERSON ST              SUITE 400  ...
#
#      address_line1_hospital address_line2_hospital city_hospital  \
# 1823      2300 PATTERSON ST                   None     NASHVILLE
# 2476      2300 PATTERSON ST                   None     NASHVILLE
# 3876         391 WALLACE RD                   None     NASHVILLE
# 1595    200 STONECREST BLVD                   None        SMYRNA
# 2082      2300 PATTERSON ST                   None     NASHVILLE
# 2213      2300 PATTERSON ST                   None     NASHVILLE
# 1830      2300 PATTERSON ST                   None     NASHVILLE
# 2275      2300 PATTERSON ST                   None     NASHVILLE
# 3882         391 WALLACE RD                   None     NASHVILLE
# 2248      2300 PATTERSON ST                   None     NASHVILLE
# 1881      2300 PATTERSON ST                   None     NASHVILLE
# 2094      2300 PATTERSON ST                   None     NASHVILLE
# 1920      2300 PATTERSON ST                   None     NASHVILLE
# 2134      2300 PATTERSON ST                   None     NASHVILLE
# 1619    200 STONECREST BLVD                   None        SMYRNA
# 2201      2300 PATTERSON ST                   None     NASHVILLE
# 2363      2300 PATTERSON ST                   None     NASHVILLE
# 1945      2300 PATTERSON ST                   None     NASHVILLE
# 1887      2300 PATTERSON ST                   None     NASHVILLE
# 2046      2300 PATTERSON ST                   None     NASHVILLE
# 1787      2300 PATTERSON ST                   None     NASHVILLE
# 2458      2300 PATTERSON ST                   None     NASHVILLE
# 2440      2300 PATTERSON ST                   None     NASHVILLE
# 2012      2300 PATTERSON ST                   None     NASHVILLE
# 2473      2300 PATTERSON ST                   None     NASHVILLE
# 2187      2300 PATTERSON ST                   None     NASHVILLE
# 1751      2300 PATTERSON ST                   None     NASHVILLE
# 1754      2300 PATTERSON ST                   None     NASHVILLE
# 1611    200 STONECREST BLVD                   None        SMYRNA
# 2023      2300 PATTERSON ST                   None     NASHVILLE
# 2378      2300 PATTERSON ST                   None     NASHVILLE
# 2113      2300 PATTERSON ST                   None     NASHVILLE
# 2463      2300 PATTERSON ST                   None     NASHVILLE
# 1804      2300 PATTERSON ST                   None     NASHVILLE
# 1792      2300 PATTERSON ST                   None     NASHVILLE
# 1992      2300 PATTERSON ST                   None     NASHVILLE
# 1543    200 STONECREST BLVD                   None        SMYRNA
# 2459      2300 PATTERSON ST                   None     NASHVILLE
# 1793      2300 PATTERSON ST                   None     NASHVILLE
# 2217      2300 PATTERSON ST                   None     NASHVILLE
#
#      state_hospital  zip_hospital                        address_hospital  \
# 1823             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2476             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 3876             TN         37211     391 WALLACE RD, NASHVILLE, TN 37211
# 1595             TN         37167   200 STONECREST BLVD, SMYRNA, TN 37167
# 2082             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2213             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1830             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2275             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 3882             TN         37211     391 WALLACE RD, NASHVILLE, TN 37211
# 2248             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1881             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2094             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1920             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2134             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1619             TN         37167   200 STONECREST BLVD, SMYRNA, TN 37167
# 2201             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2363             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1945             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1887             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2046             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1787             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2458             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2440             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2012             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2473             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2187             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1751             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1754             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1611             TN         37167   200 STONECREST BLVD, SMYRNA, TN 37167
# 2023             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2378             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2113             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2463             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1804             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1792             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1992             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1543             TN         37167   200 STONECREST BLVD, SMYRNA, TN 37167
# 2459             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 1793             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
# 2217             TN         37203  2300 PATTERSON ST, NASHVILLE, TN 37203
#
#      patient_count transaction_count average_day_wait std_day_wait
# 1823          9196             16819            9.041       32.187
# 2476          5571              9007            0.578        8.745
# 3876          2610              5166            8.390       30.802
# 1595          2060              3436           15.872       37.309
# 2082          1935              2974            4.444       20.451
# 2213          1663              2079            2.392       17.119
# 1830          1634              2401            2.257       15.758
# 2275          1501              1692            4.113       22.752
# 3882          1487              2878            6.929       27.265
# 2248          1378              2042            1.769       14.410
# 1881          1369              1556            9.722       37.087
# 2094          1364              1480           17.103       46.204
# 1920          1340              1527            9.624       31.216
# 2134          1280              2264            4.680       22.656
# 1619          1276              2074            5.768       23.561
# 2201          1247              1371           18.233       46.143
# 2363          1102              1907            6.228       24.698
# 1945          1081              1201           19.886       48.030
# 1887          1042              1084           19.482       50.219
# 2046          1033              1128            2.207       17.125
# 1787          1032              1105           18.254       49.258
# 2458           989              1067           15.041       42.159
# 2440           969              1057           18.618       45.453
# 2012           936              1485            7.036       28.591
# 2473           936               998           14.573       43.406
# 2187           927               961           19.045       50.871
# 1751           915              1543            4.593       21.092
# 1754           905               948           20.194       48.370
# 1611           901              1452            7.552       28.191
# 2023           898              1074            2.835       19.457
# 2378           869               951           13.891       40.851
# 2113           865               921           18.822       50.077
# 2463           856               891           19.474       51.204
# 1804           823               880           20.870       48.836
# 1792           822               890           16.342       43.764
# 1992           816               930           12.510       42.252
# 1543           800               938            2.323       18.751
# 2459           783               817           16.043       46.564
# 1793           757              1777            5.258       22.562
# 2217           743              1385            4.061       20.047
#
# [40 rows x 30 columns]

# %%
#top 20 taxonomies (classification/specialization) referring patients 

(full_refs.groupby(['taxonomy_code_provider', 'Classification_provider', 'Specialization_provider'])
     ['patient_count']
     .sum()
     .sort_values(ascending = False)
     .nlargest(20)
)
# Out:
# taxonomy_code_provider  Classification_provider  Specialization_provider
# 2085R0202X              Radiology                Diagnostic Radiology                                302876
# 207RC0000X              Internal Medicine        Cardiovascular Disease                              126991
# 207ZP0102X              Pathology                Anatomic Pathology & Clinical Pathology              49194
# 363LF0000X              Nurse Practitioner       Family                                               30923
# 207RP1001X              Internal Medicine        Pulmonary Disease                                    26743
# 207RN0300X              Internal Medicine        Nephrology                                           26353
# 363LA2100X              Nurse Practitioner       Acute Care                                           21791
# 207RG0100X              Internal Medicine        Gastroenterology                                     21705
# 207RI0011X              Internal Medicine        Interventional Cardiology                            20002
# 2084N0400X              Psychiatry & Neurology   Neurology                                            18003
# 207RH0003X              Internal Medicine        Hematology & Oncology                                17565
# 207RC0001X              Internal Medicine        Clinical Cardiac Electrophysiology                   14103
# 207RX0202X              Internal Medicine        Medical Oncology                                     11598
# 207RE0101X              Internal Medicine        Endocrinology, Diabetes & Metabolism                 10308
# 363LA2200X              Nurse Practitioner       Adult Health                                          9706
# 207RA0001X              Internal Medicine        Advanced Heart Failure and Transplant Cardiology      9178
# 2086S0129X              Surgery                  Vascular Surgery                                      8033
# 207RI0200X              Internal Medicine        Infectious Disease                                    7843
# 2085R0204X              Radiology                Vascular & Interventional Radiology                   7594
# 2084P0800X              Psychiatry & Neurology   Psychiatry                                            7428
# Name: patient_count, dtype: int64

# %%
#dataframe showing if the referral is to vanderbilt or not 

def make_not_to_vandy(df, group):

    # create a column that labels whether the recommendation went to Vanderbilt or not
    df['to_vandy'] = df['organization_hospital'].str.contains("VANDERBILT")

    # for each specialty, determine the count of patients recommended to and not recommended to Vanderbilt
    to_vandy = (df.groupby(group + ['to_vandy'])
         ['patient_count']
         .sum()
         .reset_index()
    )

    # add a column for overall count of referrals by specialty, then determine proportion
    # of referrals to Vanderbilt vs proportion not to Vanderbilt
    to_vandy['patient_count_overall'] = (to_vandy.groupby(group)
                                     ['patient_count']
                                     .transform(sum)
                                    )
    to_vandy['patient_prop'] = round((to_vandy['patient_count']/
                                     to_vandy['patient_count_overall']
                                    ), 2)

    # filter to focus just on referrals not to Vanderbilt
    not_to_vandy = to_vandy[to_vandy['to_vandy'] == False]
    
    return not_to_vandy.sort_values('patient_count', ascending = False)

# %%
#top 25 specialties not referring to vandy

spec_not_to_vandy = make_not_to_vandy(full_refs, ['taxonomy_code_provider', 'Classification_provider', 'Specialization_provider'])

spec_not_to_vandy.nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider Classification_provider  \
# 141             2085R0202X               Radiology
# 35              207RC0000X       Internal Medicine
# 101             207ZP0102X               Pathology
# 61              207RP1001X       Internal Medicine
# 55              207RI0011X       Internal Medicine
# 184             363LF0000X      Nurse Practitioner
# 59              207RN0300X       Internal Medicine
# 43              207RG0100X       Internal Medicine
# 37              207RC0001X       Internal Medicine
# 120             2084N0400X  Psychiatry & Neurology
# 178             363LA2100X      Nurse Practitioner
# 51              207RH0003X       Internal Medicine
# 68              207RX0202X       Internal Medicine
# 144             2085R0204X               Radiology
# 32              207RA0001X       Internal Medicine
# 154             2086S0129X                 Surgery
# 57              207RI0200X       Internal Medicine
# 12              207LC0200X          Anesthesiology
# 41              207RE0101X       Internal Medicine
# 180             363LA2200X      Nurse Practitioner
# 124             2084P0800X  Psychiatry & Neurology
# 166             213ES0103X              Podiatrist
# 19              207PE0004X      Emergency Medicine
# 174             363AM0700X     Physician Assistant
# 86              207XS0117X     Orthopaedic Surgery
#
#                               Specialization_provider  to_vandy  \
# 141                              Diagnostic Radiology     False
# 35                             Cardiovascular Disease     False
# 101           Anatomic Pathology & Clinical Pathology     False
# 61                                  Pulmonary Disease     False
# 55                          Interventional Cardiology     False
# 184                                            Family     False
# 59                                         Nephrology     False
# 43                                   Gastroenterology     False
# 37                 Clinical Cardiac Electrophysiology     False
# 120                                         Neurology     False
# 178                                        Acute Care     False
# 51                              Hematology & Oncology     False
# 68                                   Medical Oncology     False
# 144               Vascular & Interventional Radiology     False
# 32   Advanced Heart Failure and Transplant Cardiology     False
# 154                                  Vascular Surgery     False
# 57                                 Infectious Disease     False
# 12                             Critical Care Medicine     False
# 41               Endocrinology, Diabetes & Metabolism     False
# 180                                      Adult Health     False
# 124                                        Psychiatry     False
# 166                              Foot & Ankle Surgery     False
# 19                         Emergency Medical Services     False
# 174                                           Medical     False
# 86                   Orthopaedic Surgery of the Spine     False
#
#      patient_count  patient_count_overall  patient_prop
# 141         230982                 302876          0.76
# 35           68782                 126991          0.54
# 101          39049                  49194          0.79
# 61           21469                  26743          0.80
# 55           17511                  20002          0.88
# 184          17198                  30923          0.56
# 59           16921                  26353          0.64
# 43           14090                  21705          0.65
# 37           10870                  14103          0.77
# 120           8834                  18003          0.49
# 178           8497                  21791          0.39
# 51            7906                  17565          0.45
# 68            6670                  11598          0.58
# 144           6300                   7594          0.83
# 32            6097                   9178          0.66
# 154           5279                   8033          0.66
# 57            4399                   7843          0.56
# 12            4008                   7044          0.57
# 41            3952                  10308          0.38
# 180           3401                   9706          0.35
# 124           3097                   7428          0.42
# 166           3037                   5327          0.57
# 19            2445                   2726          0.90
# 174           2339                   3285          0.71
# 86            2290                   2290          1.00

# %%
# specialties where at least 50% of patients are being referred somewhere other than Vanderbilt
spec_not_to_vandy[spec_not_to_vandy['patient_prop'] >= 0.5].nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider  Classification_provider  \
# 141             2085R0202X                Radiology
# 35              207RC0000X        Internal Medicine
# 101             207ZP0102X                Pathology
# 61              207RP1001X        Internal Medicine
# 55              207RI0011X        Internal Medicine
# 184             363LF0000X       Nurse Practitioner
# 59              207RN0300X        Internal Medicine
# 43              207RG0100X        Internal Medicine
# 37              207RC0001X        Internal Medicine
# 68              207RX0202X        Internal Medicine
# 144             2085R0204X                Radiology
# 32              207RA0001X        Internal Medicine
# 154             2086S0129X                  Surgery
# 57              207RI0200X        Internal Medicine
# 12              207LC0200X           Anesthesiology
# 166             213ES0103X               Podiatrist
# 19              207PE0004X       Emergency Medicine
# 174             363AM0700X      Physician Assistant
# 86              207XS0117X      Orthopaedic Surgery
# 176             363AS0400X      Physician Assistant
# 24              207QG0300X          Family Medicine
# 39              207RC0200X        Internal Medicine
# 89              207XX0005X      Orthopaedic Surgery
# 82              207XS0106X      Orthopaedic Surgery
# 73              207VG0400X  Obstetrics & Gynecology
#
#                               Specialization_provider  to_vandy  \
# 141                              Diagnostic Radiology     False
# 35                             Cardiovascular Disease     False
# 101           Anatomic Pathology & Clinical Pathology     False
# 61                                  Pulmonary Disease     False
# 55                          Interventional Cardiology     False
# 184                                            Family     False
# 59                                         Nephrology     False
# 43                                   Gastroenterology     False
# 37                 Clinical Cardiac Electrophysiology     False
# 68                                   Medical Oncology     False
# 144               Vascular & Interventional Radiology     False
# 32   Advanced Heart Failure and Transplant Cardiology     False
# 154                                  Vascular Surgery     False
# 57                                 Infectious Disease     False
# 12                             Critical Care Medicine     False
# 166                              Foot & Ankle Surgery     False
# 19                         Emergency Medical Services     False
# 174                                           Medical     False
# 86                   Orthopaedic Surgery of the Spine     False
# 176                                          Surgical     False
# 24                                 Geriatric Medicine     False
# 39                             Critical Care Medicine     False
# 89                                    Sports Medicine     False
# 82                                       Hand Surgery     False
# 73                                         Gynecology     False
#
#      patient_count  patient_count_overall  patient_prop
# 141         230982                 302876          0.76
# 35           68782                 126991          0.54
# 101          39049                  49194          0.79
# 61           21469                  26743          0.80
# 55           17511                  20002          0.88
# 184          17198                  30923          0.56
# 59           16921                  26353          0.64
# 43           14090                  21705          0.65
# 37           10870                  14103          0.77
# 68            6670                  11598          0.58
# 144           6300                   7594          0.83
# 32            6097                   9178          0.66
# 154           5279                   8033          0.66
# 57            4399                   7843          0.56
# 12            4008                   7044          0.57
# 166           3037                   5327          0.57
# 19            2445                   2726          0.90
# 174           2339                   3285          0.71
# 86            2290                   2290          1.00
# 176           2095                   2624          0.80
# 24            1743                   1979          0.88
# 39            1467                   1762          0.83
# 89            1327                   2470          0.54
# 82            1169                   2236          0.52
# 73            1143                   1535          0.74

# %%
# specialties where all patients are referred somewhere other than Vanderbilt
spec_not_to_vandy[spec_not_to_vandy['patient_prop'] == 1].nlargest(25, 'patient_count')
# Out:
#     taxonomy_code_provider    Classification_provider  \
# 86              207XS0117X        Orthopaedic Surgery
# 143             2085R0203X                  Radiology
# 149             2086S0105X                    Surgery
# 109             2080P0207X                 Pediatrics
# 197             364SW0102X  Clinical Nurse Specialist
# 21              207QA0401X            Family Medicine
# 9               163WG0600X           Registered Nurse
# 80              207WX0200X              Ophthalmology
# 173             261QP2300X              Clinic/Center
# 7               1223S0112X                    Dentist
#
#                            Specialization_provider  to_vandy  patient_count  \
# 86                Orthopaedic Surgery of the Spine     False           2290
# 143                          Therapeutic Radiology     False            218
# 149                            Surgery of the Hand     False            194
# 109                  Pediatric Hematology-Oncology     False            139
# 197                                 Women's Health     False            135
# 21                              Addiction Medicine     False             81
# 9                                      Gerontology     False             71
# 80   Ophthalmic Plastic and Reconstructive Surgery     False             55
# 173                                   Primary Care     False             55
# 7                   Oral and Maxillofacial Surgery     False             38
#
#      patient_count_overall  patient_prop
# 86                    2290           1.0
# 143                    218           1.0
# 149                    194           1.0
# 109                    139           1.0
# 197                    135           1.0
# 21                      81           1.0
# 9                       71           1.0
# 80                      55           1.0
# 173                     55           1.0
# 7                       38           1.0

# %%
#providers not referring patients to vanderbilt 

#In internal medicine, John Riddick and in pathology, Derek Welch should be reached out by vanderbilt to gain patients. 

prov_not_to_vandy = make_not_to_vandy(full_refs, ['from_npi', 'name', 'Classification_provider', 'Specialization_provider'])
prov_not_to_vandy.nlargest(25, 'patient_count')
# Out:
#         from_npi                name Classification_provider  \
# 199   1093753303        WELCH, DEREK               Pathology
# 1023  1417131715       RIDDICK, JOHN       Internal Medicine
# 306   1134321235       PARIKH, VIRAJ               Radiology
# 97    1043232879    GORDON, JONATHAN               Radiology
# 1798  1710932017  HIMMELFARB, ELLIOT               Radiology
# 2136  1851339634      HARNEY, IANTHA               Radiology
# 1912  1760672026         HAQUE, AMER               Radiology
# 2306  1912984758   LASSITER, GREGORY               Radiology
# 2188  1871548818      KLEIN, WILLIAM               Radiology
# 824   1336189521   WILLIAMS, JEFFREY               Radiology
# 526   1215257670    HUTCHENS, ANDREW               Radiology
# 2375  1942254883     BURCHAM, ROBERT               Radiology
# 756   1306993282      SHIPMAN, JASON               Radiology
# 913   1376756742   GRIFFIN, BENJAMIN               Radiology
# 2069  1821060526      WATERS, RONALD               Radiology
# 1110  1447234141      CAPLAN, STUART               Radiology
# 788   1316977861       PARKER, KEITH               Radiology
# 491   1205070851       PATEL, MANISH               Radiology
# 1639  1649219742     LEVITT, MICHAEL               Radiology
# 1887  1750410452       YOUNG, ROBERT               Radiology
# 983   1396909255       SHABA, STEVEN               Radiology
# 792   1326023789        MOYERS, JOHN               Radiology
# 1224  1487816948     PATTERSON, GARY               Radiology
# 154   1073557831   MEYEROWITZ, COLIN               Radiology
# 34    1013184340       SAVA, MELINDA               Radiology
#
#                       Specialization_provider  to_vandy  patient_count  \
# 199   Anatomic Pathology & Clinical Pathology     False          15506
# 1023                Interventional Cardiology     False           6168
# 306                      Diagnostic Radiology     False           4685
# 97                       Diagnostic Radiology     False           4485
# 1798                     Diagnostic Radiology     False           3601
# 2136                     Diagnostic Radiology     False           3455
# 1912                     Diagnostic Radiology     False           3401
# 2306                     Diagnostic Radiology     False           3371
# 2188                     Diagnostic Radiology     False           3292
# 824                      Diagnostic Radiology     False           3238
# 526                      Diagnostic Radiology     False           3220
# 2375                     Diagnostic Radiology     False           3136
# 756                      Diagnostic Radiology     False           3123
# 913                      Diagnostic Radiology     False           2960
# 2069                     Diagnostic Radiology     False           2785
# 1110                     Diagnostic Radiology     False           2751
# 788                      Diagnostic Radiology     False           2741
# 491                      Diagnostic Radiology     False           2726
# 1639                     Diagnostic Radiology     False           2704
# 1887      Vascular & Interventional Radiology     False           2674
# 983                      Diagnostic Radiology     False           2628
# 792                      Diagnostic Radiology     False           2558
# 1224                     Diagnostic Radiology     False           2542
# 154                      Diagnostic Radiology     False           2496
# 34                       Diagnostic Radiology     False           2469
#
#       patient_count_overall  patient_prop
# 199                   15506           1.0
# 1023                   6168           1.0
# 306                    4685           1.0
# 97                     4485           1.0
# 1798                   3601           1.0
# 2136                   3455           1.0
# 1912                   3401           1.0
# 2306                   3371           1.0
# 2188                   3292           1.0
# 824                    3238           1.0
# 526                    3220           1.0
# 2375                   3136           1.0
# 756                    3123           1.0
# 913                    2960           1.0
# 2069                   2785           1.0
# 1110                   2751           1.0
# 788                    2741           1.0
# 491                    2726           1.0
# 1639                   2704           1.0
# 1887                   2674           1.0
# 983                    2628           1.0
# 792                    2558           1.0
# 1224                   2542           1.0
# 154                    2496           1.0
# 34                     2469           1.0

# %%
prov_not_to_vandy[prov_not_to_vandy['Specialization_provider'] != 'Diagnostic Radiology'].nlargest(25, 'patient_count')
# Out:
#         from_npi                 name Classification_provider  \
# 199   1093753303         WELCH, DEREK               Pathology
# 1023  1417131715        RIDDICK, JOHN       Internal Medicine
# 1887  1750410452        YOUNG, ROBERT               Radiology
# 1717  1679689285     CALLISTER, TRACY       Internal Medicine
# 258   1114961513     HUMPHREY, STEVEN       Internal Medicine
# 2265  1902823859     HUNEYCUTT, DAVID       Internal Medicine
# 121   1053337717          KAZA, SUNIL       Internal Medicine
# 1068  1427079946  CONLEY, CHRISTOPHER       Internal Medicine
# 236   1104933738            LEE, JUNG       Internal Medicine
# 2447  1972658060         KETCH, TERRY       Internal Medicine
# 544   1225027014        KUDELKO, PAUL       Internal Medicine
# 33    1013179860           YAWN, GARY       Internal Medicine
# 1403  1558461970     WHEATLEY, ROBERT       Internal Medicine
# 2008  1790891315        RUSSO, DONALD       Internal Medicine
# 2380  1942290333  DICKERSON, REGINALD       Internal Medicine
# 799   1326086653        GRAVES, DANTE       Internal Medicine
# 1001  1407830102    LUSCHEN, MICHELLE               Radiology
# 2348  1932274503       CABELL, THOMAS       Internal Medicine
# 674   1275536468       ASAD, MUHAMMAD       Internal Medicine
# 1655  1649471780        GREENE, ELTON               Radiology
# 2164  1861430621         KEMP, WILSON       Internal Medicine
# 683   1275714958         THOMAS, LANI               Radiology
# 2388  1942429816       ZURICK, ANDREW       Internal Medicine
# 1923  1770519704        GIBSON, DAVID       Internal Medicine
# 238   1104989581         MIXON, JAMES               Pathology
#
#                       Specialization_provider  to_vandy  patient_count  \
# 199   Anatomic Pathology & Clinical Pathology     False          15506
# 1023                Interventional Cardiology     False           6168
# 1887      Vascular & Interventional Radiology     False           2674
# 1717                   Cardiovascular Disease     False           2280
# 258                    Cardiovascular Disease     False           2187
# 2265                   Cardiovascular Disease     False           2163
# 121                    Cardiovascular Disease     False           2119
# 1068       Clinical Cardiac Electrophysiology     False           2070
# 236                    Cardiovascular Disease     False           2049
# 2447                   Cardiovascular Disease     False           2018
# 544                    Cardiovascular Disease     False           1961
# 33                  Interventional Cardiology     False           1899
# 1403                Interventional Cardiology     False           1805
# 2008                   Cardiovascular Disease     False           1803
# 2380                   Cardiovascular Disease     False           1718
# 799                    Cardiovascular Disease     False           1704
# 1001      Vascular & Interventional Radiology     False           1683
# 2348                   Cardiovascular Disease     False           1678
# 674                    Cardiovascular Disease     False           1677
# 1655                           Neuroradiology     False           1622
# 2164                   Cardiovascular Disease     False           1612
# 683       Vascular & Interventional Radiology     False           1534
# 2388                   Cardiovascular Disease     False           1477
# 1923                   Cardiovascular Disease     False           1469
# 238   Anatomic Pathology & Clinical Pathology     False           1442
#
#       patient_count_overall  patient_prop
# 199                   15506          1.00
# 1023                   6168          1.00
# 1887                   2674          1.00
# 1717                   2526          0.90
# 258                    2187          1.00
# 2265                   2163          1.00
# 121                    2119          1.00
# 1068                   2070          1.00
# 236                    2049          1.00
# 2447                   2018          1.00
# 544                    1961          1.00
# 33                     1899          1.00
# 1403                   1805          1.00
# 2008                   1803          1.00
# 2380                   1718          1.00
# 799                    1704          1.00
# 1001                   1683          1.00
# 2348                   1814          0.93
# 674                    1677          1.00
# 1655                   1622          1.00
# 2164                   1776          0.91
# 683                    1534          1.00
# 2388                   1477          1.00
# 1923                   1469          1.00
# 238                    1442          1.00

# %%
not_vandy_doc=prov_not_to_vandy[prov_not_to_vandy['Classification_provider'] != 'Radiology'].nlargest(25, 'patient_count')
not_vandy_doc
# Out:
#         from_npi                 name Classification_provider  \
# 199   1093753303         WELCH, DEREK               Pathology
# 1023  1417131715        RIDDICK, JOHN       Internal Medicine
# 1717  1679689285     CALLISTER, TRACY       Internal Medicine
# 258   1114961513     HUMPHREY, STEVEN       Internal Medicine
# 2265  1902823859     HUNEYCUTT, DAVID       Internal Medicine
# 121   1053337717          KAZA, SUNIL       Internal Medicine
# 1068  1427079946  CONLEY, CHRISTOPHER       Internal Medicine
# 236   1104933738            LEE, JUNG       Internal Medicine
# 2447  1972658060         KETCH, TERRY       Internal Medicine
# 544   1225027014        KUDELKO, PAUL       Internal Medicine
# 33    1013179860           YAWN, GARY       Internal Medicine
# 1403  1558461970     WHEATLEY, ROBERT       Internal Medicine
# 2008  1790891315        RUSSO, DONALD       Internal Medicine
# 2380  1942290333  DICKERSON, REGINALD       Internal Medicine
# 799   1326086653        GRAVES, DANTE       Internal Medicine
# 2348  1932274503       CABELL, THOMAS       Internal Medicine
# 674   1275536468       ASAD, MUHAMMAD       Internal Medicine
# 2164  1861430621         KEMP, WILSON       Internal Medicine
# 2388  1942429816       ZURICK, ANDREW       Internal Medicine
# 1923  1770519704        GIBSON, DAVID       Internal Medicine
# 238   1104989581         MIXON, JAMES               Pathology
# 2397  1952304990       FLEET, WILLIAM       Internal Medicine
# 790   1316985120         ZENKER, MARK       Internal Medicine
# 57    1023103462     JOHNSTON, THOMAS       Internal Medicine
# 1120  1447366075   LIPPOLIS, NICHOLAS       Internal Medicine
#
#                                Specialization_provider  to_vandy  \
# 199            Anatomic Pathology & Clinical Pathology     False
# 1023                         Interventional Cardiology     False
# 1717                            Cardiovascular Disease     False
# 258                             Cardiovascular Disease     False
# 2265                            Cardiovascular Disease     False
# 121                             Cardiovascular Disease     False
# 1068                Clinical Cardiac Electrophysiology     False
# 236                             Cardiovascular Disease     False
# 2447                            Cardiovascular Disease     False
# 544                             Cardiovascular Disease     False
# 33                           Interventional Cardiology     False
# 1403                         Interventional Cardiology     False
# 2008                            Cardiovascular Disease     False
# 2380                            Cardiovascular Disease     False
# 799                             Cardiovascular Disease     False
# 2348                            Cardiovascular Disease     False
# 674                             Cardiovascular Disease     False
# 2164                            Cardiovascular Disease     False
# 2388                            Cardiovascular Disease     False
# 1923                            Cardiovascular Disease     False
# 238            Anatomic Pathology & Clinical Pathology     False
# 2397                            Cardiovascular Disease     False
# 790                             Cardiovascular Disease     False
# 57    Advanced Heart Failure and Transplant Cardiology     False
# 1120                            Cardiovascular Disease     False
#
#       patient_count  patient_count_overall  patient_prop
# 199           15506                  15506          1.00
# 1023           6168                   6168          1.00
# 1717           2280                   2526          0.90
# 258            2187                   2187          1.00
# 2265           2163                   2163          1.00
# 121            2119                   2119          1.00
# 1068           2070                   2070          1.00
# 236            2049                   2049          1.00
# 2447           2018                   2018          1.00
# 544            1961                   1961          1.00
# 33             1899                   1899          1.00
# 1403           1805                   1805          1.00
# 2008           1803                   1803          1.00
# 2380           1718                   1718          1.00
# 799            1704                   1704          1.00
# 2348           1678                   1814          0.93
# 674            1677                   1677          1.00
# 2164           1612                   1776          0.91
# 2388           1477                   1477          1.00
# 1923           1469                   1469          1.00
# 238            1442                   1442          1.00
# 2397           1423                   1423          1.00
# 790            1423                   1423          1.00
# 57             1421                   1421          1.00
# 1120           1221                   1221          1.00

# %%
not_vandy_doc[['name', 'Classification_provider', 'Specialization_provider', 'patient_count']]
# Out:
#                      name Classification_provider  \
# 199          WELCH, DEREK               Pathology
# 1023        RIDDICK, JOHN       Internal Medicine
# 1717     CALLISTER, TRACY       Internal Medicine
# 258      HUMPHREY, STEVEN       Internal Medicine
# 2265     HUNEYCUTT, DAVID       Internal Medicine
# 121           KAZA, SUNIL       Internal Medicine
# 1068  CONLEY, CHRISTOPHER       Internal Medicine
# 236             LEE, JUNG       Internal Medicine
# 2447         KETCH, TERRY       Internal Medicine
# 544         KUDELKO, PAUL       Internal Medicine
# 33             YAWN, GARY       Internal Medicine
# 1403     WHEATLEY, ROBERT       Internal Medicine
# 2008        RUSSO, DONALD       Internal Medicine
# 2380  DICKERSON, REGINALD       Internal Medicine
# 799         GRAVES, DANTE       Internal Medicine
# 2348       CABELL, THOMAS       Internal Medicine
# 674        ASAD, MUHAMMAD       Internal Medicine
# 2164         KEMP, WILSON       Internal Medicine
# 2388       ZURICK, ANDREW       Internal Medicine
# 1923        GIBSON, DAVID       Internal Medicine
# 238          MIXON, JAMES               Pathology
# 2397       FLEET, WILLIAM       Internal Medicine
# 790          ZENKER, MARK       Internal Medicine
# 57       JOHNSTON, THOMAS       Internal Medicine
# 1120   LIPPOLIS, NICHOLAS       Internal Medicine
#
#                                Specialization_provider  patient_count
# 199            Anatomic Pathology & Clinical Pathology          15506
# 1023                         Interventional Cardiology           6168
# 1717                            Cardiovascular Disease           2280
# 258                             Cardiovascular Disease           2187
# 2265                            Cardiovascular Disease           2163
# 121                             Cardiovascular Disease           2119
# 1068                Clinical Cardiac Electrophysiology           2070
# 236                             Cardiovascular Disease           2049
# 2447                            Cardiovascular Disease           2018
# 544                             Cardiovascular Disease           1961
# 33                           Interventional Cardiology           1899
# 1403                         Interventional Cardiology           1805
# 2008                            Cardiovascular Disease           1803
# 2380                            Cardiovascular Disease           1718
# 799                             Cardiovascular Disease           1704
# 2348                            Cardiovascular Disease           1678
# 674                             Cardiovascular Disease           1677
# 2164                            Cardiovascular Disease           1612
# 2388                            Cardiovascular Disease           1477
# 1923                            Cardiovascular Disease           1469
# 238            Anatomic Pathology & Clinical Pathology           1442
# 2397                            Cardiovascular Disease           1423
# 790                             Cardiovascular Disease           1423
# 57    Advanced Heart Failure and Transplant Cardiology           1421
# 1120                            Cardiovascular Disease           1221

# %%
#for family medicine, Donald Vollmer and Raul Couret can be reached out by Vanderbilt to gain patients. 
#However, it might be better to look at specific specialties 

family_medicine=prov_not_to_vandy[prov_not_to_vandy['Classification_provider']=='Family Medicine']
family_medicine
# Out:
#         from_npi                   name Classification_provider  \
# 429   1184612921        VOLLMER, DONALD         Family Medicine
# 753   1306969696           COURET, RAUL         Family Medicine
# 439   1184782740   DOLAPTCHIEV, BOJIDAR         Family Medicine
# 2190  1871565465         HOOPER, HALDEN         Family Medicine
# 511   1205978152     STEUART, CATHERINE         Family Medicine
# 505   1205879467       KELLOGG, MICHAEL         Family Medicine
# 437   1184697898        DOZIER, KENNETH         Family Medicine
# 85    1033343728      COLLINS, KIMBERLY         Family Medicine
# 1522  1598887473  ORUGANTI, NAGA VIJAYA         Family Medicine
# 82    1033316484       KINDRED, JEFFRIE         Family Medicine
# 1797  1710920467        FISHER, TIMOTHY         Family Medicine
# 255   1114916095          AUGUST, LEILA         Family Medicine
#
#               Specialization_provider  to_vandy  patient_count  \
# 429                Geriatric Medicine     False            779
# 753                Geriatric Medicine     False            549
# 439                    Adult Medicine     False            396
# 2190               Geriatric Medicine     False            232
# 511   Hospice and Palliative Medicine     False            189
# 505                    Adult Medicine     False            186
# 437                Geriatric Medicine     False            115
# 85                 Addiction Medicine     False             81
# 1522               Geriatric Medicine     False             68
# 82                    Sports Medicine     False             38
# 1797                   Adult Medicine     False             37
# 255   Hospice and Palliative Medicine     False             33
#
#       patient_count_overall  patient_prop
# 429                     898          0.87
# 753                     615          0.89
# 439                     396          1.00
# 2190                    259          0.90
# 511                     189          1.00
# 505                     219          0.85
# 437                     115          1.00
# 85                       81          1.00
# 1522                     92          0.74
# 82                       38          1.00
# 1797                     37          1.00
# 255                      33          1.00

# %%
family_medicine[['name', 'Classification_provider', 'Specialization_provider', 'patient_count']]
# Out:
#                        name Classification_provider  \
# 429         VOLLMER, DONALD         Family Medicine
# 753            COURET, RAUL         Family Medicine
# 439    DOLAPTCHIEV, BOJIDAR         Family Medicine
# 2190         HOOPER, HALDEN         Family Medicine
# 511      STEUART, CATHERINE         Family Medicine
# 505        KELLOGG, MICHAEL         Family Medicine
# 437         DOZIER, KENNETH         Family Medicine
# 85        COLLINS, KIMBERLY         Family Medicine
# 1522  ORUGANTI, NAGA VIJAYA         Family Medicine
# 82         KINDRED, JEFFRIE         Family Medicine
# 1797        FISHER, TIMOTHY         Family Medicine
# 255           AUGUST, LEILA         Family Medicine
#
#               Specialization_provider  patient_count
# 429                Geriatric Medicine            779
# 753                Geriatric Medicine            549
# 439                    Adult Medicine            396
# 2190               Geriatric Medicine            232
# 511   Hospice and Palliative Medicine            189
# 505                    Adult Medicine            186
# 437                Geriatric Medicine            115
# 85                 Addiction Medicine             81
# 1522               Geriatric Medicine             68
# 82                    Sports Medicine             38
# 1797                   Adult Medicine             37
# 255   Hospice and Palliative Medicine             33

# %%
prov_not_to_vandy[prov_not_to_vandy['Specialization_provider']=='Orthopedic']
# Out:
#         from_npi            name Classification_provider  \
# 1604  1629320130  LAY, NATHANIEL      Physical Therapist
#
#      Specialization_provider  to_vandy  patient_count  patient_count_overall  \
# 1604              Orthopedic     False             47                     47
#
#       patient_prop
# 1604           1.0

# %%
#list of orthopedic surgeons vanderbilt should reach out to gain patients 

ortho=prov_not_to_vandy[prov_not_to_vandy['Classification_provider']=='Orthopaedic Surgery']
ortho
# Out:
#         from_npi                   name Classification_provider  \
# 117   1053308502          KLEKAMP, JOHN     Orthopaedic Surgery
# 170   1083601397      MCNAMARA, MICHAEL     Orthopaedic Surgery
# 1588  1619978822        BABAT, LAWRENCE     Orthopaedic Surgery
# 1585  1619964111            WURTH, TODD     Orthopaedic Surgery
# 1050  1417973249        CALENDINE, CORY     Orthopaedic Surgery
# 1383  1548485071       PERKINSON, BRIAN     Orthopaedic Surgery
# 2068  1821046459            FISH, JAMES     Orthopaedic Surgery
# 763   1316050487          LOONEY, COLIN     Orthopaedic Surgery
# 281   1124175948             BYRAM, IAN     Orthopaedic Surgery
# 990   1396988960         CROSBY, SAMUEL     Orthopaedic Surgery
# 1836  1730156720          LORIO, MORGAN     Orthopaedic Surgery
# 967   1396713715          ARTHUR, SCOTT     Orthopaedic Surgery
# 1407  1558565036          CROSBY, COLIN     Orthopaedic Surgery
# 723   1295700110          RAAB, GREGORY     Orthopaedic Surgery
# 626   1255535746    ANDERSON, CHRISTIAN     Orthopaedic Surgery
# 2221  1881734119         BURVAL, DANIEL     Orthopaedic Surgery
# 951   1386848869          CORN, WILLIAM     Orthopaedic Surgery
# 1453  1578550059           DERR, RONALD     Orthopaedic Surgery
# 1518  1598852600         KREGOR, PHILIP     Orthopaedic Surgery
# 1482  1588691083        THOMSON, ANDREW     Orthopaedic Surgery
# 1575  1619295060   KUTSIKOVICH, JEFFREY     Orthopaedic Surgery
# 2084  1821397183           WEST, JUSTIN     Orthopaedic Surgery
# 677   1275586646           JOYNER, KYLE     Orthopaedic Surgery
# 1053  1417986688          HASLAM, JASON     Orthopaedic Surgery
# 1450  1578523809  KAUFFMAN, CHRISTOPHER     Orthopaedic Surgery
# 984   1396967493           EVANS, JASON     Orthopaedic Surgery
# 1205  1477754992           WHITE, LYDIA     Orthopaedic Surgery
# 1     1003031261        RUBRIGHT, JAMES     Orthopaedic Surgery
# 1935  1770745432        SULLIVAN, JARON     Orthopaedic Surgery
# 1499  1598022121      MILLIKAN, PATRICK     Orthopaedic Surgery
# 536   1215930466          DINKINS, JUAN     Orthopaedic Surgery
# 1839  1730236621         DOUGLAS, KEITH     Orthopaedic Surgery
# 606   1245527506            RUBIN, TODD     Orthopaedic Surgery
# 2095  1831169556        FERGUSON, TANIA     Orthopaedic Surgery
#
#                        Specialization_provider  to_vandy  patient_count  \
# 117           Orthopaedic Surgery of the Spine     False            492
# 170           Orthopaedic Surgery of the Spine     False            425
# 1588          Orthopaedic Surgery of the Spine     False            353
# 1585                              Hand Surgery     False            351
# 1050  Adult Reconstructive Orthopaedic Surgery     False            331
# 1383  Adult Reconstructive Orthopaedic Surgery     False            317
# 2068          Orthopaedic Surgery of the Spine     False            258
# 763                            Sports Medicine     False            232
# 281                            Sports Medicine     False            231
# 990                               Hand Surgery     False            220
# 1836          Orthopaedic Surgery of the Spine     False            204
# 967                            Sports Medicine     False            197
# 1407          Orthopaedic Surgery of the Spine     False            196
# 723   Adult Reconstructive Orthopaedic Surgery     False            180
# 626                            Sports Medicine     False            179
# 2221          Orthopaedic Surgery of the Spine     False            173
# 951                     Foot and Ankle Surgery     False            173
# 1453                           Sports Medicine     False            173
# 1518                        Orthopaedic Trauma     False            165
# 1482  Adult Reconstructive Orthopaedic Surgery     False            158
# 1575                              Hand Surgery     False            153
# 2084                           Sports Medicine     False            138
# 677                               Hand Surgery     False            122
# 1053                              Hand Surgery     False            121
# 1450          Orthopaedic Surgery of the Spine     False            119
# 984                         Orthopaedic Trauma     False            106
# 1205                           Sports Medicine     False            101
# 1                                 Hand Surgery     False             93
# 1935                           Sports Medicine     False             76
# 1499  Adult Reconstructive Orthopaedic Surgery     False             75
# 536           Orthopaedic Surgery of the Spine     False             70
# 1839                              Hand Surgery     False             60
# 606                               Hand Surgery     False             49
# 2095                        Orthopaedic Trauma     False             43
#
#       patient_count_overall  patient_prop
# 117                     492          1.00
# 170                     425          1.00
# 1588                    353          1.00
# 1585                    351          1.00
# 1050                    538          0.62
# 1383                    490          0.65
# 2068                    258          1.00
# 763                     399          0.58
# 281                     367          0.63
# 990                     220          1.00
# 1836                    204          1.00
# 967                     333          0.59
# 1407                    196          1.00
# 723                     180          1.00
# 626                     179          1.00
# 2221                    173          1.00
# 951                     173          1.00
# 1453                    173          1.00
# 1518                    165          1.00
# 1482                    265          0.60
# 1575                    274          0.56
# 2084                    138          1.00
# 677                     122          1.00
# 1053                    121          1.00
# 1450                    119          1.00
# 984                     106          1.00
# 1205                    101          1.00
# 1                        93          1.00
# 1935                    255          0.30
# 1499                     75          1.00
# 536                      70          1.00
# 1839                     60          1.00
# 606                      49          1.00
# 2095                     43          1.00

# %%
ortho[['name', 'Classification_provider', 'Specialization_provider', 'patient_count']]
# Out:
#                        name Classification_provider  \
# 117           KLEKAMP, JOHN     Orthopaedic Surgery
# 170       MCNAMARA, MICHAEL     Orthopaedic Surgery
# 1588        BABAT, LAWRENCE     Orthopaedic Surgery
# 1585            WURTH, TODD     Orthopaedic Surgery
# 1050        CALENDINE, CORY     Orthopaedic Surgery
# 1383       PERKINSON, BRIAN     Orthopaedic Surgery
# 2068            FISH, JAMES     Orthopaedic Surgery
# 763           LOONEY, COLIN     Orthopaedic Surgery
# 281              BYRAM, IAN     Orthopaedic Surgery
# 990          CROSBY, SAMUEL     Orthopaedic Surgery
# 1836          LORIO, MORGAN     Orthopaedic Surgery
# 967           ARTHUR, SCOTT     Orthopaedic Surgery
# 1407          CROSBY, COLIN     Orthopaedic Surgery
# 723           RAAB, GREGORY     Orthopaedic Surgery
# 626     ANDERSON, CHRISTIAN     Orthopaedic Surgery
# 2221         BURVAL, DANIEL     Orthopaedic Surgery
# 951           CORN, WILLIAM     Orthopaedic Surgery
# 1453           DERR, RONALD     Orthopaedic Surgery
# 1518         KREGOR, PHILIP     Orthopaedic Surgery
# 1482        THOMSON, ANDREW     Orthopaedic Surgery
# 1575   KUTSIKOVICH, JEFFREY     Orthopaedic Surgery
# 2084           WEST, JUSTIN     Orthopaedic Surgery
# 677            JOYNER, KYLE     Orthopaedic Surgery
# 1053          HASLAM, JASON     Orthopaedic Surgery
# 1450  KAUFFMAN, CHRISTOPHER     Orthopaedic Surgery
# 984            EVANS, JASON     Orthopaedic Surgery
# 1205           WHITE, LYDIA     Orthopaedic Surgery
# 1           RUBRIGHT, JAMES     Orthopaedic Surgery
# 1935        SULLIVAN, JARON     Orthopaedic Surgery
# 1499      MILLIKAN, PATRICK     Orthopaedic Surgery
# 536           DINKINS, JUAN     Orthopaedic Surgery
# 1839         DOUGLAS, KEITH     Orthopaedic Surgery
# 606             RUBIN, TODD     Orthopaedic Surgery
# 2095        FERGUSON, TANIA     Orthopaedic Surgery
#
#                        Specialization_provider  patient_count
# 117           Orthopaedic Surgery of the Spine            492
# 170           Orthopaedic Surgery of the Spine            425
# 1588          Orthopaedic Surgery of the Spine            353
# 1585                              Hand Surgery            351
# 1050  Adult Reconstructive Orthopaedic Surgery            331
# 1383  Adult Reconstructive Orthopaedic Surgery            317
# 2068          Orthopaedic Surgery of the Spine            258
# 763                            Sports Medicine            232
# 281                            Sports Medicine            231
# 990                               Hand Surgery            220
# 1836          Orthopaedic Surgery of the Spine            204
# 967                            Sports Medicine            197
# 1407          Orthopaedic Surgery of the Spine            196
# 723   Adult Reconstructive Orthopaedic Surgery            180
# 626                            Sports Medicine            179
# 2221          Orthopaedic Surgery of the Spine            173
# 951                     Foot and Ankle Surgery            173
# 1453                           Sports Medicine            173
# 1518                        Orthopaedic Trauma            165
# 1482  Adult Reconstructive Orthopaedic Surgery            158
# 1575                              Hand Surgery            153
# 2084                           Sports Medicine            138
# 677                               Hand Surgery            122
# 1053                              Hand Surgery            121
# 1450          Orthopaedic Surgery of the Spine            119
# 984                         Orthopaedic Trauma            106
# 1205                           Sports Medicine            101
# 1                                 Hand Surgery             93
# 1935                           Sports Medicine             76
# 1499  Adult Reconstructive Orthopaedic Surgery             75
# 536           Orthopaedic Surgery of the Spine             70
# 1839                              Hand Surgery             60
# 606                               Hand Surgery             49
# 2095                        Orthopaedic Trauma             43

# %%
#list of all specialties

prov_not_to_vandy['Specialization_provider'].unique()
# Out:
# array(['Anatomic Pathology & Clinical Pathology',
#        'Interventional Cardiology', 'Diagnostic Radiology',
#        'Vascular & Interventional Radiology', 'Cardiovascular Disease',
#        'Clinical Cardiac Electrophysiology', 'Neuroradiology',
#        'Advanced Heart Failure and Transplant Cardiology',
#        'Medical Oncology', 'Pulmonary Disease', 'Nephrology',
#        'Emergency Medical Services', 'Critical Care Medicine',
#        'Gastroenterology', 'Geriatric Medicine', 'Surgical Oncology',
#        'Clinical Pathology/Laboratory Medicine', 'Family',
#        'Endocrinology, Diabetes & Metabolism', 'Hematology & Oncology',
#        'Acute Care', 'Neurology', 'Gynecology',
#        'Orthopaedic Surgery of the Spine', 'Vascular Surgery',
#        'Vascular Neurology', 'Infectious Disease', "Women's Health",
#        'Sleep Medicine', 'Foot & Ankle Surgery', 'Medical',
#        'Adult Medicine', 'Adult Health', 'Radiation Oncology',
#        'Hand Surgery', 'Rheumatology',
#        'Adult Reconstructive Orthopaedic Surgery', 'Retina Specialist',
#        'Pain Medicine', 'Primary Care', 'Hospice and Palliative Medicine',
#        'Gynecologic Oncology', 'Psychiatry', 'Surgical', 'Trauma Surgery',
#        'Sports Medicine', 'Therapeutic Radiology', 'Hematology',
#        'Surgery of the Hand', 'Plastic and Reconstructive Surgery',
#        'Female Pelvic Medicine and Reconstructive Surgery',
#        'Interventional Pain Medicine', 'Foot and Ankle Surgery',
#        'Cytopathology', 'Orthopaedic Trauma', 'Otology & Neurotology',
#        'Foot Surgery', 'Gerontology', 'Pediatric Hematology-Oncology',
#        'Primary Podiatric Medicine', 'Psychiatric/Mental Health',
#        'Addiction Medicine', 'Pediatric Cardiology',
#        'Neuromuscular Medicine', 'Pediatric Radiology',
#        'Ophthalmic Plastic and Reconstructive Surgery',
#        'Diagnostic Ultrasound', 'Adolescent Medicine', 'Allergy',
#        'Orthopedic', 'Occupational Medicine',
#        'Oral and Maxillofacial Surgery', 'Clinical Child & Adolescent',
#        'Clinical'], dtype=object)

# %%
prov_not_to_vandy['Classification_provider'].unique()
# Out:
# array(['Pathology', 'Internal Medicine', 'Radiology',
#        'Emergency Medicine', 'Anesthesiology', 'Family Medicine',
#        'Surgery', 'Nurse Practitioner', 'Psychiatry & Neurology',
#        'Obstetrics & Gynecology', 'Orthopaedic Surgery', 'Podiatrist',
#        'Physician Assistant', 'Ophthalmology',
#        'Physical Medicine & Rehabilitation', 'Pain Medicine',
#        'Clinical Nurse Specialist', 'Otolaryngology', 'Pediatrics',
#        'Urology', 'Registered Nurse', 'Clinic/Center',
#        'Allergy & Immunology', 'Physical Therapist',
#        'Preventive Medicine', 'Dentist', 'Psychologist', 'Social Worker'],
#       dtype=object)

# %%
#specialty referrals to hospitals
#diagnostic radiology is the highest specialty 

spec_to_hosp = (full_refs.groupby(['taxonomy_code_provider', 'Classification_provider', 'Specialization_provider', 'to_npi', 'organization_hospital', 'address_hospital'])
     ['patient_count']
     .sum()
     .sort_values(ascending = False)
     .reset_index()
)

spec_to_hosp
# Out:
#     taxonomy_code_provider  Classification_provider  \
# 0               2085R0202X                Radiology
# 1               207RC0000X        Internal Medicine
# 2               2085R0202X                Radiology
# 3               2085R0202X                Radiology
# 4               2085R0202X                Radiology
# ..                     ...                      ...
# 560             207VX0201X  Obstetrics & Gynecology
# 561             2080P0210X               Pediatrics
# 562             207RR0500X        Internal Medicine
# 563             103TC2200X             Psychologist
# 564             363LF0000X       Nurse Practitioner
#
#          Specialization_provider      to_npi  \
# 0           Diagnostic Radiology  1396882205
# 1         Cardiovascular Disease  1396882205
# 2           Diagnostic Radiology  1023055126
# 3           Diagnostic Radiology  1629025648
# 4           Diagnostic Radiology  1780778969
# ..                           ...         ...
# 560         Gynecologic Oncology  1538114434
# 561         Pediatric Nephrology  1396882205
# 562                 Rheumatology  1568551455
# 563  Clinical Child & Adolescent  1558408633
# 564                       Family  1568551455
#
#                       organization_hospital  \
# 0      VANDERBILT UNIVERSITY MEDICAL CENTER
# 1      VANDERBILT UNIVERSITY MEDICAL CENTER
# 2    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3                SAINT THOMAS WEST HOSPITAL
# 4                SAINT THOMAS WEST HOSPITAL
# ..                                      ...
# 560     HENDERSONVILLE HOSPITAL CORPORATION
# 561    VANDERBILT UNIVERSITY MEDICAL CENTER
# 562              NASHVILLE GENERAL HOSPITAL
# 563    VANDERBILT UNIVERSITY MEDICAL CENTER
# 564              NASHVILLE GENERAL HOSPITAL
#
#                                       address_hospital  patient_count
# 0       1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          71894
# 1       1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 2               2300 PATTERSON ST, NASHVILLE, TN 37203          42282
# 3                 4220 HARDING RD, NASHVILLE, TN 37205          36715
# 4                  2000 CHURCH ST, NASHVILLE, TN 37236          28344
# ..                                                 ...            ...
# 560  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...             21
# 561     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232             19
# 562  1818 ALBION ST, ATTN: MARTHA LAMPLEY, NASHVILL...             17
# 563               1601 23RD AVE S, NASHVILLE, TN 37212             12
# 564  1818 ALBION ST, ATTN: MARTHA LAMPLEY, NASHVILL...             12
#
# [565 rows x 7 columns]

# %%
#top 20 hospital referrals

spec_to_hosp.nlargest(20, 'patient_count')
# Out:
#    taxonomy_code_provider Classification_provider  \
# 0              2085R0202X               Radiology
# 1              207RC0000X       Internal Medicine
# 2              2085R0202X               Radiology
# 3              2085R0202X               Radiology
# 4              2085R0202X               Radiology
# 5              2085R0202X               Radiology
# 6              2085R0202X               Radiology
# 7              2085R0202X               Radiology
# 8              207RC0000X       Internal Medicine
# 9              2085R0202X               Radiology
# 10             363LF0000X      Nurse Practitioner
# 11             207ZP0102X               Pathology
# 12             363LA2100X      Nurse Practitioner
# 13             2085R0202X               Radiology
# 14             207RC0000X       Internal Medicine
# 15             2085R0202X               Radiology
# 16             207ZP0102X               Pathology
# 17             2085R0202X               Radiology
# 18             207RI0011X       Internal Medicine
# 19             207RH0003X       Internal Medicine
#
#                     Specialization_provider      to_npi  \
# 0                      Diagnostic Radiology  1396882205
# 1                    Cardiovascular Disease  1396882205
# 2                      Diagnostic Radiology  1023055126
# 3                      Diagnostic Radiology  1629025648
# 4                      Diagnostic Radiology  1780778969
# 5                      Diagnostic Radiology  1295780476
# 6                      Diagnostic Radiology  1164590386
# 7                      Diagnostic Radiology  1265445506
# 8                    Cardiovascular Disease  1629025648
# 9                      Diagnostic Radiology  1538114434
# 10                                   Family  1396882205
# 11  Anatomic Pathology & Clinical Pathology  1023055126
# 12                               Acute Care  1396882205
# 13                     Diagnostic Radiology  1447571658
# 14                   Cardiovascular Disease  1265445506
# 15                     Diagnostic Radiology  1720032345
# 16  Anatomic Pathology & Clinical Pathology  1396882205
# 17                     Diagnostic Radiology  1992776405
# 18                Interventional Cardiology  1023055126
# 19                    Hematology & Oncology  1396882205
#
#                      organization_hospital  \
# 0     VANDERBILT UNIVERSITY MEDICAL CENTER
# 1     VANDERBILT UNIVERSITY MEDICAL CENTER
# 2   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3               SAINT THOMAS WEST HOSPITAL
# 4               SAINT THOMAS WEST HOSPITAL
# 5        HTI MEMORIAL HOSPITAL CORPORATION
# 6         SAINT THOMAS RUTHERFORD HOSPITAL
# 7      WILLIAMSON COUNTY HOSPITAL DISTRICT
# 8               SAINT THOMAS WEST HOSPITAL
# 9      HENDERSONVILLE HOSPITAL CORPORATION
# 10    VANDERBILT UNIVERSITY MEDICAL CENTER
# 11  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 12    VANDERBILT UNIVERSITY MEDICAL CENTER
# 13      SUMNER REGIONAL MEDICAL CENTER LLC
# 14     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 15  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 16    VANDERBILT UNIVERSITY MEDICAL CENTER
# 17  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 18  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 19    VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                                      address_hospital  patient_count
# 0      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          71894
# 1      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 2              2300 PATTERSON ST, NASHVILLE, TN 37203          42282
# 3                4220 HARDING RD, NASHVILLE, TN 37205          36715
# 4                 2000 CHURCH ST, NASHVILLE, TN 37236          28344
# 5            3441 DICKERSON PIKE, NASHVILLE, TN 37207          27111
# 6    1700 MEDICAL CENTER PKWY, MURFREESBORO, TN 37129          21610
# 7          4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          20038
# 8                4220 HARDING RD, NASHVILLE, TN 37205          16639
# 9   355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...          15831
# 10     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13725
# 11             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 12     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13294
# 13            555 HARTSVILLE PIKE, GALLATIN, TN 37066          13191
# 14         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258
# 15                391 WALLACE RD, NASHVILLE, TN 37211          10179
# 16     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          10145
# 17              200 STONECREST BLVD, SMYRNA, TN 37167           9895
# 18             2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# 19     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9659

# %%
spec_to_hosp['organization_hospital'].unique()
# Out:
# array(['VANDERBILT UNIVERSITY MEDICAL CENTER',
#        'HCA HEALTH SERVICES OF TENNESSEE, INC.',
#        'SAINT THOMAS WEST HOSPITAL', 'HTI MEMORIAL HOSPITAL CORPORATION',
#        'SAINT THOMAS RUTHERFORD HOSPITAL',
#        'WILLIAMSON COUNTY HOSPITAL DISTRICT',
#        'HENDERSONVILLE HOSPITAL CORPORATION',
#        'SUMNER REGIONAL MEDICAL CENTER LLC',
#        'SUMNER REGIONAL HEALTH SYSTEMS, INC',
#        'NASHVILLE GENERAL HOSPITAL', 'SETON CORPORATION',
#        'TRUSTPOINT HOSPITAL, LLC'], dtype=object)

# %%
#radiology and pathology are the top two fields that vanderbilt needs to look closely 


spec_to_hosp[spec_to_hosp['organization_hospital']=='HCA HEALTH SERVICES OF TENNESSEE, INC.']
# Out:
#     taxonomy_code_provider Classification_provider  \
# 2               2085R0202X               Radiology
# 11              207ZP0102X               Pathology
# 15              2085R0202X               Radiology
# 17              2085R0202X               Radiology
# 18              207RI0011X       Internal Medicine
# ..                     ...                     ...
# 543             103TC0700X            Psychologist
# 544             207XS0106X     Orthopaedic Surgery
# 546             363LW0102X      Nurse Practitioner
# 550             363LP0808X      Nurse Practitioner
# 553             207RA0000X       Internal Medicine
#
#                      Specialization_provider      to_npi  \
# 2                       Diagnostic Radiology  1023055126
# 11   Anatomic Pathology & Clinical Pathology  1023055126
# 15                      Diagnostic Radiology  1720032345
# 17                      Diagnostic Radiology  1992776405
# 18                 Interventional Cardiology  1023055126
# ..                                       ...         ...
# 543                                 Clinical  1992776405
# 544                             Hand Surgery  1992776405
# 546                           Women's Health  1023055126
# 550                Psychiatric/Mental Health  1992776405
# 553                      Adolescent Medicine  1023055126
#
#                       organization_hospital  \
# 2    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 11   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 15   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 17   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 18   HCA HEALTH SERVICES OF TENNESSEE, INC.
# ..                                      ...
# 543  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 544  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 546  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 550  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 553  HCA HEALTH SERVICES OF TENNESSEE, INC.
#
#                            address_hospital  patient_count
# 2    2300 PATTERSON ST, NASHVILLE, TN 37203          42282
# 11   2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 15      391 WALLACE RD, NASHVILLE, TN 37211          10179
# 17    200 STONECREST BLVD, SMYRNA, TN 37167           9895
# 18   2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# ..                                      ...            ...
# 543   200 STONECREST BLVD, SMYRNA, TN 37167             35
# 544   200 STONECREST BLVD, SMYRNA, TN 37167             34
# 546  2300 PATTERSON ST, NASHVILLE, TN 37203             34
# 550   200 STONECREST BLVD, SMYRNA, TN 37167             32
# 553  2300 PATTERSON ST, NASHVILLE, TN 37203             30
#
# [123 rows x 7 columns]

# %%
spec_to_hosp[spec_to_hosp['Specialization_provider'] != 'Diagnostic Radiology'].nlargest(20, 'patient_count')
# Out:
#    taxonomy_code_provider Classification_provider  \
# 1              207RC0000X       Internal Medicine
# 8              207RC0000X       Internal Medicine
# 10             363LF0000X      Nurse Practitioner
# 11             207ZP0102X               Pathology
# 12             363LA2100X      Nurse Practitioner
# 14             207RC0000X       Internal Medicine
# 16             207ZP0102X               Pathology
# 18             207RI0011X       Internal Medicine
# 19             207RH0003X       Internal Medicine
# 20             207RN0300X       Internal Medicine
# 21             2084N0400X  Psychiatry & Neurology
# 22             207RC0000X       Internal Medicine
# 23             207RG0100X       Internal Medicine
# 24             207RE0101X       Internal Medicine
# 25             363LA2200X      Nurse Practitioner
# 26             207RC0000X       Internal Medicine
# 27             207RC0000X       Internal Medicine
# 28             207ZP0102X               Pathology
# 29             207RC0000X       Internal Medicine
# 30             2085N0700X               Radiology
#
#                     Specialization_provider      to_npi  \
# 1                    Cardiovascular Disease  1396882205
# 8                    Cardiovascular Disease  1629025648
# 10                                   Family  1396882205
# 11  Anatomic Pathology & Clinical Pathology  1023055126
# 12                               Acute Care  1396882205
# 14                   Cardiovascular Disease  1265445506
# 16  Anatomic Pathology & Clinical Pathology  1396882205
# 18                Interventional Cardiology  1023055126
# 19                    Hematology & Oncology  1396882205
# 20                               Nephrology  1396882205
# 21                                Neurology  1396882205
# 22                   Cardiovascular Disease  1023055126
# 23                         Gastroenterology  1396882205
# 24     Endocrinology, Diabetes & Metabolism  1396882205
# 25                             Adult Health  1396882205
# 26                   Cardiovascular Disease  1538114434
# 27                   Cardiovascular Disease  1447571658
# 28  Anatomic Pathology & Clinical Pathology  1780778969
# 29                   Cardiovascular Disease  1780778969
# 30                           Neuroradiology  1396882205
#
#                      organization_hospital  \
# 1     VANDERBILT UNIVERSITY MEDICAL CENTER
# 8               SAINT THOMAS WEST HOSPITAL
# 10    VANDERBILT UNIVERSITY MEDICAL CENTER
# 11  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 12    VANDERBILT UNIVERSITY MEDICAL CENTER
# 14     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 16    VANDERBILT UNIVERSITY MEDICAL CENTER
# 18  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 19    VANDERBILT UNIVERSITY MEDICAL CENTER
# 20    VANDERBILT UNIVERSITY MEDICAL CENTER
# 21    VANDERBILT UNIVERSITY MEDICAL CENTER
# 22  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 23    VANDERBILT UNIVERSITY MEDICAL CENTER
# 24    VANDERBILT UNIVERSITY MEDICAL CENTER
# 25    VANDERBILT UNIVERSITY MEDICAL CENTER
# 26     HENDERSONVILLE HOSPITAL CORPORATION
# 27      SUMNER REGIONAL MEDICAL CENTER LLC
# 28              SAINT THOMAS WEST HOSPITAL
# 29              SAINT THOMAS WEST HOSPITAL
# 30    VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                                      address_hospital  patient_count
# 1      1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          58209
# 8                4220 HARDING RD, NASHVILLE, TN 37205          16639
# 10     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13725
# 11             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 12     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          13294
# 14         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258
# 16     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232          10145
# 18             2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# 19     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9659
# 20     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9432
# 21     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           9113
# 22             2300 PATTERSON ST, NASHVILLE, TN 37203           7902
# 23     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           7615
# 24     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           6356
# 25     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           6305
# 26  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...           6270
# 27            555 HARTSVILLE PIKE, GALLATIN, TN 37066           6170
# 28                2000 CHURCH ST, NASHVILLE, TN 37236           5882
# 29                2000 CHURCH ST, NASHVILLE, TN 37236           5571
# 30     1211 MEDICAL CENTER DRIVE, NASHVILLE, TN 37232           5543

# %%
(spec_to_hosp[(spec_to_hosp['Specialization_provider'] != 'Diagnostic Radiology')
             &
             (spec_to_hosp['organization_hospital'] != 'VANDERBILT UNIVERSITY MEDICAL CENTER')]
             .nlargest(20, 'patient_count')
)
# Out:
#    taxonomy_code_provider Classification_provider  \
# 8              207RC0000X       Internal Medicine
# 11             207ZP0102X               Pathology
# 14             207RC0000X       Internal Medicine
# 18             207RI0011X       Internal Medicine
# 22             207RC0000X       Internal Medicine
# 26             207RC0000X       Internal Medicine
# 27             207RC0000X       Internal Medicine
# 28             207ZP0102X               Pathology
# 29             207RC0000X       Internal Medicine
# 33             207RC0000X       Internal Medicine
# 34             207ZP0102X               Pathology
# 36             207RP1001X       Internal Medicine
# 37             207RC0000X       Internal Medicine
# 38             363LA2100X      Nurse Practitioner
# 39             207RN0300X       Internal Medicine
# 40             207RP1001X       Internal Medicine
# 43             207RG0100X       Internal Medicine
# 44             207RC0001X       Internal Medicine
# 45             207RN0300X       Internal Medicine
# 46             363LF0000X      Nurse Practitioner
#
#                     Specialization_provider      to_npi  \
# 8                    Cardiovascular Disease  1629025648
# 11  Anatomic Pathology & Clinical Pathology  1023055126
# 14                   Cardiovascular Disease  1265445506
# 18                Interventional Cardiology  1023055126
# 22                   Cardiovascular Disease  1023055126
# 26                   Cardiovascular Disease  1538114434
# 27                   Cardiovascular Disease  1447571658
# 28  Anatomic Pathology & Clinical Pathology  1780778969
# 29                   Cardiovascular Disease  1780778969
# 33                   Cardiovascular Disease  1164590386
# 34  Anatomic Pathology & Clinical Pathology  1629025648
# 36                        Pulmonary Disease  1780778969
# 37                   Cardiovascular Disease  1295780476
# 38                               Acute Care  1629025648
# 39                               Nephrology  1023055126
# 40                        Pulmonary Disease  1629025648
# 43                         Gastroenterology  1023055126
# 44       Clinical Cardiac Electrophysiology  1629025648
# 45                               Nephrology  1629025648
# 46                                   Family  1023055126
#
#                      organization_hospital  \
# 8               SAINT THOMAS WEST HOSPITAL
# 11  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 14     WILLIAMSON COUNTY HOSPITAL DISTRICT
# 18  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 22  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 26     HENDERSONVILLE HOSPITAL CORPORATION
# 27      SUMNER REGIONAL MEDICAL CENTER LLC
# 28              SAINT THOMAS WEST HOSPITAL
# 29              SAINT THOMAS WEST HOSPITAL
# 33        SAINT THOMAS RUTHERFORD HOSPITAL
# 34              SAINT THOMAS WEST HOSPITAL
# 36              SAINT THOMAS WEST HOSPITAL
# 37       HTI MEMORIAL HOSPITAL CORPORATION
# 38              SAINT THOMAS WEST HOSPITAL
# 39  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 40              SAINT THOMAS WEST HOSPITAL
# 43  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 44              SAINT THOMAS WEST HOSPITAL
# 45              SAINT THOMAS WEST HOSPITAL
# 46  HCA HEALTH SERVICES OF TENNESSEE, INC.
#
#                                      address_hospital  patient_count
# 8                4220 HARDING RD, NASHVILLE, TN 37205          16639
# 11             2300 PATTERSON ST, NASHVILLE, TN 37203          13682
# 14         4321 CAROTHERS PARKWAY, FRANKLIN, TN 37067          10258
# 18             2300 PATTERSON ST, NASHVILLE, TN 37203           9676
# 22             2300 PATTERSON ST, NASHVILLE, TN 37203           7902
# 26  355 NEW SHACKLE ISLAND RD, HENDERSONVILLE, TN ...           6270
# 27            555 HARTSVILLE PIKE, GALLATIN, TN 37066           6170
# 28                2000 CHURCH ST, NASHVILLE, TN 37236           5882
# 29                2000 CHURCH ST, NASHVILLE, TN 37236           5571
# 33   1700 MEDICAL CENTER PKWY, MURFREESBORO, TN 37129           5140
# 34               4220 HARDING RD, NASHVILLE, TN 37205           5012
# 36                2000 CHURCH ST, NASHVILLE, TN 37236           4585
# 37           3441 DICKERSON PIKE, NASHVILLE, TN 37207           4166
# 38               4220 HARDING RD, NASHVILLE, TN 37205           3715
# 39             2300 PATTERSON ST, NASHVILLE, TN 37203           3692
# 40               4220 HARDING RD, NASHVILLE, TN 37205           3545
# 43             2300 PATTERSON ST, NASHVILLE, TN 37203           3386
# 44               4220 HARDING RD, NASHVILLE, TN 37205           3358
# 45               4220 HARDING RD, NASHVILLE, TN 37205           3316
# 46             2300 PATTERSON ST, NASHVILLE, TN 37203           3311

# %%
#number of providers
full_refs_hosp['address_provider'].nunique()
# Out:
# 2157

# %%
#number of hospitals
full_refs_hosp['address_hospital'].nunique()
# Out:
# 22

# %%
def make_not_to_vandy(df, group):

    # create a column that labels whether the recommendation went to Vanderbilt or not
    df['to_vandy'] = df['organization_hospital'].str.contains("VANDERBILT")

    # for each specialty, determine the transaction count 
    to_vandy = (df.groupby(group + ['to_vandy'])
         ['transaction_count']
         .sum()
         .reset_index()
    )

    # add a column for overall count of referrals by specialty, then determine proportion
    # of transaction in Vanderbilt vs proportion not in Vanderbilt
    to_vandy['transaction_count_overall'] = (to_vandy.groupby(group)
                                     ['transaction_count']
                                     .transform(sum)
                                    )
    to_vandy['transaction_prop'] = (to_vandy['transaction_count']/
                                     to_vandy['transaction_count_overall']
                                    )

    # filter to focus just on referrals not to Vanderbilt
    not_to_vandy = to_vandy[to_vandy['to_vandy'] == False]
    
    return not_to_vandy.sort_values('transaction_count', ascending = False)

# %%
#top 25 specialties not referring to vandy

spec_not_to_vandy = make_not_to_vandy(full_refs, ['taxonomy_code_provider', 'Classification_provider', 'Specialization_provider'])

spec_not_to_vandy.nlargest(25, 'transaction_count')
# Out:
#     taxonomy_code_provider Classification_provider  \
# 141             2085R0202X               Radiology
# 35              207RC0000X       Internal Medicine
# 101             207ZP0102X               Pathology
# 61              207RP1001X       Internal Medicine
# 59              207RN0300X       Internal Medicine
# 184             363LF0000X      Nurse Practitioner
# 55              207RI0011X       Internal Medicine
# 43              207RG0100X       Internal Medicine
# 37              207RC0001X       Internal Medicine
# 51              207RH0003X       Internal Medicine
# 120             2084N0400X  Psychiatry & Neurology
# 68              207RX0202X       Internal Medicine
# 32              207RA0001X       Internal Medicine
# 178             363LA2100X      Nurse Practitioner
# 154             2086S0129X                 Surgery
# 57              207RI0200X       Internal Medicine
# 41              207RE0101X       Internal Medicine
# 144             2085R0204X               Radiology
# 166             213ES0103X              Podiatrist
# 12              207LC0200X          Anesthesiology
# 124             2084P0800X  Psychiatry & Neurology
# 180             363LA2200X      Nurse Practitioner
# 139             2085R0001X               Radiology
# 86              207XS0117X     Orthopaedic Surgery
# 24              207QG0300X         Family Medicine
#
#                               Specialization_provider  to_vandy  \
# 141                              Diagnostic Radiology     False
# 35                             Cardiovascular Disease     False
# 101           Anatomic Pathology & Clinical Pathology     False
# 61                                  Pulmonary Disease     False
# 59                                         Nephrology     False
# 184                                            Family     False
# 55                          Interventional Cardiology     False
# 43                                   Gastroenterology     False
# 37                 Clinical Cardiac Electrophysiology     False
# 51                              Hematology & Oncology     False
# 120                                         Neurology     False
# 68                                   Medical Oncology     False
# 32   Advanced Heart Failure and Transplant Cardiology     False
# 178                                        Acute Care     False
# 154                                  Vascular Surgery     False
# 57                                 Infectious Disease     False
# 41               Endocrinology, Diabetes & Metabolism     False
# 144               Vascular & Interventional Radiology     False
# 166                              Foot & Ankle Surgery     False
# 12                             Critical Care Medicine     False
# 124                                        Psychiatry     False
# 180                                      Adult Health     False
# 139                                Radiation Oncology     False
# 86                   Orthopaedic Surgery of the Spine     False
# 24                                 Geriatric Medicine     False
#
#      transaction_count  transaction_count_overall  transaction_prop
# 141             257888                     335792          0.767999
# 35              101095                     178469          0.566457
# 101              52401                      63471          0.825590
# 61               42755                      51295          0.833512
# 59               38464                      56694          0.678449
# 184              29593                      49040          0.603446
# 55               27244                      30148          0.903675
# 43               22780                      33726          0.675443
# 37               18820                      23626          0.796580
# 51               15199                      42759          0.355457
# 120              13897                      28793          0.482652
# 68               12809                      26173          0.489397
# 32               12684                      16730          0.758159
# 178              12467                      32069          0.388755
# 154              11855                      15497          0.764987
# 57               10807                      16210          0.666687
# 41                9000                      18764          0.479642
# 144               8000                       9461          0.845577
# 166               6065                      10074          0.602045
# 12                5926                       9000          0.658444
# 124               5840                      14004          0.417024
# 180               5278                      15016          0.351492
# 139               4883                       9657          0.505644
# 86                4612                       4612          1.000000
# 24                3338                       3716          0.898278
