# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import sqlite3

# %%
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT *
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT npi
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT 
            to_npi,
            referral_id,
            qf.entity_type_code,
            qf.taxonomy_code,
            classification,
            specialization,
            qf."provider_organization_name_(legal_business_name)" AS organization,
            qf.provider_first_line_business_practice_location_address AS address_line1,
            qf.provider_second_line_business_practice_location_address AS address_line2,
            qf.provider_business_practice_location_address_city_name AS city,
            qf.provider_business_practice_location_address_state_name AS state,
            qf.provider_business_practice_location_address_postal_code AS zip
        FROM qualifying_refs AS qf
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""
with sqlite3.connect('data/hopteam.sqlite') as db:
    groups = pd.read_sql(query, db)

# %%
groups
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 0      1013012616     18854880               2.0    207Q00000X
# 1      1013012616    131966153               2.0    207Q00000X
# 2      1013012616    146169993               2.0    207Q00000X
# 3      1902804271       320488               2.0    208VP0014X
# 4      1902804271      6754370               2.0    208VP0014X
# ...           ...          ...               ...           ...
# 69422  1669872735     30083148               2.0    363LF0000X
# 69423  1669872735    114150220               2.0    363LF0000X
# 69424  1669872735    178563129               2.0    363LF0000X
# 69425  1669872735    184096138               2.0    363LF0000X
# 69426  1053867184     97303120               2.0    363LF0000X
#
#            Classification                Specialization  \
# 0         Family Medicine                          None
# 1         Family Medicine                          None
# 2         Family Medicine                          None
# 3           Pain Medicine  Interventional Pain Medicine
# 4           Pain Medicine  Interventional Pain Medicine
# ...                   ...                           ...
# 69422  Nurse Practitioner                        Family
# 69423  Nurse Practitioner                        Family
# 69424  Nurse Practitioner                        Family
# 69425  Nurse Practitioner                        Family
# 69426  Nurse Practitioner                        Family
#
#                              organization        address_line1 address_line2  \
# 0            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 1            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 2            CRIPPS, HOOPER & RHODY, PLLC  400 E PUBLIC SQUARE          None
# 3             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# 4             PAIN MANAGEMENT GROUP, P.C.  5801 CROSSINGS BLVD          None
# ...                                   ...                  ...           ...
# 69422  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69423  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69424  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69425  RIVERVIEW PHYSICIAN PRACTICES, LLC       14 MAIN STREET       SUITE B
# 69426     SMITH COUNTY FAMILY MEDICAL LLC  8 NEW MIDDLETON HWY         STE A
#
#                city state    zip
# 0        ALEXANDRIA    TN  37012
# 1        ALEXANDRIA    TN  37012
# 2        ALEXANDRIA    TN  37012
# 3           ANTIOCH    TN  37013
# 4           ANTIOCH    TN  37013
# ...             ...   ...    ...
# 69422  GORDONSVILLE    TN  38563
# 69423  GORDONSVILLE    TN  38563
# 69424  GORDONSVILLE    TN  38563
# 69425  GORDONSVILLE    TN  38563
# 69426  GORDONSVILLE    TN  38563
#
# [69427 rows x 12 columns]

# %%
# profiles of all providers
# with referrals to metro nashville groups (entity 2) 
#having referrals of over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT 
                referral_id
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT
            from_npi,
            referral_id,
            entity_type_code,
            "provider_last_name_(legal_name)" || ', ' || provider_first_name AS name,
            taxonomy_code,
            classification,
            specialization,
            "provider_organization_name_(legal_business_name)" AS organization,
            provider_first_line_business_practice_location_address AS address_line1,
            provider_second_line_business_practice_location_address AS address_line2,
            provider_business_practice_location_address_city_name AS city,
            provider_business_practice_location_address_state_name AS state,
            provider_business_practice_location_address_postal_code AS zip     
        FROM qualifying_refs
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    providers = pd.read_sql(query, db)

# %%
providers
# Out:
#          from_npi  referral_id  entity_type_code                 name  \
# 0      1821080961     18854880               1.0    SHERWOOD, WILLIAM
# 1      1841282779    131966153               1.0         RHODY, KEVIN
# 2      1770575607    146169993               1.0       COOPER, STEVEN
# 3      1508804337       320488               1.0       SHARMA, VINEET
# 4      1538109103      6754370               1.0            NAU, PAUL
# ...           ...          ...               ...                  ...
# 69422  1558355941     30083148               1.0         JOSEPH, JOJU
# 69423  1023099074    114150220               1.0     LAMBERT, HEATHER
# 69424  1184619124    178563129               1.0  RUTHERFORD, RICHARD
# 69425  1205931565    184096138               1.0       NOBLE, MICHAEL
# 69426  1912156696     97303120               1.0    GREGORY, KIMBERLY
#
#       taxonomy_code      Classification        Specialization organization  \
# 0        207Q00000X     Family Medicine                  None         None
# 1        207Q00000X     Family Medicine                  None         None
# 2        207Q00000X     Family Medicine                  None         None
# 3        2085R0202X           Radiology  Diagnostic Radiology         None
# 4        2085R0202X           Radiology  Diagnostic Radiology         None
# ...             ...                 ...                   ...          ...
# 69422    207RN0300X   Internal Medicine            Nephrology         None
# 69423    363LW0102X  Nurse Practitioner        Women's Health         None
# 69424    207Q00000X     Family Medicine                  None         None
# 69425    207Q00000X     Family Medicine                  None         None
# 69426    363LF0000X  Nurse Practitioner                Family         None
#
#                 address_line1 address_line2            city state    zip
# 0         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 1         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 2         302 N CONGRESS BLVD          None      SMITHVILLE    TN  37166
# 3      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# 4      3024 BUSINESS PARK CIR          None  GOODLETTSVILLE    TN  37072
# ...                       ...           ...             ...   ...    ...
# 69422    270 EAST MAIN STREET     SUITE 200        GALLATIN    TN  37066
# 69423    507 GORDONSVILLE HWY     SUITE 203    GORDONSVILLE    TN  38563
# 69424         133 HOSPITAL DR     SUITE 500        CARTHAGE    TN  37030
# 69425            37 PALMER ST          None          CALAIS    ME  04619
# 69426     8 NEW MIDDLETON HWY         STE A    GORDONSVILLE    TN  38563
#
# [69427 rows x 13 columns]

# %%
# referrals from providers (entity 1) to metro nashville groups (entity 2) 
# having over 50 transactions and under 50 average wait time

query = """
        
        WITH metro_entity_2 AS (
            SELECT *
            FROM profile
            WHERE provider_business_practice_location_address_postal_code IN (
                SELECT zip
                FROM zip_cbsa
                WHERE cbsa = '34980'
                )
                AND entity_type_code = 2.0
            ),
        referrals50 AS (
            SELECT *
            FROM referrals
            WHERE average_day_wait < 50
            AND transaction_count >= 50
        ),
        qualifying_refs AS (
            SELECT
                to_npi,
                referral_id,
                patient_count,
                transaction_count,
                average_day_wait,
                std_day_wait  
            FROM metro_entity_2
            INNER JOIN referral_to
            ON metro_entity_2.npi = referral_to.to_npi
            INNER JOIN referrals50
            USING (referral_id)
        ),
        entity1 AS (
            SELECT *
            FROM profile
            INNER JOIN taxonomy
            ON profile.taxonomy_code = taxonomy.code
            WHERE entity_type_code = 1.0
        )
        SELECT
            from_npi,
            to_npi,
            referral_id,
            patient_count,
            transaction_count,
            average_day_wait,
            std_day_wait
        FROM qualifying_refs
        INNER JOIN referral_from
        USING (referral_id)
        INNER JOIN entity1
        ON referral_from.from_npi = entity1.npi;

"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    referrals = pd.read_sql(query, db)

# %%
referrals
# Out:
#          from_npi      to_npi  referral_id  patient_count  transaction_count  \
# 0      1821080961  1013012616     18854880             91                238
# 1      1841282779  1013012616    131966153             94                236
# 2      1770575607  1013012616    146169993            115                320
# 3      1508804337  1902804271       320488            157                163
# 4      1538109103  1902804271      6754370            312                320
# ...           ...         ...          ...            ...                ...
# 69422  1558355941  1669872735     30083148             31                 89
# 69423  1023099074  1669872735    114150220            256               1309
# 69424  1184619124  1669872735    178563129             40                 90
# 69425  1205931565  1669872735    184096138             35                 54
# 69426  1912156696  1053867184     97303120             97                428
#
#        average_day_wait  std_day_wait
# 0                 9.924        40.266
# 1                 7.695        36.447
# 2                 2.725        18.756
# 3                27.583        51.939
# 4                12.709        40.583
# ...                 ...           ...
# 69422            23.101        31.695
# 69423             0.214         5.207
# 69424            23.089        36.995
# 69425             1.315         6.815
# 69426             0.000         0.000
#
# [69427 rows x 7 columns]

# %%
# General Acute Care Hospitals in Nashville and nearby 


cities = ['NASHVILLE',
          'MURFREESBORO',
          'BRENTWOOD',
          'FRANKLIN',
          'HENDERSONVILLE',
          'GOODLETTSVILLE',
          'LA VERGNE',
          'SMYRNA',
          'MT. JULIET',
          'GALLATIN']

gach = (groups
     .loc[(groups['Classification'].str.contains('General Acute Care Hospital', na = False)) 
            & 
           (groups['city'].isin(cities))
           ,
          ]
     .drop_duplicates()
     .sort_values('organization')
)

gach
# Out:
#            to_npi  referral_id  entity_type_code taxonomy_code  \
# 33687  1023055126     48731386               2.0    282N00000X
# 33707  1023055126     53473559               2.0    282N00000X
# 33708  1023055126     55525652               2.0    282N00000X
# 33709  1023055126     55525663               2.0    282N00000X
# 33710  1023055126     55525676               2.0    282N00000X
# ...           ...          ...               ...           ...
# 10962  1265445506     53960238               2.0    282N00000X
# 10961  1265445506     53960229               2.0    282N00000X
# 10960  1265445506     52260376               2.0    282N00000X
# 10967  1265445506     55966757               2.0    282N00000X
# 11062  1265445506    130486815               2.0    282N00000X
#
#                     Classification Specialization  \
# 33687  General Acute Care Hospital           None
# 33707  General Acute Care Hospital           None
# 33708  General Acute Care Hospital           None
# 33709  General Acute Care Hospital           None
# 33710  General Acute Care Hospital           None
# ...                            ...            ...
# 10962  General Acute Care Hospital           None
# 10961  General Acute Care Hospital           None
# 10960  General Acute Care Hospital           None
# 10967  General Acute Care Hospital           None
# 11062  General Acute Care Hospital           None
#
#                                  organization           address_line1  \
# 33687  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33707  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33708  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33709  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# 33710  HCA HEALTH SERVICES OF TENNESSEE, INC.       2300 PATTERSON ST
# ...                                       ...                     ...
# 10962     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10961     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10960     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 10967     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
# 11062     WILLIAMSON COUNTY HOSPITAL DISTRICT  4321 CAROTHERS PARKWAY
#
#       address_line2       city state    zip
# 33687          None  NASHVILLE    TN  37203
# 33707          None  NASHVILLE    TN  37203
# 33708          None  NASHVILLE    TN  37203
# 33709          None  NASHVILLE    TN  37203
# 33710          None  NASHVILLE    TN  37203
# ...             ...        ...   ...    ...
# 10962          None   FRANKLIN    TN  37067
# 10961          None   FRANKLIN    TN  37067
# 10960          None   FRANKLIN    TN  37067
# 10967          None   FRANKLIN    TN  37067
# 11062          None   FRANKLIN    TN  37067
#
# [6875 rows x 12 columns]

# %%
gach.drop_duplicates(subset = ['organization', 'address_line1', 'city', 'state', 'zip']).reset_index().sort_values('organization')
# Out:
#     index      to_npi  referral_id  entity_type_code taxonomy_code  \
# 0   33687  1023055126     48731386               2.0    282N00000X
# 1   50076  1720032345    155535970               2.0    282N00000X
# 2   24794  1992776405    100689576               2.0    282N00000X
# 3   14903  1538114434    169422729               2.0    282N00000X
# 4   45127  1093769606     20019626               2.0    282N00000X
# 5   46796  1568551455    132969432               2.0    282N00000X
# 6   22376  1164590386    117188077               2.0    282N00000X
# 7   44234  1629025648    176011269               2.0    282N00000X
# 8   66179  1780778969    194249596               2.0    282N00000X
# 9   66249  1992861314    106709285               2.0    282N00000X
# 10   9506  1285644237    144750825               2.0    282N00000X
# 11   9933  1447571658    152868401               2.0    282N00000X
# 12  20704  1184987505    168584524               2.0    282N00000X
# 13  59249  1396882205     13694209               2.0    282N00000X
# 14  51120  1558408633     75013834               2.0    282N00000X
# 15  11173  1265445506    187509096               2.0    282N00000X
#
#                  Classification Specialization  \
# 0   General Acute Care Hospital           None
# 1   General Acute Care Hospital           None
# 2   General Acute Care Hospital           None
# 3   General Acute Care Hospital           None
# 4   General Acute Care Hospital           None
# 5   General Acute Care Hospital           None
# 6   General Acute Care Hospital           None
# 7   General Acute Care Hospital           None
# 8   General Acute Care Hospital           None
# 9   General Acute Care Hospital           None
# 10  General Acute Care Hospital           None
# 11  General Acute Care Hospital           None
# 12  General Acute Care Hospital           None
# 13  General Acute Care Hospital           None
# 14  General Acute Care Hospital           None
# 15  General Acute Care Hospital           None
#
#                               organization              address_line1  \
# 0   HCA HEALTH SERVICES OF TENNESSEE, INC.          2300 PATTERSON ST
# 1   HCA HEALTH SERVICES OF TENNESSEE, INC.             391 WALLACE RD
# 2   HCA HEALTH SERVICES OF TENNESSEE, INC.        200 STONECREST BLVD
# 3      HENDERSONVILLE HOSPITAL CORPORATION  355 NEW SHACKLE ISLAND RD
# 4        HTI MEMORIAL HOSPITAL CORPORATION        3441 DICKERSON PIKE
# 5               NASHVILLE GENERAL HOSPITAL             1818 ALBION ST
# 6         SAINT THOMAS RUTHERFORD HOSPITAL   1700 MEDICAL CENTER PKWY
# 7               SAINT THOMAS WEST HOSPITAL            4220 HARDING RD
# 8               SAINT THOMAS WEST HOSPITAL             2000 CHURCH ST
# 9                        SETON CORPORATION             2000 CHURCH ST
# 10     SUMNER REGIONAL HEALTH SYSTEMS, INC        555 HARTSVILLE PIKE
# 11      SUMNER REGIONAL MEDICAL CENTER LLC        555 HARTSVILLE PIKE
# 12                TRUSTPOINT HOSPITAL, LLC        1009 N. THOMPSON LN
# 13    VANDERBILT UNIVERSITY MEDICAL CENTER  1211 MEDICAL CENTER DRIVE
# 14    VANDERBILT UNIVERSITY MEDICAL CENTER            1601 23RD AVE S
# 15     WILLIAMSON COUNTY HOSPITAL DISTRICT     4321 CAROTHERS PARKWAY
#
#            address_line2            city state    zip
# 0                   None       NASHVILLE    TN  37203
# 1                   None       NASHVILLE    TN  37211
# 2                   None          SMYRNA    TN  37167
# 3                   None  HENDERSONVILLE    TN  37075
# 4                   None       NASHVILLE    TN  37207
# 5   ATTN: MARTHA LAMPLEY       NASHVILLE    TN  37208
# 6                   None    MURFREESBORO    TN  37129
# 7                   None       NASHVILLE    TN  37205
# 8                   None       NASHVILLE    TN  37236
# 9                   None       NASHVILLE    TN  37236
# 10                  None        GALLATIN    TN  37066
# 11                  None        GALLATIN    TN  37066
# 12                  None    MURFREESBORO    TN  37128
# 13                  None       NASHVILLE    TN  37232
# 14                  None       NASHVILLE    TN  37212
# 15                  None        FRANKLIN    TN  37067

# %%
#Combine relevant dfs to make full_refs

full_refs = (providers.merge(gach, 
                on = 'referral_id',
               suffixes = ('_provider', '_hospital'))
          .merge(referrals,
                on = ['referral_id', 'from_npi', 'to_npi'])
)

full_refs
# Out:
#         from_npi  referral_id  entity_type_code_provider  \
# 0     1548466808      9550017                        1.0
# 1     1558355941      9550019                        1.0
# 2     1790891315     13457790                        1.0
# 3     1053366369     20389882                        1.0
# 4     1043663719     20389883                        1.0
# ...          ...          ...                        ...
# 6870  1174565543    167471199                        1.0
# 6871  1942254883    174721235                        1.0
# 6872  1194751354    181082032                        1.0
# 6873  1194743914    181082033                        1.0
# 6874  1265589139    196663623                        1.0
#
#                       name taxonomy_code_provider  \
# 0           JONES, MATTHEW             2085R0202X
# 1             JOSEPH, JOJU             207RN0300X
# 2            RUSSO, DONALD             207RC0000X
# 3            NABORS, GLENN             2085R0202X
# 4     GUSTAFSON, STEPHANIE             367500000X
# ...                    ...                    ...
# 6870           DOSS, HABIB             207RH0003X
# 6871       BURCHAM, ROBERT             2085R0202X
# 6872        PEACOCK, NANCY             207RX0202X
# 6873       PENLEY, WILLIAM             207RX0202X
# 6874            NICK, ALPA             207VX0201X
#
#                       Classification_provider Specialization_provider  \
# 0                                   Radiology    Diagnostic Radiology
# 1                           Internal Medicine              Nephrology
# 2                           Internal Medicine  Cardiovascular Disease
# 3                                   Radiology    Diagnostic Radiology
# 4     Nurse Anesthetist, Certified Registered                    None
# ...                                       ...                     ...
# 6870                        Internal Medicine   Hematology & Oncology
# 6871                                Radiology    Diagnostic Radiology
# 6872                        Internal Medicine        Medical Oncology
# 6873                        Internal Medicine        Medical Oncology
# 6874                  Obstetrics & Gynecology    Gynecologic Oncology
#
#      organization_provider     address_line1_provider address_line2_provider  \
# 0                     None             1265 UNION AVE                   None
# 1                     None       270 EAST MAIN STREET              SUITE 200
# 2                     None  353 NEW SHACKLE ISLAND RD                  #300C
# 3                     None        620 HARTSVILLE PIKE                   None
# 4                     None             110 29TH AVE N              SUITE 201
# ...                    ...                        ...                    ...
# 6870                  None      2004 HAYES ST STE 350                   None
# 6871                  None     3024 BUSINESS PARK CIR                   None
# 6872                  None      2004 HAYES ST STE 350                   None
# 6873                  None      2004 HAYES ST STE 350                   None
# 6874                  None      2004 HAYES ST STE 350                   None
#
#       ...                organization_hospital address_line1_hospital  \
# 0     ...  SUMNER REGIONAL HEALTH SYSTEMS, INC    555 HARTSVILLE PIKE
# 1     ...  SUMNER REGIONAL HEALTH SYSTEMS, INC    555 HARTSVILLE PIKE
# 2     ...  SUMNER REGIONAL HEALTH SYSTEMS, INC    555 HARTSVILLE PIKE
# 3     ...  SUMNER REGIONAL HEALTH SYSTEMS, INC    555 HARTSVILLE PIKE
# 4     ...  SUMNER REGIONAL HEALTH SYSTEMS, INC    555 HARTSVILLE PIKE
# ...   ...                                  ...                    ...
# 6870  ...                    SETON CORPORATION         2000 CHURCH ST
# 6871  ...                    SETON CORPORATION         2000 CHURCH ST
# 6872  ...                    SETON CORPORATION         2000 CHURCH ST
# 6873  ...                    SETON CORPORATION         2000 CHURCH ST
# 6874  ...                    SETON CORPORATION         2000 CHURCH ST
#
#      address_line2_hospital  city_hospital  state_hospital zip_hospital  \
# 0                      None       GALLATIN              TN        37066
# 1                      None       GALLATIN              TN        37066
# 2                      None       GALLATIN              TN        37066
# 3                      None       GALLATIN              TN        37066
# 4                      None       GALLATIN              TN        37066
# ...                     ...            ...             ...          ...
# 6870                   None      NASHVILLE              TN        37236
# 6871                   None      NASHVILLE              TN        37236
# 6872                   None      NASHVILLE              TN        37236
# 6873                   None      NASHVILLE              TN        37236
# 6874                   None      NASHVILLE              TN        37236
#
#      patient_count transaction_count average_day_wait std_day_wait
# 0              121               135           32.563       62.417
# 1               81               292            6.767       30.330
# 2               70                71           47.254       75.620
# 3              141               154           38.636       68.659
# 4               71                73            5.808       21.015
# ...            ...               ...              ...          ...
# 6870            69               143            3.273       26.756
# 6871            52                65           13.154       32.501
# 6872            37                64           12.641       38.231
# 6873            43                69           23.420       48.484
# 6874            31                67            0.313        2.566
#
# [6875 rows x 28 columns]

# %%
#we don't want radiology and pathology because they don't refer patients to doctors

full_refs=full_refs[(full_refs['Classification_provider'] != 'Radiology') 
         & (full_refs['Classification_provider'] != 'Pathology')
         & (full_refs['Classification_provider'] != 'Emergency Medicine')]

# %%
#dataframe showing if the referral is to vanderbilt or not 

def make_not_to_vandy(df, group):

    # create a column that labels whether the recommendation went to Vanderbilt or not
    df['to_vandy'] = df['organization_hospital'].str.contains('VANDERBILT')

    # for each specialty, determine the count of patients recommended to and not recommended to Vanderbilt
    to_vandy = (df.groupby(group + ['to_vandy'])
         ['patient_count']
         .sum()
         .reset_index()
    )

    # add a column for overall count of referrals by specialty, then determine proportion
    to_vandy['patient_count_overall'] = (to_vandy.groupby(group)
                                     ['patient_count']
                                     .transform(sum)
                                    )
    
    #add a column for referral percentage not to vanderbilt
    to_vandy['ref_perc_not_vandy'] = round((to_vandy['patient_count']/
                                     to_vandy['patient_count_overall']
                                    ), 2)
    
 
    #add a column for referral percentage to vanderbilt
    to_vandy['ref_perc_to_vandy']= (1- to_vandy['ref_perc_not_vandy'])
        
    
    # filter to focus just on referrals not to Vanderbilt
    not_to_vandy = to_vandy[to_vandy['to_vandy'] == False]
    
    return not_to_vandy.sort_values('patient_count', ascending = False)

# %%
#top 25 specialties not referring to vandy
#In internal medicine, cardiovascular disease, 54% of patients are referred somewhere else and only 46% are referred to vandy

spec_not_to_vandy = make_not_to_vandy(full_refs, ['taxonomy_code_provider', 'Classification_provider', 'Specialization_provider'])

spec_not_to_vandy.nlargest(25, 'patient_count_overall')
# Out:
#     taxonomy_code_provider Classification_provider  \
# 33              207RC0000X       Internal Medicine
# 156             363LF0000X      Nurse Practitioner
# 59              207RP1001X       Internal Medicine
# 57              207RN0300X       Internal Medicine
# 150             363LA2100X      Nurse Practitioner
# 41              207RG0100X       Internal Medicine
# 53              207RI0011X       Internal Medicine
# 107             2084N0400X  Psychiatry & Neurology
# 49              207RH0003X       Internal Medicine
# 35              207RC0001X       Internal Medicine
# 66              207RX0202X       Internal Medicine
# 39              207RE0101X       Internal Medicine
# 152             363LA2200X      Nurse Practitioner
# 30              207RA0001X       Internal Medicine
# 126             2086S0129X                 Surgery
# 55              207RI0200X       Internal Medicine
# 111             2084P0800X  Psychiatry & Neurology
# 61              207RR0500X       Internal Medicine
# 12              207LC0200X          Anesthesiology
# 138             213ES0103X              Podiatrist
# 146             363AM0700X     Physician Assistant
# 124             2086S0127X                 Surgery
# 76              207WX0107X           Ophthalmology
# 43              207RG0300X       Internal Medicine
# 14              207LP2900X          Anesthesiology
#
#                               Specialization_provider  to_vandy  \
# 33                             Cardiovascular Disease     False
# 156                                            Family     False
# 59                                  Pulmonary Disease     False
# 57                                         Nephrology     False
# 150                                        Acute Care     False
# 41                                   Gastroenterology     False
# 53                          Interventional Cardiology     False
# 107                                         Neurology     False
# 49                              Hematology & Oncology     False
# 35                 Clinical Cardiac Electrophysiology     False
# 66                                   Medical Oncology     False
# 39               Endocrinology, Diabetes & Metabolism     False
# 152                                      Adult Health     False
# 30   Advanced Heart Failure and Transplant Cardiology     False
# 126                                  Vascular Surgery     False
# 55                                 Infectious Disease     False
# 111                                        Psychiatry     False
# 61                                       Rheumatology     False
# 12                             Critical Care Medicine     False
# 138                              Foot & Ankle Surgery     False
# 146                                           Medical     False
# 124                                    Trauma Surgery     False
# 76                                  Retina Specialist     False
# 43                                 Geriatric Medicine     False
# 14                                      Pain Medicine     False
#
#      patient_count  patient_count_overall  ref_perc_not_vandy  \
# 33           68782                 126991                0.54
# 156          17198                  30923                0.56
# 59           21469                  26743                0.80
# 57           16921                  26353                0.64
# 150           8497                  21791                0.39
# 41           14090                  21705                0.65
# 53           17511                  20002                0.88
# 107           8834                  18003                0.49
# 49            7906                  17565                0.45
# 35           10870                  14103                0.77
# 66            6670                  11598                0.58
# 39            3952                  10308                0.38
# 152           3401                   9706                0.35
# 30            6097                   9178                0.66
# 126           5279                   8033                0.66
# 55            4399                   7843                0.56
# 111           3097                   7428                0.42
# 61            1748                   7147                0.24
# 12            4008                   7044                0.57
# 138           3037                   5327                0.57
# 146           2339                   3285                0.71
# 124            760                   3014                0.25
# 76            1381                   2952                0.47
# 43             521                   2936                0.18
# 14            1206                   2779                0.43
#
#      ref_perc_to_vandy
# 33                0.46
# 156               0.44
# 59                0.20
# 57                0.36
# 150               0.61
# 41                0.35
# 53                0.12
# 107               0.51
# 49                0.55
# 35                0.23
# 66                0.42
# 39                0.62
# 152               0.65
# 30                0.34
# 126               0.34
# 55                0.44
# 111               0.58
# 61                0.76
# 12                0.43
# 138               0.43
# 146               0.29
# 124               0.75
# 76                0.53
# 43                0.82
# 14                0.57

# %%
#top 10 specializations (with highest number of patients) referring 25-75% patients to vandy 

top_spec=spec_not_to_vandy[(spec_not_to_vandy['ref_perc_to_vandy'] >= 0.25) 
                  & (spec_not_to_vandy['ref_perc_to_vandy']<=0.75)].nlargest(10, 'patient_count_overall')
top_spec
# Out:
#     taxonomy_code_provider Classification_provider  \
# 33              207RC0000X       Internal Medicine
# 156             363LF0000X      Nurse Practitioner
# 57              207RN0300X       Internal Medicine
# 150             363LA2100X      Nurse Practitioner
# 41              207RG0100X       Internal Medicine
# 107             2084N0400X  Psychiatry & Neurology
# 49              207RH0003X       Internal Medicine
# 66              207RX0202X       Internal Medicine
# 39              207RE0101X       Internal Medicine
# 152             363LA2200X      Nurse Practitioner
#
#                   Specialization_provider  to_vandy  patient_count  \
# 33                 Cardiovascular Disease     False          68782
# 156                                Family     False          17198
# 57                             Nephrology     False          16921
# 150                            Acute Care     False           8497
# 41                       Gastroenterology     False          14090
# 107                             Neurology     False           8834
# 49                  Hematology & Oncology     False           7906
# 66                       Medical Oncology     False           6670
# 39   Endocrinology, Diabetes & Metabolism     False           3952
# 152                          Adult Health     False           3401
#
#      patient_count_overall  ref_perc_not_vandy  ref_perc_to_vandy
# 33                  126991                0.54               0.46
# 156                  30923                0.56               0.44
# 57                   26353                0.64               0.36
# 150                  21791                0.39               0.61
# 41                   21705                0.65               0.35
# 107                  18003                0.49               0.51
# 49                   17565                0.45               0.55
# 66                   11598                0.58               0.42
# 39                   10308                0.38               0.62
# 152                   9706                0.35               0.65

# %%
#renaming the columns we are interested in

top_spec=top_spec.rename(columns ={'Classification_provider': 'Classification',
                                           'Specialization_provider': 'Specialization',
                                            'patient_count_overall': 'Total Patient Count',
                                            'ref_perc_to_vandy': 'Referral Percentage to Vanderlit'
    
})
top_spec
# Out:
#     taxonomy_code_provider          Classification  \
# 33              207RC0000X       Internal Medicine
# 156             363LF0000X      Nurse Practitioner
# 57              207RN0300X       Internal Medicine
# 150             363LA2100X      Nurse Practitioner
# 41              207RG0100X       Internal Medicine
# 107             2084N0400X  Psychiatry & Neurology
# 49              207RH0003X       Internal Medicine
# 66              207RX0202X       Internal Medicine
# 39              207RE0101X       Internal Medicine
# 152             363LA2200X      Nurse Practitioner
#
#                            Specialization  to_vandy  patient_count  \
# 33                 Cardiovascular Disease     False          68782
# 156                                Family     False          17198
# 57                             Nephrology     False          16921
# 150                            Acute Care     False           8497
# 41                       Gastroenterology     False          14090
# 107                             Neurology     False           8834
# 49                  Hematology & Oncology     False           7906
# 66                       Medical Oncology     False           6670
# 39   Endocrinology, Diabetes & Metabolism     False           3952
# 152                          Adult Health     False           3401
#
#      Total Patient Count  ref_perc_not_vandy  Referral Percentage to Vanderlit
# 33                126991                0.54                              0.46
# 156                30923                0.56                              0.44
# 57                 26353                0.64                              0.36
# 150                21791                0.39                              0.61
# 41                 21705                0.65                              0.35
# 107                18003                0.49                              0.51
# 49                 17565                0.45                              0.55
# 66                 11598                0.58                              0.42
# 39                 10308                0.38                              0.62
# 152                 9706                0.35                              0.65

# %%
#final table that has top 10 specialization that has 25-75% referral to vanderbilt

top_spec[['Classification','Specialization','Total Patient Count', 'Referral Percentage to Vanderlit']]
# Out:
#              Classification                        Specialization  \
# 33        Internal Medicine                Cardiovascular Disease
# 156      Nurse Practitioner                                Family
# 57        Internal Medicine                            Nephrology
# 150      Nurse Practitioner                            Acute Care
# 41        Internal Medicine                      Gastroenterology
# 107  Psychiatry & Neurology                             Neurology
# 49        Internal Medicine                 Hematology & Oncology
# 66        Internal Medicine                      Medical Oncology
# 39        Internal Medicine  Endocrinology, Diabetes & Metabolism
# 152      Nurse Practitioner                          Adult Health
#
#      Total Patient Count  Referral Percentage to Vanderlit
# 33                126991                              0.46
# 156                30923                              0.44
# 57                 26353                              0.36
# 150                21791                              0.61
# 41                 21705                              0.35
# 107                18003                              0.51
# 49                 17565                              0.55
# 66                 11598                              0.42
# 39                 10308                              0.62
# 152                 9706                              0.65

# %% [markdown]
# #### Now, we should find which providers we can recommend to Vanderbilt

# %%
#providers not referring patients to vanderbilt 

#In internal medicine, John Riddick and in pathology, Derek Welch should be reached out by vanderbilt to gain patients. 

prov_not_to_vandy = make_not_to_vandy(full_refs, ['from_npi', 'name', 'Classification_provider', 'Specialization_provider'])
prov_not_to_vandy.nlargest(25, 'patient_count_overall')
# Out:
#         from_npi                    name Classification_provider  \
# 846   1417131715           RIDDICK, JOHN       Internal Medicine
# 973   1467491670            HUGHES, SEAN       Internal Medicine
# 1441  1679665095           PRUDOFF, ADAM       Internal Medicine
# 1443  1679689285        CALLISTER, TRACY       Internal Medicine
# 210   1114961513        HUMPHREY, STEVEN       Internal Medicine
# 1907  1902823859        HUNEYCUTT, DAVID       Internal Medicine
# 98    1053337717             KAZA, SUNIL       Internal Medicine
# 891   1427079946     CONLEY, CHRISTOPHER       Internal Medicine
# 194   1104933738               LEE, JUNG       Internal Medicine
# 2052  1972658060            KETCH, TERRY       Internal Medicine
# 510   1255488052         ANDERSON, BRENT       Internal Medicine
# 448   1225027014           KUDELKO, PAUL       Internal Medicine
# 24    1013179860              YAWN, GARY       Internal Medicine
# 1276  1598833808           ESTRADA, JUAN       Internal Medicine
# 1970  1932274503          CABELL, THOMAS       Internal Medicine
# 1178  1558461970        WHEATLEY, ROBERT       Internal Medicine
# 1676  1790891315           RUSSO, DONALD       Internal Medicine
# 1817  1861430621            KEMP, WILSON       Internal Medicine
# 1106  1528174752      ELLIS, CHRISTOPHER       Internal Medicine
# 272   1144377011             DAMP, JULIE       Internal Medicine
# 1980  1932381795  KANAGASUNDRAM, ARVINDH       Internal Medicine
# 1989  1942203849         FRANKLIN, JERRY       Internal Medicine
# 1997  1942290333     DICKERSON, REGINALD       Internal Medicine
# 952   1457437782      RICHARDSON, THOMAS       Internal Medicine
# 663   1326086653           GRAVES, DANTE       Internal Medicine
#
#                  Specialization_provider  to_vandy  patient_count  \
# 846            Interventional Cardiology     False           6168
# 973               Cardiovascular Disease     False            897
# 1441              Cardiovascular Disease     False           1154
# 1443              Cardiovascular Disease     False           2280
# 210               Cardiovascular Disease     False           2187
# 1907              Cardiovascular Disease     False           2163
# 98                Cardiovascular Disease     False           2119
# 891   Clinical Cardiac Electrophysiology     False           2070
# 194               Cardiovascular Disease     False           2049
# 2052              Cardiovascular Disease     False           2018
# 510               Cardiovascular Disease     False           1205
# 448               Cardiovascular Disease     False           1961
# 24             Interventional Cardiology     False           1899
# 1276              Cardiovascular Disease     False            316
# 1970              Cardiovascular Disease     False           1678
# 1178           Interventional Cardiology     False           1805
# 1676              Cardiovascular Disease     False           1803
# 1817              Cardiovascular Disease     False           1612
# 1106              Cardiovascular Disease     False             78
# 272               Cardiovascular Disease     False             73
# 1980              Cardiovascular Disease     False             75
# 1989              Cardiovascular Disease     False           1089
# 1997              Cardiovascular Disease     False           1718
# 952               Cardiovascular Disease     False            902
# 663               Cardiovascular Disease     False           1704
#
#       patient_count_overall  ref_perc_not_vandy  ref_perc_to_vandy
# 846                    6168                1.00               0.00
# 973                    3249                0.28               0.72
# 1441                   2652                0.44               0.56
# 1443                   2526                0.90               0.10
# 210                    2187                1.00               0.00
# 1907                   2163                1.00               0.00
# 98                     2119                1.00               0.00
# 891                    2070                1.00               0.00
# 194                    2049                1.00               0.00
# 2052                   2018                1.00               0.00
# 510                    1968                0.61               0.39
# 448                    1961                1.00               0.00
# 24                     1899                1.00               0.00
# 1276                   1850                0.17               0.83
# 1970                   1814                0.93               0.07
# 1178                   1805                1.00               0.00
# 1676                   1803                1.00               0.00
# 1817                   1776                0.91               0.09
# 1106                   1775                0.04               0.96
# 272                    1773                0.04               0.96
# 1980                   1752                0.04               0.96
# 1989                   1739                0.63               0.37
# 1997                   1718                1.00               0.00
# 952                    1708                0.53               0.47
# 663                    1704                1.00               0.00

# %%
#providers referring 25-75% of their patients to vandy 

top_prov=prov_not_to_vandy[(prov_not_to_vandy['ref_perc_to_vandy'] >= 0.25) 
                  & (prov_not_to_vandy['ref_perc_to_vandy']<=0.75)].nlargest(25, 'patient_count_overall')

top_prov
# Out:
#         from_npi                             name Classification_provider  \
# 973   1467491670                     HUGHES, SEAN       Internal Medicine
# 1441  1679665095                    PRUDOFF, ADAM       Internal Medicine
# 510   1255488052                  ANDERSON, BRENT       Internal Medicine
# 1989  1942203849                  FRANKLIN, JERRY       Internal Medicine
# 952   1457437782               RICHARDSON, THOMAS       Internal Medicine
# 1766  1831281245                   FRIESINGER, G.       Internal Medicine
# 776   1386663144                 THOMPSON, THOMAS       Internal Medicine
# 187   1104859115                    KOLLI, MURALI       Internal Medicine
# 1752  1831122860                  MANDA, RAVINDER       Internal Medicine
# 36    1013958776               ABU-HALIMAH, AHMAD       Internal Medicine
# 249   1134211550                  MILSTONE, AARON       Internal Medicine
# 1579  1750394060                  HABERMANN, RALF       Internal Medicine
# 1897  1902075500                  DANTZLER, DAVID       Internal Medicine
# 1133  1538256672                    ROBBINS, MARK       Internal Medicine
# 868   1417946203                     WALLACE, ROY           Ophthalmology
# 968   1467406314                     PHARES, JOEL       Internal Medicine
# 196   1114019528                      HUNT, LAURA       Internal Medicine
# 1722  1811287204                  KENNEDY, MARTHA      Nurse Practitioner
# 873   1417973249                  CALENDINE, CORY     Orthopaedic Surgery
# 109   1063449031                      MALTZ, BRAD       Internal Medicine
# 724   1356438469                  RECCHIA, FRANCO           Ophthalmology
# 1160  1548485071                 PERKINSON, BRIAN     Orthopaedic Surgery
# 172   1093941890                     ASSAD, TUFIK       Internal Medicine
# 1423  1669665105                REICHSTEIN, DAVID           Ophthalmology
# 895   1427251859  SANTANA DE LOS SANTOS, JENNIFER       Internal Medicine
#
#                        Specialization_provider  to_vandy  patient_count  \
# 973                     Cardiovascular Disease     False            897
# 1441                    Cardiovascular Disease     False           1154
# 510                     Cardiovascular Disease     False           1205
# 1989                    Cardiovascular Disease     False           1089
# 952                     Cardiovascular Disease     False            902
# 1766                    Cardiovascular Disease     False            992
# 776                     Cardiovascular Disease     False            717
# 187                     Cardiovascular Disease     False            523
# 1752                    Cardiovascular Disease     False            554
# 36                      Cardiovascular Disease     False            456
# 249                          Pulmonary Disease     False            687
# 1579                        Geriatric Medicine     False            233
# 1897                 Interventional Cardiology     False            337
# 1133                 Interventional Cardiology     False            146
# 868                          Retina Specialist     False            325
# 968                     Cardiovascular Disease     False            145
# 196                          Pulmonary Disease     False            394
# 1722                              Adult Health     False            395
# 873   Adult Reconstructive Orthopaedic Surgery     False            331
# 109                           Gastroenterology     False            252
# 724                          Retina Specialist     False            307
# 1160  Adult Reconstructive Orthopaedic Surgery     False            317
# 172                          Pulmonary Disease     False            343
# 1423                         Retina Specialist     False            308
# 895                                 Nephrology     False            304
#
#       patient_count_overall  ref_perc_not_vandy  ref_perc_to_vandy
# 973                    3249                0.28               0.72
# 1441                   2652                0.44               0.56
# 510                    1968                0.61               0.39
# 1989                   1739                0.63               0.37
# 952                    1708                0.53               0.47
# 1766                   1699                0.58               0.42
# 776                    1213                0.59               0.41
# 187                    1164                0.45               0.55
# 1752                   1090                0.51               0.49
# 36                     1051                0.43               0.57
# 249                    1044                0.66               0.34
# 1579                    838                0.28               0.72
# 1897                    654                0.52               0.48
# 1133                    644                0.23               0.77
# 868                     602                0.54               0.46
# 968                     568                0.26               0.74
# 196                     563                0.70               0.30
# 1722                    544                0.73               0.27
# 873                     538                0.62               0.38
# 109                     516                0.49               0.51
# 724                     501                0.61               0.39
# 1160                    490                0.65               0.35
# 172                     464                0.74               0.26
# 1423                    418                0.74               0.26
# 895                     405                0.75               0.25

# %%
#we need to know doctors' affiliation

query = """
SELECT *
FROM affiliations_from

"""
with sqlite3.connect('data/hopteam_broad.sqlite') as db: 
    aff_from_sqlite = pd.read_sql(query, db)
    
aff_from_sqlite
# Out:
#          from_npi            affiliation_from
# 0      1821080961            NOT IN NASHVILLE
# 1      1093741464                         HCA
# 2      1295726032            NOT IN NASHVILLE
# 3      1679677199            NOT IN NASHVILLE
# 4      1841282779            NOT IN NASHVILLE
# ...           ...                         ...
# 38945  1912301771            NOT IN NASHVILLE
# 38946  1508880493  NO MAJOR AFFILIATION/OTHER
# 38947  1134143027            NOT IN NASHVILLE
# 38948  1326550674  NO MAJOR AFFILIATION/OTHER
# 38949  1205931565            NOT IN NASHVILLE
#
# [38950 rows x 2 columns]

# %%
#merging affiliation with the providers' dataset

prov_aff=pd.merge(top_prov, aff_from_sqlite)
prov_aff
# Out:
#       from_npi                             name Classification_provider  \
# 0   1467491670                     HUGHES, SEAN       Internal Medicine
# 1   1679665095                    PRUDOFF, ADAM       Internal Medicine
# 2   1255488052                  ANDERSON, BRENT       Internal Medicine
# 3   1942203849                  FRANKLIN, JERRY       Internal Medicine
# 4   1457437782               RICHARDSON, THOMAS       Internal Medicine
# 5   1831281245                   FRIESINGER, G.       Internal Medicine
# 6   1386663144                 THOMPSON, THOMAS       Internal Medicine
# 7   1104859115                    KOLLI, MURALI       Internal Medicine
# 8   1831122860                  MANDA, RAVINDER       Internal Medicine
# 9   1013958776               ABU-HALIMAH, AHMAD       Internal Medicine
# 10  1134211550                  MILSTONE, AARON       Internal Medicine
# 11  1750394060                  HABERMANN, RALF       Internal Medicine
# 12  1902075500                  DANTZLER, DAVID       Internal Medicine
# 13  1538256672                    ROBBINS, MARK       Internal Medicine
# 14  1417946203                     WALLACE, ROY           Ophthalmology
# 15  1467406314                     PHARES, JOEL       Internal Medicine
# 16  1114019528                      HUNT, LAURA       Internal Medicine
# 17  1811287204                  KENNEDY, MARTHA      Nurse Practitioner
# 18  1417973249                  CALENDINE, CORY     Orthopaedic Surgery
# 19  1063449031                      MALTZ, BRAD       Internal Medicine
# 20  1356438469                  RECCHIA, FRANCO           Ophthalmology
# 21  1548485071                 PERKINSON, BRIAN     Orthopaedic Surgery
# 22  1093941890                     ASSAD, TUFIK       Internal Medicine
# 23  1669665105                REICHSTEIN, DAVID           Ophthalmology
# 24  1427251859  SANTANA DE LOS SANTOS, JENNIFER       Internal Medicine
#
#                      Specialization_provider  to_vandy  patient_count  \
# 0                     Cardiovascular Disease     False            897
# 1                     Cardiovascular Disease     False           1154
# 2                     Cardiovascular Disease     False           1205
# 3                     Cardiovascular Disease     False           1089
# 4                     Cardiovascular Disease     False            902
# 5                     Cardiovascular Disease     False            992
# 6                     Cardiovascular Disease     False            717
# 7                     Cardiovascular Disease     False            523
# 8                     Cardiovascular Disease     False            554
# 9                     Cardiovascular Disease     False            456
# 10                         Pulmonary Disease     False            687
# 11                        Geriatric Medicine     False            233
# 12                 Interventional Cardiology     False            337
# 13                 Interventional Cardiology     False            146
# 14                         Retina Specialist     False            325
# 15                    Cardiovascular Disease     False            145
# 16                         Pulmonary Disease     False            394
# 17                              Adult Health     False            395
# 18  Adult Reconstructive Orthopaedic Surgery     False            331
# 19                          Gastroenterology     False            252
# 20                         Retina Specialist     False            307
# 21  Adult Reconstructive Orthopaedic Surgery     False            317
# 22                         Pulmonary Disease     False            343
# 23                         Retina Specialist     False            308
# 24                                Nephrology     False            304
#
#     patient_count_overall  ref_perc_not_vandy  ref_perc_to_vandy  \
# 0                    3249                0.28               0.72
# 1                    2652                0.44               0.56
# 2                    1968                0.61               0.39
# 3                    1739                0.63               0.37
# 4                    1708                0.53               0.47
# 5                    1699                0.58               0.42
# 6                    1213                0.59               0.41
# 7                    1164                0.45               0.55
# 8                    1090                0.51               0.49
# 9                    1051                0.43               0.57
# 10                   1044                0.66               0.34
# 11                    838                0.28               0.72
# 12                    654                0.52               0.48
# 13                    644                0.23               0.77
# 14                    602                0.54               0.46
# 15                    568                0.26               0.74
# 16                    563                0.70               0.30
# 17                    544                0.73               0.27
# 18                    538                0.62               0.38
# 19                    516                0.49               0.51
# 20                    501                0.61               0.39
# 21                    490                0.65               0.35
# 22                    464                0.74               0.26
# 23                    418                0.74               0.26
# 24                    405                0.75               0.25
#
#           affiliation_from
# 0               VANDERBILT
# 1               VANDERBILT
# 2               VANDERBILT
# 3               VANDERBILT
# 4               VANDERBILT
# 5                LIFEPOINT
# 6   SAINT THOMAS ASCENSION
# 7               VANDERBILT
# 8               VANDERBILT
# 9               VANDERBILT
# 10              VANDERBILT
# 11              VANDERBILT
# 12  SAINT THOMAS ASCENSION
# 13  SAINT THOMAS ASCENSION
# 14                     HCA
# 15              VANDERBILT
# 16              VANDERBILT
# 17              VANDERBILT
# 18              VANDERBILT
# 19              VANDERBILT
# 20                     HCA
# 21              VANDERBILT
# 22        NOT IN NASHVILLE
# 23                     HCA
# 24  SAINT THOMAS ASCENSION

# %%
#renaming columns we are interested in

prov_aff=prov_aff.rename(columns ={'Classification_provider': 'Classification',
                                           'Specialization_provider': 'Specialization',
                                            'patient_count_overall': 'Total Patient Count',
                                            'ref_perc_to_vandy': 'Referral Percentage to Vanderlit',
                                           'affiliation_from': 'Affiliation',
                                           'name': 'Name'
    
})
prov_aff
# Out:
#       from_npi                             Name       Classification  \
# 0   1467491670                     HUGHES, SEAN    Internal Medicine
# 1   1679665095                    PRUDOFF, ADAM    Internal Medicine
# 2   1255488052                  ANDERSON, BRENT    Internal Medicine
# 3   1942203849                  FRANKLIN, JERRY    Internal Medicine
# 4   1457437782               RICHARDSON, THOMAS    Internal Medicine
# 5   1831281245                   FRIESINGER, G.    Internal Medicine
# 6   1386663144                 THOMPSON, THOMAS    Internal Medicine
# 7   1104859115                    KOLLI, MURALI    Internal Medicine
# 8   1831122860                  MANDA, RAVINDER    Internal Medicine
# 9   1013958776               ABU-HALIMAH, AHMAD    Internal Medicine
# 10  1134211550                  MILSTONE, AARON    Internal Medicine
# 11  1750394060                  HABERMANN, RALF    Internal Medicine
# 12  1902075500                  DANTZLER, DAVID    Internal Medicine
# 13  1538256672                    ROBBINS, MARK    Internal Medicine
# 14  1417946203                     WALLACE, ROY        Ophthalmology
# 15  1467406314                     PHARES, JOEL    Internal Medicine
# 16  1114019528                      HUNT, LAURA    Internal Medicine
# 17  1811287204                  KENNEDY, MARTHA   Nurse Practitioner
# 18  1417973249                  CALENDINE, CORY  Orthopaedic Surgery
# 19  1063449031                      MALTZ, BRAD    Internal Medicine
# 20  1356438469                  RECCHIA, FRANCO        Ophthalmology
# 21  1548485071                 PERKINSON, BRIAN  Orthopaedic Surgery
# 22  1093941890                     ASSAD, TUFIK    Internal Medicine
# 23  1669665105                REICHSTEIN, DAVID        Ophthalmology
# 24  1427251859  SANTANA DE LOS SANTOS, JENNIFER    Internal Medicine
#
#                               Specialization  to_vandy  patient_count  \
# 0                     Cardiovascular Disease     False            897
# 1                     Cardiovascular Disease     False           1154
# 2                     Cardiovascular Disease     False           1205
# 3                     Cardiovascular Disease     False           1089
# 4                     Cardiovascular Disease     False            902
# 5                     Cardiovascular Disease     False            992
# 6                     Cardiovascular Disease     False            717
# 7                     Cardiovascular Disease     False            523
# 8                     Cardiovascular Disease     False            554
# 9                     Cardiovascular Disease     False            456
# 10                         Pulmonary Disease     False            687
# 11                        Geriatric Medicine     False            233
# 12                 Interventional Cardiology     False            337
# 13                 Interventional Cardiology     False            146
# 14                         Retina Specialist     False            325
# 15                    Cardiovascular Disease     False            145
# 16                         Pulmonary Disease     False            394
# 17                              Adult Health     False            395
# 18  Adult Reconstructive Orthopaedic Surgery     False            331
# 19                          Gastroenterology     False            252
# 20                         Retina Specialist     False            307
# 21  Adult Reconstructive Orthopaedic Surgery     False            317
# 22                         Pulmonary Disease     False            343
# 23                         Retina Specialist     False            308
# 24                                Nephrology     False            304
#
#     Total Patient Count  ref_perc_not_vandy  Referral Percentage to Vanderlit  \
# 0                  3249                0.28                              0.72
# 1                  2652                0.44                              0.56
# 2                  1968                0.61                              0.39
# 3                  1739                0.63                              0.37
# 4                  1708                0.53                              0.47
# 5                  1699                0.58                              0.42
# 6                  1213                0.59                              0.41
# 7                  1164                0.45                              0.55
# 8                  1090                0.51                              0.49
# 9                  1051                0.43                              0.57
# 10                 1044                0.66                              0.34
# 11                  838                0.28                              0.72
# 12                  654                0.52                              0.48
# 13                  644                0.23                              0.77
# 14                  602                0.54                              0.46
# 15                  568                0.26                              0.74
# 16                  563                0.70                              0.30
# 17                  544                0.73                              0.27
# 18                  538                0.62                              0.38
# 19                  516                0.49                              0.51
# 20                  501                0.61                              0.39
# 21                  490                0.65                              0.35
# 22                  464                0.74                              0.26
# 23                  418                0.74                              0.26
# 24                  405                0.75                              0.25
#
#                Affiliation
# 0               VANDERBILT
# 1               VANDERBILT
# 2               VANDERBILT
# 3               VANDERBILT
# 4               VANDERBILT
# 5                LIFEPOINT
# 6   SAINT THOMAS ASCENSION
# 7               VANDERBILT
# 8               VANDERBILT
# 9               VANDERBILT
# 10              VANDERBILT
# 11              VANDERBILT
# 12  SAINT THOMAS ASCENSION
# 13  SAINT THOMAS ASCENSION
# 14                     HCA
# 15              VANDERBILT
# 16              VANDERBILT
# 17              VANDERBILT
# 18              VANDERBILT
# 19              VANDERBILT
# 20                     HCA
# 21              VANDERBILT
# 22        NOT IN NASHVILLE
# 23                     HCA
# 24  SAINT THOMAS ASCENSION

# %%
#25 providers with 25-75% referral to vanderbilt

prov_aff[['Name', 'Affiliation','Classification','Specialization','Total Patient Count', 'Referral Percentage to Vanderlit']].sort_values('Total Patient Count', ascending=False)
# Out:
#                                Name             Affiliation  \
# 0                      HUGHES, SEAN              VANDERBILT
# 1                     PRUDOFF, ADAM              VANDERBILT
# 2                   ANDERSON, BRENT              VANDERBILT
# 3                   FRANKLIN, JERRY              VANDERBILT
# 4                RICHARDSON, THOMAS              VANDERBILT
# 5                    FRIESINGER, G.               LIFEPOINT
# 6                  THOMPSON, THOMAS  SAINT THOMAS ASCENSION
# 7                     KOLLI, MURALI              VANDERBILT
# 8                   MANDA, RAVINDER              VANDERBILT
# 9                ABU-HALIMAH, AHMAD              VANDERBILT
# 10                  MILSTONE, AARON              VANDERBILT
# 11                  HABERMANN, RALF              VANDERBILT
# 12                  DANTZLER, DAVID  SAINT THOMAS ASCENSION
# 13                    ROBBINS, MARK  SAINT THOMAS ASCENSION
# 14                     WALLACE, ROY                     HCA
# 15                     PHARES, JOEL              VANDERBILT
# 16                      HUNT, LAURA              VANDERBILT
# 17                  KENNEDY, MARTHA              VANDERBILT
# 18                  CALENDINE, CORY              VANDERBILT
# 19                      MALTZ, BRAD              VANDERBILT
# 20                  RECCHIA, FRANCO                     HCA
# 21                 PERKINSON, BRIAN              VANDERBILT
# 22                     ASSAD, TUFIK        NOT IN NASHVILLE
# 23                REICHSTEIN, DAVID                     HCA
# 24  SANTANA DE LOS SANTOS, JENNIFER  SAINT THOMAS ASCENSION
#
#          Classification                            Specialization  \
# 0     Internal Medicine                    Cardiovascular Disease
# 1     Internal Medicine                    Cardiovascular Disease
# 2     Internal Medicine                    Cardiovascular Disease
# 3     Internal Medicine                    Cardiovascular Disease
# 4     Internal Medicine                    Cardiovascular Disease
# 5     Internal Medicine                    Cardiovascular Disease
# 6     Internal Medicine                    Cardiovascular Disease
# 7     Internal Medicine                    Cardiovascular Disease
# 8     Internal Medicine                    Cardiovascular Disease
# 9     Internal Medicine                    Cardiovascular Disease
# 10    Internal Medicine                         Pulmonary Disease
# 11    Internal Medicine                        Geriatric Medicine
# 12    Internal Medicine                 Interventional Cardiology
# 13    Internal Medicine                 Interventional Cardiology
# 14        Ophthalmology                         Retina Specialist
# 15    Internal Medicine                    Cardiovascular Disease
# 16    Internal Medicine                         Pulmonary Disease
# 17   Nurse Practitioner                              Adult Health
# 18  Orthopaedic Surgery  Adult Reconstructive Orthopaedic Surgery
# 19    Internal Medicine                          Gastroenterology
# 20        Ophthalmology                         Retina Specialist
# 21  Orthopaedic Surgery  Adult Reconstructive Orthopaedic Surgery
# 22    Internal Medicine                         Pulmonary Disease
# 23        Ophthalmology                         Retina Specialist
# 24    Internal Medicine                                Nephrology
#
#     Total Patient Count  Referral Percentage to Vanderlit
# 0                  3249                              0.72
# 1                  2652                              0.56
# 2                  1968                              0.39
# 3                  1739                              0.37
# 4                  1708                              0.47
# 5                  1699                              0.42
# 6                  1213                              0.41
# 7                  1164                              0.55
# 8                  1090                              0.49
# 9                  1051                              0.57
# 10                 1044                              0.34
# 11                  838                              0.72
# 12                  654                              0.48
# 13                  644                              0.77
# 14                  602                              0.46
# 15                  568                              0.74
# 16                  563                              0.30
# 17                  544                              0.27
# 18                  538                              0.38
# 19                  516                              0.51
# 20                  501                              0.39
# 21                  490                              0.35
# 22                  464                              0.26
# 23                  418                              0.26
# 24                  405                              0.25

# %%
#formatting percentage 
prov_aff['Referral Percentage to Vanderlit']= (prov_aff['Referral Percentage to Vanderlit']*100).astype(int).astype(str).add('%')

# %%
prov_aff[['Name', 'Affiliation','Classification','Specialization','Total Patient Count', 'Referral Percentage to Vanderlit']].sort_values('Total Patient Count', ascending=False)
# Out:
#                                Name             Affiliation  \
# 0                      HUGHES, SEAN              VANDERBILT
# 1                     PRUDOFF, ADAM              VANDERBILT
# 2                   ANDERSON, BRENT              VANDERBILT
# 3                   FRANKLIN, JERRY              VANDERBILT
# 4                RICHARDSON, THOMAS              VANDERBILT
# 5                    FRIESINGER, G.               LIFEPOINT
# 6                  THOMPSON, THOMAS  SAINT THOMAS ASCENSION
# 7                     KOLLI, MURALI              VANDERBILT
# 8                   MANDA, RAVINDER              VANDERBILT
# 9                ABU-HALIMAH, AHMAD              VANDERBILT
# 10                  MILSTONE, AARON              VANDERBILT
# 11                  HABERMANN, RALF              VANDERBILT
# 12                  DANTZLER, DAVID  SAINT THOMAS ASCENSION
# 13                    ROBBINS, MARK  SAINT THOMAS ASCENSION
# 14                     WALLACE, ROY                     HCA
# 15                     PHARES, JOEL              VANDERBILT
# 16                      HUNT, LAURA              VANDERBILT
# 17                  KENNEDY, MARTHA              VANDERBILT
# 18                  CALENDINE, CORY              VANDERBILT
# 19                      MALTZ, BRAD              VANDERBILT
# 20                  RECCHIA, FRANCO                     HCA
# 21                 PERKINSON, BRIAN              VANDERBILT
# 22                     ASSAD, TUFIK        NOT IN NASHVILLE
# 23                REICHSTEIN, DAVID                     HCA
# 24  SANTANA DE LOS SANTOS, JENNIFER  SAINT THOMAS ASCENSION
#
#          Classification                            Specialization  \
# 0     Internal Medicine                    Cardiovascular Disease
# 1     Internal Medicine                    Cardiovascular Disease
# 2     Internal Medicine                    Cardiovascular Disease
# 3     Internal Medicine                    Cardiovascular Disease
# 4     Internal Medicine                    Cardiovascular Disease
# 5     Internal Medicine                    Cardiovascular Disease
# 6     Internal Medicine                    Cardiovascular Disease
# 7     Internal Medicine                    Cardiovascular Disease
# 8     Internal Medicine                    Cardiovascular Disease
# 9     Internal Medicine                    Cardiovascular Disease
# 10    Internal Medicine                         Pulmonary Disease
# 11    Internal Medicine                        Geriatric Medicine
# 12    Internal Medicine                 Interventional Cardiology
# 13    Internal Medicine                 Interventional Cardiology
# 14        Ophthalmology                         Retina Specialist
# 15    Internal Medicine                    Cardiovascular Disease
# 16    Internal Medicine                         Pulmonary Disease
# 17   Nurse Practitioner                              Adult Health
# 18  Orthopaedic Surgery  Adult Reconstructive Orthopaedic Surgery
# 19    Internal Medicine                          Gastroenterology
# 20        Ophthalmology                         Retina Specialist
# 21  Orthopaedic Surgery  Adult Reconstructive Orthopaedic Surgery
# 22    Internal Medicine                         Pulmonary Disease
# 23        Ophthalmology                         Retina Specialist
# 24    Internal Medicine                                Nephrology
#
#     Total Patient Count Referral Percentage to Vanderlit
# 0                  3249                              72%
# 1                  2652                              56%
# 2                  1968                              39%
# 3                  1739                              37%
# 4                  1708                              47%
# 5                  1699                              42%
# 6                  1213                              41%
# 7                  1164                              55%
# 8                  1090                              49%
# 9                  1051                              57%
# 10                 1044                              34%
# 11                  838                              72%
# 12                  654                              48%
# 13                  644                              77%
# 14                  602                              46%
# 15                  568                              74%
# 16                  563                              30%
# 17                  544                              27%
# 18                  538                              38%
# 19                  516                              51%
# 20                  501                              39%
# 21                  490                              35%
# 22                  464                              26%
# 23                  418                              26%
# 24                  405                              25%
