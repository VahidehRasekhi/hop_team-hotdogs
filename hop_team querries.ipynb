# %%
import pandas as pd
import sqlite3
from tqdm.notebook import tqdm

# %%
query = """
SELECT * 
FROM referrals 
WHERE transaction_count >=50
AND average_day_wait < 50
LIMIT 5

"""
with sqlite3.connect('data/hopteam.sqlite') as db: 
    ref_sqlite = pd.read_sql(query, db)
    
ref_sqlite
# Out:
#    referral_id  patient_count  transaction_count  average_day_wait  \
# 0            7             58                 67            23.925
# 1           10             51                 51            28.196
# 2           15            340                391            18.302
# 3           18             50                 79            12.658
# 4           25            132                145             8.579
#
#    std_day_wait
# 0        43.923
# 1        52.876
# 2        42.422
# 3        26.402
# 4        28.053

# %%
querry="""
SELECT *
FROM referral_from
LIMIT 5
"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    ref_from_sqlite=pd.read_sql(querry, db)

ref_from_sqlite
# Out:
#    referral_id    from_npi
# 0            0  1508062167
# 1            1  1508065640
# 2            2  1508052093
# 3            3  1508172545
# 4            4  1508285131

# %%
querry="""
SELECT *
FROM referral_to
LIMIT 5
"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    ref_to_sqlite=pd.read_sql(querry, db)

ref_to_sqlite
# Out:
#    referral_id      to_npi
# 0            0  1730166109
# 1            1  1730166109
# 2            2  1730166109
# 3            3  1730166109
# 4            4  1730166109

# %%
querry="""
SELECT *
FROM profile
LIMIT 5
"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    pro_sqlite=pd.read_sql(querry, db)

    
pro_sqlite
# Out:
#   Provider_First_Name Provider_Last_Name_(Legal_Name)  \
# 0               DAVID                           WIEBE
# 1             WILLIAM                         PILCHER
# 2                None                            None
# 3             LAURENT                         GRESSOT
# 4                None                            None
#
#   Provider_Business_Practice_Location_Address_State_Name  \
# 0                                                 NE
# 1                                                 FL
# 2                                                 NC
# 3                                                 TX
# 4                                                 CA
#
#   Provider_First_Line_Business_Practice_Location_Address  \
# 0                                   3500 CENTRAL AVE
# 1                                   1824 KING STREET
# 2                                    3418 VILLAGE DR
# 3                                   17323 RED OAK DR
# ...

# %%
querry="""
SELECT *
FROM zip_cbsa
LIMIT 5
"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    zip_sqlite=pd.read_sql(querry, db)
    
zip_sqlite
# Out:
#      zip   cbsa        city state  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0  00683  41900  SAN GERMAN    PR   0.999842        1.0        1.0   0.999855
# 1  00683  32420  SAN GERMAN    PR   0.000158        0.0        0.0   0.000145
# 2  00923  41980    SAN JUAN    PR   1.000000        1.0        1.0   1.000000
# 3  01010  44140   BRIMFIELD    MA   0.976896        1.0        1.0   0.977816
# 4  01010  49340   BRIMFIELD    MA   0.023104        0.0        0.0   0.022184

# %%
querry="""
SELECT *
FROM taxonomy_code
LIMIT 5
"""

with sqlite3.connect('data/hopteam.sqlite') as db:
    taxonomy_sqlite=pd.read_sql(querry, db)

taxonomy_sqlite
# Out:
#          Code                             Grouping        Classification  \
# 0  193200000X                                Group       Multi-Specialty
# 1  193400000X                                Group      Single Specialty
# 2  207K00000X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 3  207KA0200X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 4  207KI0005X  Allopathic & Osteopathic Physicians  Allergy & Immunology
#
#                      Specialization  \
# 0                              None
# 1                              None
# 2                              None
# 3                           Allergy
# 4  Clinical & Laboratory Immunology
#
#                                           Definition  \
# 0  A business group of one or more individual pra...
# 1  A business group of one or more individual pra...
# 2  An allergist-immunologist is trained in evalua...
# 3                              Definition to come...
# ...
